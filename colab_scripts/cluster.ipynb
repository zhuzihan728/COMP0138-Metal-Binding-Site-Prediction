# %% [markdown]
# <a href="https://colab.research.google.com/github/zhuzihan728/COMP0138-Metal-Binding-Site-Prediction/blob/main/colab_scripts/cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libs

# %%
# !pip install biopython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting biopython
#   Downloading biopython-1.81-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from biopython) (1.22.4)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
import pandas as pd
from Bio import SeqIO
import json

# %% [markdown]
# # Extract datasets

# %%
# !tar -xvf /content/drive/MyDrive/FYP/miniconda -C /root
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# miniconda/lib/python3.7/site-packages/conda_env/cli/__pycache__/main_config.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/cli/main_config.py
# miniconda/lib/python3.7/site-packages/conda_env/cli/main.py
# miniconda/lib/python3.7/site-packages/conda_env/cli/main_vars.py
# miniconda/lib/python3.7/site-packages/conda_env/exceptions.py
# miniconda/lib/python3.7/site-packages/conda_env/installers/
# miniconda/lib/python3.7/site-packages/conda_env/installers/__init__.py
# miniconda/lib/python3.7/site-packages/conda_env/installers/conda.py
# miniconda/lib/python3.7/site-packages/conda_env/installers/base.py
# miniconda/lib/python3.7/site-packages/conda_env/installers/__pycache__/
# miniconda/lib/python3.7/site-packages/conda_env/installers/__pycache__/pip.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/installers/__pycache__/conda.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/installers/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/installers/__pycache__/base.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/installers/pip.py
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/env.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/pip_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/exceptions.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/__pycache__/__main__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/
# miniconda/lib/python3.7/site-packages/conda_env/specs/__init__.py
# miniconda/lib/python3.7/site-packages/conda_env/specs/requirements.py
# miniconda/lib/python3.7/site-packages/conda_env/specs/binstar.py
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/notebook.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/binstar.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/requirements.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/__pycache__/yaml_file.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/conda_env/specs/yaml_file.py
# miniconda/lib/python3.7/site-packages/conda_env/specs/notebook.py
# miniconda/lib/python3.7/site-packages/conda_env/pip_util.py
# miniconda/lib/python3.7/site-packages/conda_env/env.py
# miniconda/lib/python3.7/site-packages/conda_env/compat.py
# miniconda/lib/python3.7/site-packages/conda_env/__main__.py
# miniconda/lib/python3.7/site-packages/pycparser/
# miniconda/lib/python3.7/site-packages/pycparser/c_generator.py
# miniconda/lib/python3.7/site-packages/pycparser/__init__.py
# miniconda/lib/python3.7/site-packages/pycparser/c_lexer.py
# miniconda/lib/python3.7/site-packages/pycparser/plyparser.py
# miniconda/lib/python3.7/site-packages/pycparser/yacctab.py
# miniconda/lib/python3.7/site-packages/pycparser/ast_transforms.py
# miniconda/lib/python3.7/site-packages/pycparser/c_parser.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/
# miniconda/lib/python3.7/site-packages/pycparser/ply/lex.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/__init__.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/ygen.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/ctokens.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/yacc.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/cpp.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/ygen.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/__pycache__/lex.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/ply/ctokens.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/cpp.py
# miniconda/lib/python3.7/site-packages/pycparser/ply/yacc.py
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/yacctab.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/_build_tables.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/c_parser.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/plyparser.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/c_ast.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/lextab.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/c_generator.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/_ast_gen.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/ast_transforms.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/__pycache__/c_lexer.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/pycparser/_build_tables.py
# miniconda/lib/python3.7/site-packages/pycparser/lextab.py
# miniconda/lib/python3.7/site-packages/pycparser/_ast_gen.py
# miniconda/lib/python3.7/site-packages/pycparser/_c_ast.cfg
# miniconda/lib/python3.7/site-packages/pycparser/c_ast.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__init__.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/scalarfloat.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/resolver.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/reader.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/anchor.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/parser.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/tokens.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/error.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/nodes.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/emitter.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/comments.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/constructor.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/cyaml.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/configobjwalker.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/util.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/representer.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/constructor.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/cyaml.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/error.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/timestamp.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/scalarint.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/configobjwalker.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/serializer.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/scalarbool.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/parser.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/composer.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/loader.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/events.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/main.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/scalarstring.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/emitter.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/scalarfloat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/dumper.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/anchor.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/reader.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/comments.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/scanner.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/resolver.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/tokens.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/__pycache__/nodes.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/composer.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/dumper.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/timestamp.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/events.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/main.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/ext/
# miniconda/lib/python3.7/site-packages/ruamel_yaml/ext/__init__.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/ext/_ruamel_yaml.cpython-37m-x86_64-linux-gnu.so
# miniconda/lib/python3.7/site-packages/ruamel_yaml/ext/__pycache__/
# miniconda/lib/python3.7/site-packages/ruamel_yaml/ext/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/ruamel_yaml/scalarstring.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/scanner.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/scalarint.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/representer.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/compat.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/scalarbool.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/loader.py
# miniconda/lib/python3.7/site-packages/ruamel_yaml/serializer.py
# miniconda/lib/python3.7/site-packages/setuptools/
# miniconda/lib/python3.7/site-packages/setuptools/depends.py
# miniconda/lib/python3.7/site-packages/setuptools/installer.py
# miniconda/lib/python3.7/site-packages/setuptools/launch.py
# miniconda/lib/python3.7/site-packages/setuptools/cli-32.exe
# miniconda/lib/python3.7/site-packages/setuptools/_reqs.py
# miniconda/lib/python3.7/site-packages/setuptools/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/windows_support.py
# miniconda/lib/python3.7/site-packages/setuptools/errors.py
# miniconda/lib/python3.7/site-packages/setuptools/gui-32.exe
# miniconda/lib/python3.7/site-packages/setuptools/script.tmpl
# miniconda/lib/python3.7/site-packages/setuptools/namespaces.py
# miniconda/lib/python3.7/site-packages/setuptools/_deprecation_warning.py
# miniconda/lib/python3.7/site-packages/setuptools/gui.exe
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/_types.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__pycache__/_types.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__pycache__/_parser.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/__pycache__/_re.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/_parser.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/tomli/_re.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/fastjsonschema_validations.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/formats.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/fastjsonschema_validations.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/extra_validations.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/error_reporting.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/formats.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/__pycache__/fastjsonschema_exceptions.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/fastjsonschema_exceptions.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/error_reporting.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/_validate_pyproject/extra_validations.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_meta.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_functools.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_adapters.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_itertools.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_collections.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_meta.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_adapters.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_functools.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_text.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/__pycache__/_itertools.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_text.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_collections.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_metadata/_compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/functools.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/context.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/text/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/text/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/text/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/text/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/__pycache__/context.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/jaraco/__pycache__/functools.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/ordered_set.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/typing_extensions.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/zipp.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/__pycache__/more.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/__pycache__/recipes.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/recipes.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/more_itertools/more.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/_adapters.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/readers.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/_itertools.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/abc.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/_common.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/simple.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/_common.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/_compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/_legacy.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/readers.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/_adapters.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/abc.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/_itertools.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/__pycache__/simple.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/_legacy.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/importlib_resources/_compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/ordered_set.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/pyparsing.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/typing_extensions.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/__pycache__/zipp.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/__pycache__/_compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/nspektr/_compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/pyparsing.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__about__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/_musllinux.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/version.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/requirements.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/_manylinux.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/utils.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/_musllinux.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/__about__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/requirements.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/_manylinux.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/markers.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/_structures.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/specifiers.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/tags.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/version.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/__pycache__/utils.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/markers.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/_structures.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/specifiers.py
# miniconda/lib/python3.7/site-packages/setuptools/_vendor/packaging/tags.py
# miniconda/lib/python3.7/site-packages/setuptools/cli-arm64.exe
# miniconda/lib/python3.7/site-packages/setuptools/gui-arm64.exe
# miniconda/lib/python3.7/site-packages/setuptools/monkey.py
# miniconda/lib/python3.7/site-packages/setuptools/logging.py
# miniconda/lib/python3.7/site-packages/setuptools/sandbox.py
# miniconda/lib/python3.7/site-packages/setuptools/_itertools.py
# miniconda/lib/python3.7/site-packages/setuptools/_importlib.py
# miniconda/lib/python3.7/site-packages/setuptools/version.py
# miniconda/lib/python3.7/site-packages/setuptools/script (dev).tmpl
# miniconda/lib/python3.7/site-packages/setuptools/msvc.py
# miniconda/lib/python3.7/site-packages/setuptools/extension.py
# miniconda/lib/python3.7/site-packages/setuptools/cli.exe
# miniconda/lib/python3.7/site-packages/setuptools/dep_util.py
# miniconda/lib/python3.7/site-packages/setuptools/archive_util.py
# miniconda/lib/python3.7/site-packages/setuptools/build_meta.py
# miniconda/lib/python3.7/site-packages/setuptools/unicode_utils.py
# miniconda/lib/python3.7/site-packages/setuptools/gui-64.exe
# miniconda/lib/python3.7/site-packages/setuptools/_path.py
# miniconda/lib/python3.7/site-packages/setuptools/extern/
# miniconda/lib/python3.7/site-packages/setuptools/extern/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/extern/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/extern/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/sandbox.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/wheel.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/launch.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/extension.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/monkey.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_importlib.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_entry_points.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/installer.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/dep_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/errors.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_path.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/unicode_utils.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/discovery.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/glob.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/msvc.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/depends.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/logging.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/build_meta.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_imp.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/dist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_deprecation_warning.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/archive_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/package_index.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/windows_support.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/namespaces.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_reqs.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/_itertools.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/version.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/__pycache__/py34compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_entry_points.py
# miniconda/lib/python3.7/site-packages/setuptools/package_index.py
# miniconda/lib/python3.7/site-packages/setuptools/config/
# miniconda/lib/python3.7/site-packages/setuptools/config/pyprojecttoml.py
# miniconda/lib/python3.7/site-packages/setuptools/config/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/config/expand.py
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/pyprojecttoml.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/expand.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/_apply_pyprojecttoml.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/config/__pycache__/setupcfg.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/config/_apply_pyprojecttoml.py
# miniconda/lib/python3.7/site-packages/setuptools/config/setupcfg.py
# miniconda/lib/python3.7/site-packages/setuptools/command/
# miniconda/lib/python3.7/site-packages/setuptools/command/install_lib.py
# miniconda/lib/python3.7/site-packages/setuptools/command/saveopts.py
# miniconda/lib/python3.7/site-packages/setuptools/command/develop.py
# miniconda/lib/python3.7/site-packages/setuptools/command/setopt.py
# miniconda/lib/python3.7/site-packages/setuptools/command/rotate.py
# miniconda/lib/python3.7/site-packages/setuptools/command/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/command/upload_docs.py
# miniconda/lib/python3.7/site-packages/setuptools/command/install_egg_info.py
# miniconda/lib/python3.7/site-packages/setuptools/command/test.py
# miniconda/lib/python3.7/site-packages/setuptools/command/install_scripts.py
# miniconda/lib/python3.7/site-packages/setuptools/command/build_clib.py
# miniconda/lib/python3.7/site-packages/setuptools/command/alias.py
# miniconda/lib/python3.7/site-packages/setuptools/command/easy_install.py
# miniconda/lib/python3.7/site-packages/setuptools/command/py36compat.py
# miniconda/lib/python3.7/site-packages/setuptools/command/bdist_egg.py
# miniconda/lib/python3.7/site-packages/setuptools/command/launcher manifest.xml
# miniconda/lib/python3.7/site-packages/setuptools/command/upload.py
# miniconda/lib/python3.7/site-packages/setuptools/command/bdist_rpm.py
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/install_lib.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/build_ext.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/rotate.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/setopt.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/dist_info.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/sdist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/py36compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/upload.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/install_scripts.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/install_egg_info.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/register.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/easy_install.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/egg_info.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/upload_docs.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/test.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/alias.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/develop.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/build_py.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/build_clib.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/bdist_egg.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/install.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/saveopts.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/__pycache__/bdist_rpm.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/command/dist_info.py
# miniconda/lib/python3.7/site-packages/setuptools/command/build_ext.py
# miniconda/lib/python3.7/site-packages/setuptools/command/build_py.py
# miniconda/lib/python3.7/site-packages/setuptools/command/sdist.py
# miniconda/lib/python3.7/site-packages/setuptools/command/egg_info.py
# miniconda/lib/python3.7/site-packages/setuptools/command/register.py
# miniconda/lib/python3.7/site-packages/setuptools/command/install.py
# miniconda/lib/python3.7/site-packages/setuptools/py34compat.py
# miniconda/lib/python3.7/site-packages/setuptools/discovery.py
# miniconda/lib/python3.7/site-packages/setuptools/_imp.py
# miniconda/lib/python3.7/site-packages/setuptools/glob.py
# miniconda/lib/python3.7/site-packages/setuptools/cli-64.exe
# miniconda/lib/python3.7/site-packages/setuptools/wheel.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/py38compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/py35compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/versionpredicate.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/errors.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/_macos_compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/msvc9compiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/sysconfig.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/text_file.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/spawn.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/file_util.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/version.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/cygwinccompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/extension.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/dep_util.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/archive_util.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/util.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/core.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/text_file.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/extension.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/cmd.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/msvc9compiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/file_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/_collections.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/spawn.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/filelist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/dep_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/errors.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/py38compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/py35compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/_macos_compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/_msvccompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/ccompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/msvccompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/unixccompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/fancy_getopt.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/cygwinccompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/dist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/archive_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/log.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/bcppcompiler.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/config.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/version.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/debug.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/sysconfig.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/versionpredicate.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/__pycache__/dir_util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/unixccompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/cmd.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/_msvccompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/ccompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/log.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/dir_util.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install_lib.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install_headers.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__init__.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install_data.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/bdist.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/bdist_msi.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/build_scripts.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install_egg_info.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install_scripts.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/check.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/build_clib.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/py37compat.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/upload.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/bdist_wininst.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/bdist_rpm.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install_lib.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/build_ext.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/clean.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/bdist_msi.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/sdist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/build.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/check.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/bdist_dumb.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/upload.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install_scripts.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install_egg_info.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/register.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install_data.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/py37compat.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install_headers.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/bdist.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/build_py.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/build_clib.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/bdist_wininst.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/config.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/install.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/bdist_rpm.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/__pycache__/build_scripts.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/build_ext.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/build_py.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/build.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/sdist.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/config.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/bdist_dumb.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/register.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/clean.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/command/install.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/_collections.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/fancy_getopt.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/config.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/filelist.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/core.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/bcppcompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/msvccompiler.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/debug.py
# miniconda/lib/python3.7/site-packages/setuptools/_distutils/dist.py
# miniconda/lib/python3.7/site-packages/setuptools/dist.py
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/WHEEL
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/REQUESTED
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/RECORD
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/direct_url.json
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/INSTALLER
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/METADATA
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/LICENSE
# miniconda/lib/python3.7/site-packages/requests-2.27.1.dist-info/top_level.txt
# miniconda/lib/python3.7/site-packages/test_pycosat.py
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/requires.txt
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/dependency_links.txt
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/entry_points.txt
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/SOURCES.txt
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/PKG-INFO
# miniconda/lib/python3.7/site-packages/setuptools-61.2.0-py3.7.egg-info/top_level.txt
# miniconda/lib/python3.7/site-packages/wheel/
# miniconda/lib/python3.7/site-packages/wheel/__init__.py
# miniconda/lib/python3.7/site-packages/wheel/vendored/
# miniconda/lib/python3.7/site-packages/wheel/vendored/__init__.py
# miniconda/lib/python3.7/site-packages/wheel/vendored/__pycache__/
# miniconda/lib/python3.7/site-packages/wheel/vendored/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/__init__.py
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/_typing.py
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/__pycache__/
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/__pycache__/_typing.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/__pycache__/tags.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/vendored/packaging/tags.py
# miniconda/lib/python3.7/site-packages/wheel/pkginfo.py
# miniconda/lib/python3.7/site-packages/wheel/bdist_wheel.py
# miniconda/lib/python3.7/site-packages/wheel/cli/
# miniconda/lib/python3.7/site-packages/wheel/cli/__init__.py
# miniconda/lib/python3.7/site-packages/wheel/cli/convert.py
# miniconda/lib/python3.7/site-packages/wheel/cli/pack.py
# miniconda/lib/python3.7/site-packages/wheel/cli/__pycache__/
# miniconda/lib/python3.7/site-packages/wheel/cli/__pycache__/convert.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/cli/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/cli/__pycache__/pack.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/cli/__pycache__/unpack.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/cli/unpack.py
# miniconda/lib/python3.7/site-packages/wheel/wheelfile.py
# miniconda/lib/python3.7/site-packages/wheel/metadata.py
# miniconda/lib/python3.7/site-packages/wheel/util.py
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/macosx_libfile.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/pkginfo.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/wheelfile.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/util.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/metadata.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/bdist_wheel.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__pycache__/__main__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/wheel/__main__.py
# miniconda/lib/python3.7/site-packages/wheel/macosx_libfile.py
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/WHEEL
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/REQUESTED
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/RECORD
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/entry_points.txt
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/direct_url.json
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/INSTALLER
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/METADATA
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/LICENSE
# miniconda/lib/python3.7/site-packages/cffi-1.15.0.dist-info/top_level.txt
# miniconda/lib/python3.7/site-packages/certifi/
# miniconda/lib/python3.7/site-packages/certifi/cacert.pem
# miniconda/lib/python3.7/site-packages/certifi/__init__.py
# miniconda/lib/python3.7/site-packages/certifi/__pycache__/
# miniconda/lib/python3.7/site-packages/certifi/__pycache__/core.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/certifi/__pycache__/__init__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/certifi/__pycache__/__main__.cpython-37.pyc
# miniconda/lib/python3.7/site-packages/certifi/core.py
# miniconda/lib/python3.7/site-packages/certifi/__main__.py
# miniconda/lib/python3.7/site-packages/brotli/
# miniconda/lib/python3.7/site-packages/brotli/__init__.py
# miniconda/lib/python3.7/site-packages/brotli/_brotli.abi3.so
# miniconda/lib/python3.7/site-packages/brotli/__pycache__/
# miniconda/lib/python3.7/site-packages/brotli/__pycache__/brotli.cpython-37.pyc
# ...
# miniconda/lib/tk8.6/focus.tcl
# miniconda/lib/tk8.6/tclIndex
# miniconda/lib/tk8.6/obsolete.tcl
# miniconda/lib/tk8.6/ttk/
# miniconda/lib/tk8.6/ttk/defaults.tcl
# miniconda/lib/tk8.6/ttk/classicTheme.tcl
# miniconda/lib/tk8.6/ttk/altTheme.tcl
# miniconda/lib/tk8.6/ttk/xpTheme.tcl
# miniconda/lib/tk8.6/ttk/progress.tcl
# miniconda/lib/tk8.6/ttk/vistaTheme.tcl
# miniconda/lib/tk8.6/ttk/treeview.tcl
# miniconda/lib/tk8.6/ttk/scrollbar.tcl
# miniconda/lib/tk8.6/ttk/winTheme.tcl
# miniconda/lib/tk8.6/ttk/aquaTheme.tcl
# miniconda/lib/tk8.6/ttk/clamTheme.tcl
# miniconda/lib/tk8.6/ttk/entry.tcl
# miniconda/lib/tk8.6/ttk/scale.tcl
# miniconda/lib/tk8.6/ttk/ttk.tcl
# miniconda/lib/tk8.6/ttk/combobox.tcl
# miniconda/lib/tk8.6/ttk/sizegrip.tcl
# miniconda/lib/tk8.6/ttk/utils.tcl
# miniconda/lib/tk8.6/ttk/notebook.tcl
# miniconda/lib/tk8.6/ttk/menubutton.tcl
# miniconda/lib/tk8.6/ttk/cursors.tcl
# miniconda/lib/tk8.6/ttk/button.tcl
# miniconda/lib/tk8.6/ttk/fonts.tcl
# miniconda/lib/tk8.6/ttk/panedwindow.tcl
# miniconda/lib/tk8.6/ttk/spinbox.tcl
# miniconda/lib/tk8.6/unsupported.tcl
# miniconda/lib/tk8.6/scrlbar.tcl
# miniconda/lib/tk8.6/fontchooser.tcl
# miniconda/lib/tk8.6/demos/
# miniconda/lib/tk8.6/demos/form.tcl
# miniconda/lib/tk8.6/demos/style.tcl
# miniconda/lib/tk8.6/demos/bind.tcl
# miniconda/lib/tk8.6/demos/dialog1.tcl
# miniconda/lib/tk8.6/demos/paned1.tcl
# miniconda/lib/tk8.6/demos/license.terms
# miniconda/lib/tk8.6/demos/images/
# miniconda/lib/tk8.6/demos/images/flagup.xbm
# miniconda/lib/tk8.6/demos/images/earth.gif
# miniconda/lib/tk8.6/demos/images/letters.xbm
# miniconda/lib/tk8.6/demos/images/gray25.xbm
# miniconda/lib/tk8.6/demos/images/earthris.gif
# miniconda/lib/tk8.6/demos/images/ouster.png
# miniconda/lib/tk8.6/demos/images/teapot.ppm
# miniconda/lib/tk8.6/demos/images/pattern.xbm
# miniconda/lib/tk8.6/demos/images/noletter.xbm
# miniconda/lib/tk8.6/demos/images/flagdown.xbm
# miniconda/lib/tk8.6/demos/images/tcllogo.gif
# miniconda/lib/tk8.6/demos/images/earthmenu.png
# miniconda/lib/tk8.6/demos/knightstour.tcl
# miniconda/lib/tk8.6/demos/ttknote.tcl
# miniconda/lib/tk8.6/demos/widget
# miniconda/lib/tk8.6/demos/twind.tcl
# miniconda/lib/tk8.6/demos/aniwave.tcl
# miniconda/lib/tk8.6/demos/floor.tcl
# miniconda/lib/tk8.6/demos/README
# miniconda/lib/tk8.6/demos/tclIndex
# miniconda/lib/tk8.6/demos/label.tcl
# miniconda/lib/tk8.6/demos/ctext.tcl
# miniconda/lib/tk8.6/demos/paned2.tcl
# miniconda/lib/tk8.6/demos/states.tcl
# miniconda/lib/tk8.6/demos/rolodex
# miniconda/lib/tk8.6/demos/labelframe.tcl
# miniconda/lib/tk8.6/demos/rmt
# miniconda/lib/tk8.6/demos/bitmap.tcl
# miniconda/lib/tk8.6/demos/anilabel.tcl
# miniconda/lib/tk8.6/demos/image1.tcl
# miniconda/lib/tk8.6/demos/ttkprogress.tcl
# miniconda/lib/tk8.6/demos/nl.msg
# miniconda/lib/tk8.6/demos/image2.tcl
# miniconda/lib/tk8.6/demos/hello
# miniconda/lib/tk8.6/demos/tcolor
# miniconda/lib/tk8.6/demos/entry1.tcl
# miniconda/lib/tk8.6/demos/tree.tcl
# miniconda/lib/tk8.6/demos/clrpick.tcl
# miniconda/lib/tk8.6/demos/textpeer.tcl
# miniconda/lib/tk8.6/demos/entry2.tcl
# miniconda/lib/tk8.6/demos/radio.tcl
# miniconda/lib/tk8.6/demos/check.tcl
# miniconda/lib/tk8.6/demos/entry3.tcl
# miniconda/lib/tk8.6/demos/puzzle.tcl
# miniconda/lib/tk8.6/demos/unicodeout.tcl
# miniconda/lib/tk8.6/demos/ixset
# miniconda/lib/tk8.6/demos/vscale.tcl
# miniconda/lib/tk8.6/demos/icon.tcl
# miniconda/lib/tk8.6/demos/dialog2.tcl
# miniconda/lib/tk8.6/demos/menu.tcl
# miniconda/lib/tk8.6/demos/menubu.tcl
# miniconda/lib/tk8.6/demos/en.msg
# miniconda/lib/tk8.6/demos/arrow.tcl
# miniconda/lib/tk8.6/demos/combo.tcl
# miniconda/lib/tk8.6/demos/goldberg.tcl
# miniconda/lib/tk8.6/demos/search.tcl
# miniconda/lib/tk8.6/demos/ruler.tcl
# miniconda/lib/tk8.6/demos/ttkmenu.tcl
# miniconda/lib/tk8.6/demos/hscale.tcl
# miniconda/lib/tk8.6/demos/timer
# miniconda/lib/tk8.6/demos/filebox.tcl
# miniconda/lib/tk8.6/demos/cscroll.tcl
# miniconda/lib/tk8.6/demos/browse
# miniconda/lib/tk8.6/demos/spin.tcl
# miniconda/lib/tk8.6/demos/sayings.tcl
# miniconda/lib/tk8.6/demos/ttkbut.tcl
# miniconda/lib/tk8.6/demos/msgbox.tcl
# miniconda/lib/tk8.6/demos/colors.tcl
# miniconda/lib/tk8.6/demos/text.tcl
# miniconda/lib/tk8.6/demos/plot.tcl
# miniconda/lib/tk8.6/demos/ttkscale.tcl
# miniconda/lib/tk8.6/demos/button.tcl
# miniconda/lib/tk8.6/demos/items.tcl
# miniconda/lib/tk8.6/demos/pendulum.tcl
# miniconda/lib/tk8.6/demos/fontchoose.tcl
# miniconda/lib/tk8.6/demos/toolbar.tcl
# miniconda/lib/tk8.6/demos/ttkpane.tcl
# miniconda/lib/tk8.6/demos/mclist.tcl
# miniconda/lib/tk8.6/palette.tcl
# miniconda/lib/tk8.6/clrpick.tcl
# miniconda/lib/tk8.6/optMenu.tcl
# miniconda/lib/tk8.6/listbox.tcl
# miniconda/lib/tk8.6/tk.tcl
# miniconda/lib/tk8.6/icons.tcl
# miniconda/lib/tk8.6/menu.tcl
# miniconda/lib/tk8.6/megawidget.tcl
# miniconda/lib/tk8.6/console.tcl
# miniconda/lib/tk8.6/tkfbox.tcl
# miniconda/lib/tk8.6/dialog.tcl
# miniconda/lib/tk8.6/entry.tcl
# miniconda/lib/tk8.6/scale.tcl
# miniconda/lib/tk8.6/iconlist.tcl
# miniconda/lib/tk8.6/mkpsenc.tcl
# miniconda/lib/tk8.6/msgbox.tcl
# miniconda/lib/tk8.6/tearoff.tcl
# miniconda/lib/tk8.6/text.tcl
# miniconda/lib/tk8.6/choosedir.tcl
# miniconda/lib/tk8.6/tkAppInit.c
# miniconda/lib/tk8.6/comdlg.tcl
# miniconda/lib/tk8.6/button.tcl
# miniconda/lib/tk8.6/msgs/
# miniconda/lib/tk8.6/msgs/hu.msg
# miniconda/lib/tk8.6/msgs/ru.msg
# miniconda/lib/tk8.6/msgs/en_gb.msg
# miniconda/lib/tk8.6/msgs/it.msg
# miniconda/lib/tk8.6/msgs/fr.msg
# miniconda/lib/tk8.6/msgs/el.msg
# miniconda/lib/tk8.6/msgs/nl.msg
# miniconda/lib/tk8.6/msgs/pt.msg
# miniconda/lib/tk8.6/msgs/pl.msg
# miniconda/lib/tk8.6/msgs/cs.msg
# miniconda/lib/tk8.6/msgs/sv.msg
# miniconda/lib/tk8.6/msgs/en.msg
# miniconda/lib/tk8.6/msgs/es.msg
# miniconda/lib/tk8.6/msgs/de.msg
# miniconda/lib/tk8.6/msgs/da.msg
# miniconda/lib/tk8.6/msgs/eo.msg
# miniconda/lib/tk8.6/panedwindow.tcl
# miniconda/lib/tk8.6/bgerror.tcl
# miniconda/lib/tk8.6/spinbox.tcl
# miniconda/lib/tk8.6/xmfbox.tcl
# miniconda/lib/libformw.so.6
# miniconda/lib/libasan.so.5
# miniconda/lib/libgomp.so.1
# miniconda/lib/libssl.so.1.1
# miniconda/lib/libitm.so.1
# miniconda/lib/libasan.so.5.0.0
# miniconda/lib/libgcc_s.so.1
# miniconda/lib/libatomic.so.1
# miniconda/lib/libpanel.so.6
# miniconda/lib/liblzma.so.5
# miniconda/lib/libasan.so
# miniconda/lib/libtclstub8.6.a
# miniconda/lib/libz.so.1
# miniconda/lib/liblzma.so
# miniconda/lib/libffi.so.7
# miniconda/lib/terminfo
# miniconda/lib/libhistory.so.8.1
# miniconda/lib/libquadmath.so.0
# miniconda/lib/libstdc++.so.6
# miniconda/lib/libreadline.so
# miniconda/lib/libssl.a
# miniconda/lib/tclConfig.sh
# miniconda/lib/libcrypto.so.1.1
# miniconda/lib/tclooConfig.sh
# miniconda/lib/libubsan.so.1
# miniconda/lib/libubsan.so.1.0.0
# miniconda/lib/libffi.a
# miniconda/lib/libstdc++.so
# miniconda/lib/libgomp.so
# miniconda/lib/libhistory.so.8
# miniconda/lib/libsqlite3.so.0.8.6
# miniconda/lib/libcrypto.so
# miniconda/lib/tcl8/
# miniconda/lib/tcl8/8.5/
# miniconda/lib/tcl8/8.5/tcltest-2.5.3.tm
# miniconda/lib/tcl8/8.5/msgcat-1.6.1.tm
# miniconda/lib/tcl8/8.4/
# miniconda/lib/tcl8/8.4/platform/
# miniconda/lib/tcl8/8.4/platform/shell-1.1.4.tm
# miniconda/lib/tcl8/8.4/platform-1.0.15.tm
# miniconda/lib/tcl8/8.6/
# miniconda/lib/tcl8/8.6/http-2.9.5.tm
# miniconda/lib/tcl8/8.6/tdbc/
# miniconda/lib/tcl8/8.6/tdbc/sqlite3-1.1.2.tm
# miniconda/lib/liblsan.so
# miniconda/lib/libtinfo.so
# miniconda/lib/libyaml-0.so.2
# miniconda/lib/libtinfow.so
# miniconda/lib/tcl8.6/
# miniconda/lib/tcl8.6/opt0.4/
# miniconda/lib/tcl8.6/opt0.4/pkgIndex.tcl
# miniconda/lib/tcl8.6/opt0.4/optparse.tcl
# miniconda/lib/tcl8.6/auto.tcl
# miniconda/lib/tcl8.6/tclIndex
# miniconda/lib/tcl8.6/init.tcl
# miniconda/lib/tcl8.6/package.tcl
# miniconda/lib/tcl8.6/clock.tcl
# miniconda/lib/tcl8.6/tm.tcl
# miniconda/lib/tcl8.6/encoding/
# miniconda/lib/tcl8.6/encoding/macUkraine.enc
# miniconda/lib/tcl8.6/encoding/jis0201.enc
# miniconda/lib/tcl8.6/encoding/iso8859-14.enc
# miniconda/lib/tcl8.6/encoding/cp737.enc
# miniconda/lib/tcl8.6/encoding/iso2022-kr.enc
# miniconda/lib/tcl8.6/encoding/cp932.enc
# miniconda/lib/tcl8.6/encoding/cp865.enc
# miniconda/lib/tcl8.6/encoding/cp1258.enc
# miniconda/lib/tcl8.6/encoding/cp936.enc
# miniconda/lib/tcl8.6/encoding/gb2312.enc
# miniconda/lib/tcl8.6/encoding/cp775.enc
# miniconda/lib/tcl8.6/encoding/macCroatian.enc
# miniconda/lib/tcl8.6/encoding/cp863.enc
# miniconda/lib/tcl8.6/encoding/tis-620.enc
# miniconda/lib/tcl8.6/encoding/ksc5601.enc
# miniconda/lib/tcl8.6/encoding/koi8-u.enc
# miniconda/lib/tcl8.6/encoding/gb2312-raw.enc
# miniconda/lib/tcl8.6/encoding/euc-jp.enc
# miniconda/lib/tcl8.6/encoding/iso2022-jp.enc
# miniconda/lib/tcl8.6/encoding/macCentEuro.enc
# miniconda/lib/tcl8.6/encoding/iso8859-7.enc
# miniconda/lib/tcl8.6/encoding/dingbats.enc
# miniconda/lib/tcl8.6/encoding/iso8859-1.enc
# miniconda/lib/tcl8.6/encoding/cp1250.enc
# miniconda/lib/tcl8.6/encoding/gb1988.enc
# miniconda/lib/tcl8.6/encoding/cp949.enc
# miniconda/lib/tcl8.6/encoding/macRomania.enc
# miniconda/lib/tcl8.6/encoding/cp437.enc
# miniconda/lib/tcl8.6/encoding/iso8859-16.enc
# miniconda/lib/tcl8.6/encoding/cp861.enc
# miniconda/lib/tcl8.6/encoding/macGreek.enc
# miniconda/lib/tcl8.6/encoding/cp1254.enc
# miniconda/lib/tcl8.6/encoding/euc-cn.enc
# miniconda/lib/tcl8.6/encoding/macDingbats.enc
# miniconda/lib/tcl8.6/encoding/big5.enc
# miniconda/lib/tcl8.6/encoding/iso8859-5.enc
# miniconda/lib/tcl8.6/encoding/jis0208.enc
# miniconda/lib/tcl8.6/encoding/iso8859-15.enc
# miniconda/lib/tcl8.6/encoding/cp1256.enc
# miniconda/lib/tcl8.6/encoding/cp1251.enc
# miniconda/lib/tcl8.6/encoding/iso2022.enc
# miniconda/lib/tcl8.6/encoding/cp855.enc
# miniconda/lib/tcl8.6/encoding/macRoman.enc
# miniconda/lib/tcl8.6/encoding/euc-kr.enc
# miniconda/lib/tcl8.6/encoding/koi8-r.enc
# miniconda/lib/tcl8.6/encoding/iso8859-9.enc
# miniconda/lib/tcl8.6/encoding/cp950.enc
# miniconda/lib/tcl8.6/encoding/cp1257.enc
# miniconda/lib/tcl8.6/encoding/macTurkish.enc
# miniconda/lib/tcl8.6/encoding/ebcdic.enc
# miniconda/lib/tcl8.6/encoding/cp857.enc
# miniconda/lib/tcl8.6/encoding/iso8859-2.enc
# miniconda/lib/tcl8.6/encoding/iso8859-13.enc
# miniconda/lib/tcl8.6/encoding/iso8859-3.enc
# miniconda/lib/tcl8.6/encoding/cp850.enc
# miniconda/lib/tcl8.6/encoding/cp1253.enc
# miniconda/lib/tcl8.6/encoding/iso8859-10.enc
# miniconda/lib/tcl8.6/encoding/gb12345.enc
# miniconda/lib/tcl8.6/encoding/symbol.enc
# miniconda/lib/tcl8.6/encoding/macCyrillic.enc
# miniconda/lib/tcl8.6/encoding/cp864.enc
# miniconda/lib/tcl8.6/encoding/iso8859-8.enc
# miniconda/lib/tcl8.6/encoding/cp866.enc
# miniconda/lib/tcl8.6/encoding/macJapan.enc
# miniconda/lib/tcl8.6/encoding/iso8859-6.enc
# miniconda/lib/tcl8.6/encoding/macIceland.enc
# miniconda/lib/tcl8.6/encoding/cp852.enc
# miniconda/lib/tcl8.6/encoding/cp1252.enc
# miniconda/lib/tcl8.6/encoding/shiftjis.enc
# miniconda/lib/tcl8.6/encoding/jis0212.enc
# miniconda/lib/tcl8.6/encoding/cp860.enc
# miniconda/lib/tcl8.6/encoding/cp874.enc
# miniconda/lib/tcl8.6/encoding/macThai.enc
# miniconda/lib/tcl8.6/encoding/cp869.enc
# miniconda/lib/tcl8.6/encoding/cp1255.enc
# miniconda/lib/tcl8.6/encoding/ascii.enc
# miniconda/lib/tcl8.6/encoding/cp862.enc
# miniconda/lib/tcl8.6/encoding/iso8859-4.enc
# miniconda/lib/tcl8.6/safe.tcl
# miniconda/lib/tcl8.6/tclAppInit.c
# miniconda/lib/tcl8.6/history.tcl
# miniconda/lib/tcl8.6/http1.0/
# miniconda/lib/tcl8.6/http1.0/pkgIndex.tcl
# miniconda/lib/tcl8.6/http1.0/http.tcl
# miniconda/lib/tcl8.6/parray.tcl
# miniconda/lib/tcl8.6/word.tcl
# miniconda/lib/tcl8.6/msgs/
# miniconda/lib/tcl8.6/msgs/en_hk.msg
# miniconda/lib/tcl8.6/msgs/eu.msg
# miniconda/lib/tcl8.6/msgs/es_bo.msg
# miniconda/lib/tcl8.6/msgs/hi.msg
# miniconda/lib/tcl8.6/msgs/bn_in.msg
# miniconda/lib/tcl8.6/msgs/kw_gb.msg
# miniconda/lib/tcl8.6/msgs/sl.msg
# miniconda/lib/tcl8.6/msgs/hu.msg
# miniconda/lib/tcl8.6/msgs/et.msg
# miniconda/lib/tcl8.6/msgs/sq.msg
# miniconda/lib/tcl8.6/msgs/es_cl.msg
# miniconda/lib/tcl8.6/msgs/es_hn.msg
# miniconda/lib/tcl8.6/msgs/zh.msg
# miniconda/lib/tcl8.6/msgs/fa_ir.msg
# miniconda/lib/tcl8.6/msgs/es_py.msg
# miniconda/lib/tcl8.6/msgs/ko_kr.msg
# miniconda/lib/tcl8.6/msgs/en_za.msg
# miniconda/lib/tcl8.6/msgs/kl.msg
# miniconda/lib/tcl8.6/msgs/it_ch.msg
# miniconda/lib/tcl8.6/msgs/en_sg.msg
# miniconda/lib/tcl8.6/msgs/ru.msg
# miniconda/lib/tcl8.6/msgs/mk.msg
# miniconda/lib/tcl8.6/msgs/kok.msg
# miniconda/lib/tcl8.6/msgs/ro.msg
# miniconda/lib/tcl8.6/msgs/es_cr.msg
# miniconda/lib/tcl8.6/msgs/en_gb.msg
# miniconda/lib/tcl8.6/msgs/zh_tw.msg
# miniconda/lib/tcl8.6/msgs/ta_in.msg
# miniconda/lib/tcl8.6/msgs/nb.msg
# miniconda/lib/tcl8.6/msgs/ms_my.msg
# miniconda/lib/tcl8.6/msgs/es_co.msg
# miniconda/lib/tcl8.6/msgs/es_ec.msg
# miniconda/lib/tcl8.6/msgs/it.msg
# miniconda/lib/tcl8.6/msgs/es_pe.msg
# miniconda/lib/tcl8.6/msgs/is.msg
# miniconda/lib/tcl8.6/msgs/be.msg
# miniconda/lib/tcl8.6/msgs/hr.msg
# miniconda/lib/tcl8.6/msgs/en_be.msg
# miniconda/lib/tcl8.6/msgs/fr.msg
# miniconda/lib/tcl8.6/msgs/vi.msg
# miniconda/lib/tcl8.6/msgs/nl_be.msg
# miniconda/lib/tcl8.6/msgs/te_in.msg
# miniconda/lib/tcl8.6/msgs/fo.msg
# miniconda/lib/tcl8.6/msgs/es_ni.msg
# miniconda/lib/tcl8.6/msgs/es_sv.msg
# miniconda/lib/tcl8.6/msgs/fi.msg
# miniconda/lib/tcl8.6/msgs/th.msg
# miniconda/lib/tcl8.6/msgs/ar.msg
# miniconda/lib/tcl8.6/msgs/kl_gl.msg
# miniconda/lib/tcl8.6/msgs/es_uy.msg
# miniconda/lib/tcl8.6/msgs/de_at.msg
# miniconda/lib/tcl8.6/msgs/kok_in.msg
# miniconda/lib/tcl8.6/msgs/bn.msg
# miniconda/lib/tcl8.6/msgs/gv_gb.msg
# miniconda/lib/tcl8.6/msgs/el.msg
# miniconda/lib/tcl8.6/msgs/bg.msg
# miniconda/lib/tcl8.6/msgs/sh.msg
# miniconda/lib/tcl8.6/msgs/fr_be.msg
# miniconda/lib/tcl8.6/msgs/fr_ca.msg
# miniconda/lib/tcl8.6/msgs/nl.msg
# miniconda/lib/tcl8.6/msgs/lt.msg
# miniconda/lib/tcl8.6/msgs/pt.msg
# miniconda/lib/tcl8.6/msgs/pl.msg
# miniconda/lib/tcl8.6/msgs/nn.msg
# miniconda/lib/tcl8.6/msgs/ar_lb.msg
# miniconda/lib/tcl8.6/msgs/af_za.msg
# miniconda/lib/tcl8.6/msgs/lv.msg
# miniconda/lib/tcl8.6/msgs/gl_es.msg
# miniconda/lib/tcl8.6/msgs/pt_br.msg
# miniconda/lib/tcl8.6/msgs/he.msg
# miniconda/lib/tcl8.6/msgs/cs.msg
# miniconda/lib/tcl8.6/msgs/gv.msg
# miniconda/lib/tcl8.6/msgs/ga.msg
# miniconda/lib/tcl8.6/msgs/id.msg
# miniconda/lib/tcl8.6/msgs/ms.msg
# miniconda/lib/tcl8.6/msgs/zh_sg.msg
# miniconda/lib/tcl8.6/msgs/es_pr.msg
# miniconda/lib/tcl8.6/msgs/gl.msg
# miniconda/lib/tcl8.6/msgs/sv.msg
# miniconda/lib/tcl8.6/msgs/hi_in.msg
# miniconda/lib/tcl8.6/msgs/en_ph.msg
# miniconda/lib/tcl8.6/msgs/tr.msg
# miniconda/lib/tcl8.6/msgs/en_ie.msg
# miniconda/lib/tcl8.6/msgs/af.msg
# miniconda/lib/tcl8.6/msgs/en_zw.msg
# miniconda/lib/tcl8.6/msgs/en_in.msg
# miniconda/lib/tcl8.6/msgs/es_mx.msg
# miniconda/lib/tcl8.6/msgs/mr.msg
# miniconda/lib/tcl8.6/msgs/es_gt.msg
# miniconda/lib/tcl8.6/msgs/ar_sy.msg
# miniconda/lib/tcl8.6/msgs/ga_ie.msg
# miniconda/lib/tcl8.6/msgs/eu_es.msg
# miniconda/lib/tcl8.6/msgs/en_nz.msg
# miniconda/lib/tcl8.6/msgs/sw.msg
# miniconda/lib/tcl8.6/msgs/es.msg
# miniconda/lib/tcl8.6/msgs/zh_hk.msg
# miniconda/lib/tcl8.6/msgs/zh_cn.msg
# miniconda/lib/tcl8.6/msgs/fa.msg
# miniconda/lib/tcl8.6/msgs/de.msg
# miniconda/lib/tcl8.6/msgs/fa_in.msg
# miniconda/lib/tcl8.6/msgs/fr_ch.msg
# miniconda/lib/tcl8.6/msgs/mt.msg
# miniconda/lib/tcl8.6/msgs/kw.msg
# miniconda/lib/tcl8.6/msgs/en_au.msg
# miniconda/lib/tcl8.6/msgs/es_ar.msg
# miniconda/lib/tcl8.6/msgs/de_be.msg
# miniconda/lib/tcl8.6/msgs/en_bw.msg
# miniconda/lib/tcl8.6/msgs/ja.msg
# miniconda/lib/tcl8.6/msgs/uk.msg
# miniconda/lib/tcl8.6/msgs/ko.msg
# miniconda/lib/tcl8.6/msgs/es_pa.msg
# miniconda/lib/tcl8.6/msgs/fo_fo.msg
# miniconda/lib/tcl8.6/msgs/sr.msg
# miniconda/lib/tcl8.6/msgs/ta.msg
# miniconda/lib/tcl8.6/msgs/ar_jo.msg
# miniconda/lib/tcl8.6/msgs/te.msg
# miniconda/lib/tcl8.6/msgs/ru_ua.msg
# miniconda/lib/tcl8.6/msgs/es_ve.msg
# miniconda/lib/tcl8.6/msgs/mr_in.msg
# miniconda/lib/tcl8.6/msgs/ar_in.msg
# miniconda/lib/tcl8.6/msgs/ca.msg
# miniconda/lib/tcl8.6/msgs/da.msg
# miniconda/lib/tcl8.6/msgs/es_do.msg
# miniconda/lib/tcl8.6/msgs/eo.msg
# miniconda/lib/tcl8.6/msgs/sk.msg
# miniconda/lib/tcl8.6/msgs/id_id.msg
# miniconda/lib/tcl8.6/msgs/en_ca.msg
# miniconda/lib/libmenuw.so.6.3
# miniconda/lib/libncursesw.so
# miniconda/lib/liblsan.so.0.0.0
# miniconda/lib/libtinfow.so.6.3
# miniconda/lib/libyaml-0.so.2.0.9
# miniconda/lib/libmenu.so.6
# miniconda/lib/tdbcpostgres1.1.2/
# miniconda/lib/tdbcpostgres1.1.2/pkgIndex.tcl
# miniconda/lib/tdbcpostgres1.1.2/tdbcpostgres.tcl
# miniconda/lib/tdbcpostgres1.1.2/libtdbcpostgres1.1.2.so
# miniconda/lib/sqlite3.34.0/
# miniconda/lib/sqlite3.34.0/pkgIndex.tcl
# miniconda/lib/sqlite3.34.0/libsqlite3.34.0.so
# miniconda/lib/libtinfo.so.6
# miniconda/lib/libform.a
# miniconda/lib/libpanel.a

# %%
# !tar -xvf /content/drive/MyDrive/FYP/uniprot_datasets -C /content
# Out:
# ChEBI-IDs_for_metal_binding.tsv
# NEG_clustered_rep_seq.fasta
# NEG_TRAIN.fasta
# POS_TRAIN.fasta
# POS_TRAIN_FULL.fasta
# POS_TRAIN_FULL.tsv
# POS_TRAIN.tsv
# filtered_combined.fasta
# trimed_combined.fasta

# %%
# !cat NEG_TRAIN.fasta	POS_TRAIN.fasta > combined.fasta

# %%
total_len = len(list(SeqIO.parse("combined.fasta", "fasta")))
print("Full data set size: ", total_len)
# Out:
# Full data set size:  195450

# %% [markdown]
# # Helper functions

# %%
def check_metal_per(seqs, metal, anno, metal_count_df):
  cnt = 0
  temp = anno.loc[anno['Accession'].isin(seqs)]
  temp1 = temp['ChEBI-ID'].value_counts().to_frame().reset_index()
  row = temp1[temp1['index'] == metal]['ChEBI-ID']
  cnt = 0 if len(row) == 0 else int(row)
  per = cnt / int(metal_count_df[metal_count_df['ChEBI-ID'] == metal]['count'])
  return per

# %%
def check_metal_num(seqs, metal, anno):
  cnt = 0
  temp = anno.loc[anno['Accession'].isin(seqs)]
  temp1 = temp['ChEBI-ID'].value_counts().to_frame().reset_index()
  row = temp1[temp1['index'] == metal]['ChEBI-ID']
  cnt = 0 if len(row) == 0 else int(row)
  return cnt

# %%
def check_metal_specific_residue_proportion(acc_ls, source = 'POS_TRAIN_FULL.tsv'):
  anno = pd.read_csv(source, sep='\t')
  metal_count_df = anno['ChEBI-ID'].value_counts().to_frame().reset_index()
  metal_count_df.columns = ['ChEBI-ID', 'count']
  metal_id_name_df = pd.read_csv('ChEBI-IDs_for_metal_binding.tsv', sep='\t')
  for metal in metal_count_df['ChEBI-ID'].unique():
    metal_name = metal_id_name_df[metal_id_name_df['ChEBI-ID']==metal]['Name'].iloc[0]
    num = check_metal_num(acc_ls, metal, anno) 
    total_num = int(metal_count_df[metal_count_df['ChEBI-ID'] == metal]['count'])
    print(f'{metal:12}| {metal_name:29} | num: {int(num):6} | %: {num/total_num}')

# %%
def write_seq_ls2fasta(file_out, ls, source):
  with open(file_out, 'w') as f_out:
    for seq_record in SeqIO.parse(source, "fasta"):
      seq_acc = seq_record.id.split('|')[1]
      if seq_acc in ls:
        r = SeqIO.write(seq_record, f_out, 'fasta')

        if r!=1: 
          print('Error while writing sequence: ' + seq_acc)
        else:
          print(f'writing {seq_acc} to train fasta file.')

# %%
def fasta2acc_seq_ls(path):
  acc = []
  seq = []

  for seq_record in SeqIO.parse(path, "fasta"):
    acc.append(seq_record.id.split('|')[1])
    seq.append(str(seq_record.seq))
  return acc, seq

# %%
def check_pos_neg_proportion(ls):
  total_num = len(ls)
  
  acc, _ = fasta2acc_seq_ls("POS_TRAIN_FULL.fasta")
  inter = set(acc).intersection(ls)
  pos_num = len(inter)
  neg_num = total_num - pos_num
  pos_portion = pos_num/total_num
  neg_portion = neg_num/total_num
  print(f'total seq in the set: {total_num}')
  print(f'proportion over full dataset: {total_num/total_len}')
  print(f'pos: {pos_num} %: {pos_portion}')
  print(f'neg: {neg_num} %: {neg_portion}')
  return total_num, pos_num, neg_num, pos_portion, neg_portion

# %%
def identity_above_threshold(m8file, thres):
  data = pd.read_csv(m8file, sep="\t", index_col=False, header=None)
  data.columns = ["query", "target","sequence identity","alignment length","mismatch","gap opening", "query domain start position", "end position","target domain start position", "end position", "evalue", "bit score"]
  
  seq_above_thres = data[data["sequence identity"] > thres]["query"].unique()
  seq_below_thres = data[~data["query"].isin(seq_above_thres)]["query"].unique()
  # print(data[data["sequence identity"] > thres]["sequence identity"].unique())
  all_seq = data["query"].unique()
  proportion = len(seq_above_thres) / len(all_seq)
  print(len(all_seq) == len(seq_above_thres) + len(seq_below_thres))
  return seq_above_thres, seq_below_thres, proportion

# %%
def read_fasta(fasta_path, split_char="|", id_field=1):
    '''
        Reads in fasta file containing multiple sequences.
        Split_char and id_field allow to control identifier extraction from header.
        E.g.: set split_char="|" and id_field=1 for SwissProt/UniProt Headers.
        Returns dictionary holding multiple sequences or only single 
        sequence, depending on input file.
    '''
    
    seqs = dict()
    with open( fasta_path, 'r' ) as fasta_f:
        for line in fasta_f:
            # get uniprot ID from header and create new entry
            if line.startswith('>'):
                uniprot_id = line.replace('>', '').strip().split(split_char)[id_field]
                # replace tokens that are mis-interpreted when loading h5
                uniprot_id = uniprot_id.replace("/","_").replace(".","_")
                seqs[ uniprot_id ] = ''
            else:
                # repl. all whie-space chars and join seqs spanning multiple lines, drop gaps and cast to upper-case
                seq= ''.join( line.split() ).upper().replace("-","")
                # repl. all non-standard AAs and map them to unknown/X
                seq = seq.replace('U','X').replace('Z','X').replace('O','X')
                seqs[ uniprot_id ] += seq 
    example_id=next(iter(seqs))
    print("Read {} sequences.".format(len(seqs)))
    print("Example:\n{}\n{}".format(example_id,seqs[example_id]))

    return seqs

# %%
def dataset_metal_binding_summary(acc_ls, source = 'POS_TRAIN_FULL.tsv'):
  total_num = len(acc_ls)
  print(f'total seq in the set: {total_num}')

  all_pos_acc_ls, _ = fasta2acc_seq_ls("POS_TRAIN_FULL.fasta")
  metals = {'CHEBI:29105':0,'CHEBI:18420':1,'CHEBI:49883':2,'CHEBI:29108':3,'CHEBI:29035':4,'CHEBI:60240':5,'CHEBI:24875':6,'CHEBI:190135':7,'CHEBI:23378':8,'CHEBI:29103':9,'CHEBI:49786':10,'CHEBI:29101':11,'CHEBI:29034':12,'CHEBI:30408':13,'CHEBI:29036':14,'CHEBI:29033':15,'CHEBI:21137':16,'CHEBI:49552':17,'CHEBI:48775':18,'CHEBI:48828':19,'CHEBI:21143':20,'CHEBI:25213':21,'CHEBI:47739':22,'CHEBI:16793':23,'CHEBI:177874':24,'CHEBI:60400':25,'CHEBI:49415':26,'CHEBI:60504':27,'CHEBI:49713':28}
  anno = pd.read_csv(source, sep='\t')
  metal_count_df = anno['ChEBI-ID'].value_counts().to_frame().reset_index()
  metal_count_df.columns = ['ChEBI-ID', 'count']
  metal_id_name_df = pd.read_csv('ChEBI-IDs_for_metal_binding.tsv', sep='\t')
  prot_counter = [0]*29 
  res_counter = [0]*29
  pos_acc = set(all_pos_acc_ls).intersection(acc_ls)
  for i, metal in enumerate(metals):
    metal_name = metal_id_name_df[metal_id_name_df['ChEBI-ID']==metal]['Name'].iloc[0]
    temp = anno[anno['ChEBI-ID'] == metal]
    prot_counter[i] += len(temp[temp['Accession'].isin(pos_acc)]['Accession'].unique())
    res_counter[i] += check_metal_num(acc_ls, metal, anno)
    total_res_num = int(metal_count_df[metal_count_df['ChEBI-ID'] == metal]['count'])
    print(f"{metal:13}|{metal_name:30}|#p: {prot_counter[i]:10}|#residue: {res_counter[i]:6}|%residue/all: {res_counter[i]/total_res_num:{5}.{3}}")
  print(f"#non-binding protein: {total_num-len(pos_acc)}")
  return prot_counter, res_counter

# %%
def retrieve_json(path):
  with open(path, 'r') as fp:
    data = json.load(fp)
  return data

# %% [markdown]
# # Clustering by MMSEQS

# %%
# %alias activate $HOME/miniconda/bin/activate

# %%
# %alias mmseqs $HOME/miniconda/pkgs/mmseqs2-14.7e284-pl5321hf1761c0_0/bin/mmseqs

# %%
activate tutorial

# %%
mmseqs
# Out:
# MMseqs2 (Many against Many sequence searching) is an open-source software suite for very fast,
# parallelized protein sequence searches and clustering of huge protein sequence data sets.
#
# Please cite: M. Steinegger and J. Soding. MMseqs2 enables sensitive protein sequence searching for the analysis of massive data sets. Nature Biotechnology, doi:10.1038/nbt.3988 (2017).
#
# MMseqs2 Version: 14.7e284
# © Martin Steinegger (martin.steinegger@snu.ac.kr)
#
# usage: mmseqs <command> [<args>]
#
# Easy workflows for plain text input/output
#   easy-search       	Sensitive homology search
#   easy-cluster      	Slower, sensitive clustering
#   easy-linclust     	Fast linear time cluster, less sensitive clustering
#   easy-taxonomy     	Taxonomic classification
#   easy-rbh          	Find reciprocal best hit
#
# Main workflows for database input/output
#   search            	Sensitive homology search
#   map               	Map nearly identical sequences
#   rbh               	Reciprocal best hit search
#   linclust          	Fast, less sensitive clustering
#   cluster           	Slower, sensitive clustering
#   clusterupdate     	Update previous clustering with new sequences
#   taxonomy          	Taxonomic classification
#
# Input database creation
#   databases         	List and download databases
#   createdb          	Convert FASTA/Q file(s) to a sequence DB
#   createindex       	Store precomputed index on disk to reduce search overhead
#   convertmsa        	Convert Stockholm/PFAM MSA file to a MSA DB
#   msa2profile       	Convert a MSA DB to a profile DB
#
# Format conversion for downstream processing
#   convertalis       	Convert alignment DB to BLAST-tab, SAM or custom format
#   createtsv         	Convert result DB to tab-separated flat file
#   convert2fasta     	Convert sequence DB to FASTA format
#   taxonomyreport    	Create a taxonomy report in Kraken or Krona format
#
# An extended list of all modules can be obtained by calling 'mmseqs -h'.
#
# Bash completion for modules and parameters can be installed by adding "source MMSEQS_HOME/util/bash-completion.sh" to your "$HOME/.bash_profile".
# Include the location of the MMseqs2 binary in your "$PATH" environment variable.

# %%
mmseqs easy-cluster
# Out:
# usage: mmseqs easy-cluster <i:fastaFile1[.gz|.bz2]> ... <i:fastaFileN[.gz|.bz2]> <o:clusterPrefix> <tmpDir> [options]
# options:
#  -c FLOAT                       List matches above this fraction of aligned (covered) residues (see --cov-mode) [0.800]
#  --cov-mode INT                 0: coverage of query and target
#                                 1: coverage of target
#                                 2: coverage of query
#                                 3: target seq. length has to be at least x% of query length
#                                 4: query seq. length has to be at least x% of target length
#                                 5: short seq. needs to be at least x% of the other seq. length [0]
#  --alignment-mode INT           How to compute the alignment:
#                                 0: automatic
#                                 1: only score and end_pos
#                                 2: also start_pos and cov
#                                 3: also seq.id
#                                 4: only ungapped alignment [3]
#  --alignment-output-mode INT    How to compute the alignment:
#                                 0: automatic
#                                 1: only score and end_pos
#                                 2: also start_pos and cov
#                                 3: also seq.id
#                                 4: only ungapped alignment
#                                 5: score only (output) cluster format [0]
#  -e DOUBLE                      List matches below this E-value (range 0.0-inf) [1.000E-03]
#  --min-seq-id FLOAT             List matches above this sequence identity (for clustering) (range 0.0-1.0) [0.000]
#  --min-aln-len INT              Minimum alignment length (range 0-INT_MAX) [0]
#  --seq-id-mode INT              0: alignment length 1: shorter, 2: longer sequence [0]
#
#  --cluster-mode INT             0: Set-Cover (greedy)
#                                 1: Connected component (BLASTclust)
#                                 2,3: Greedy clustering by sequence length (CDHIT) [0]
#  --single-step-clustering BOOL  Switch from cascaded to simple clustering workflow [0]
#  --cluster-reassign BOOL        Cascaded clustering can cluster sequence that do not fulfill the clustering criteria.
#                                 Cluster reassignment corrects these errors [0]
#
#  --kmer-per-seq-scale TWIN      Scale k-mer per sequence based on sequence length as kmer-per-seq val + scale x seqlen [aa:0.000,nucl:0.200]
#
#  --taxon-list STR               Taxonomy ID, possibly multiple values separated by ',' []
#
#  --threads INT                  Number of CPU-cores used (all by default) [2]
#  --compressed INT               Write compressed output [0]
#  -v INT                         Verbosity level: 0: quiet, 1: +errors, 2: +warnings, 3: +info [3]
#
# examples:
#  mmseqs easy-cluster examples/DB.fasta result tmp
#  # Cluster output
#  #  - result_rep_seq.fasta: Representatives
#  #  - result_all_seq.fasta: FASTA-like per cluster
#  #  - result_cluster.tsv:   Adjacency list
#
#  # Important parameter: --min-seq-id, --cov-mode and -c
#  #                  --cov-mode
#  #                  0    1    2
#  # Q: MAVGTACRPA  60%  IGN  60%
#  # T: -AVGTAC---  60% 100%  IGN
#  #        -c 0.7    -    +    -
#  #        -c 0.6    +    +    +
#
#  # Cascaded clustering with reassignment
#  # - Corrects criteria-violations of cascaded merging
#  # - Produces more clusters and is a bit slower
#  mmseqs easy-cluster examples/DB.fasta result tmp --cluster-reassign
#
# references:
#  - Steinegger M, Soding J: MMseqs2 enables sensitive protein sequence searching for the analysis of massive data sets. Nature Biotechnology, 35(11), 1026-1028 (2017)
#  - Steinegger M, Soding J: Clustering huge protein sequence sets in linear time. Nature Communications, 9(1), 2542 (2018)
#
# Show an extended list of options by calling 'mmseqs easy-cluster -h'.
# Not enough input paths provided. 3 paths are required.

# %%
mmseqs easy-cluster combined.fasta assembly_clustered tmp --cov-mode 5 -c 0.25 --min-seq-id 0.4 -s 7
# Out:
# Create directory tmp
# easy-cluster combined.fasta assembly_clustered tmp --cov-mode 5 -c 0.25 --min-seq-id 0.4 -s 7
#
# MMseqs Version:                     	14.7e284
# Substitution matrix                 	aa:blosum62.out,nucl:nucleotide.out
# Seed substitution matrix            	aa:VTML80.out,nucl:nucleotide.out
# Sensitivity                         	7
# k-mer length                        	0
# k-score                             	seq:2147483647,prof:2147483647
# Alphabet size                       	aa:21,nucl:5
# Max sequence length                 	65535
# Max results per query               	20
# Split database                      	0
# Split mode                          	2
# Split memory limit                  	0
# Coverage threshold                  	0.25
# Coverage mode                       	5
# Compositional bias                  	1
# Compositional bias                  	1
# Diagonal scoring                    	true
# Exact k-mer matching                	0
# Mask residues                       	1
# Mask residues probability           	0.9
# Mask lower case residues            	0
# Minimum diagonal score              	15
# Selected taxa
# Include identical seq. id.          	false
# Spaced k-mers                       	1
# Preload mode                        	0
# Pseudo count a                      	substitution:1.100,context:1.400
# Pseudo count b                      	substitution:4.100,context:5.800
# Spaced k-mer pattern
# Local temporary path
# Threads                             	2
# Compressed                          	0
# Verbosity                           	3
# Add backtrace                       	false
# Alignment mode                      	3
# Alignment mode                      	0
# Allow wrapped scoring               	false
# E-value threshold                   	0.001
# Seq. id. threshold                  	0.4
# Min alignment length                	0
# Seq. id. mode                       	0
# Alternative alignments              	0
# Max reject                          	2147483647
# Max accept                          	2147483647
# Score bias                          	0
# Realign hits                        	false
# Realign score bias                  	-0.2
# Realign max seqs                    	2147483647
# Correlation score weight            	0
# Gap open cost                       	aa:11,nucl:5
# Gap extension cost                  	aa:1,nucl:2
# Zdrop                               	40
# Rescore mode                        	0
# Remove hits by seq. id. and coverage	false
# Sort results                        	0
# Cluster mode                        	0
# Max connected component depth       	1000
# Similarity type                     	2
# Single step clustering              	false
# Cascaded clustering steps           	3
# Cluster reassign                    	false
# Remove temporary files              	true
# Force restart with latest tmp       	false
# MPI runner
# k-mers per sequence                 	21
# Scale k-mers per sequence           	aa:0.000,nucl:0.200
# Adjust k-mer length                 	false
# Shift hash                          	67
# Include only extendable             	false
# Skip repeating k-mers               	false
# Database type                       	0
# Shuffle input database              	true
# Createdb mode                       	1
# Write lookup file                   	0
# Offset of numeric ids               	0
#
# createdb combined.fasta tmp/9744998586962423055/input --dbtype 0 --shuffle 1 --createdb-mode 1 --write-lookup 0 --id-offset 0 --compressed 0 -v 3
#
# Shuffle database cannot be combined with --createdb-mode 0
# We recompute with --shuffle 0
# Converting sequences
# Multiline fasta can not be combined with --createdb-mode 0
# We recompute with --createdb-mode 1
# Time for merging to input_h: 0h 0m 0s 0ms
# Time for merging to input: 0h 0m 0s 0ms
# [195436] 0s 457ms
# Time for merging to input_h: 0h 0m 0s 35ms
# Time for merging to input: 0h 0m 0s 90ms
# Database type: Aminoacid
# Time for processing: 0h 0m 0s 637ms
# Create directory tmp/9744998586962423055/clu_tmp
# cluster tmp/9744998586962423055/input tmp/9744998586962423055/clu tmp/9744998586962423055/clu_tmp -s 7 --max-seqs 20 -c 0.25 --cov-mode 5 --spaced-kmer-mode 1 --alignment-mode 3 -e 0.001 --min-seq-id 0.4 --remove-tmp-files 1
#
# Set cluster mode SET COVER
# Set cluster iterations to 3
# linclust tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.25 --cov-mode 5 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --alph-size aa:13,nucl:5 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 -k 0 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --rescore-mode 0 --filter-hits 0 --sort-results 0 --remove-tmp-files 1 --force-reuse 0
#
# kmermatcher tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.4 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 5 -k 0 -c 0.25 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3
#
# kmermatcher tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --alph-size aa:13,nucl:5 --min-seq-id 0.4 --kmer-per-seq 21 --spaced-kmer-mode 1 --kmer-per-seq-scale aa:0.000,nucl:0.200 --adjust-kmer-len 0 --mask 0 --mask-prob 0.9 --mask-lower-case 0 --cov-mode 5 -k 0 -c 0.25 --max-seq-len 65535 --hash-shift 67 --split-memory-limit 0 --include-only-extendable 0 --ignore-multi-kmer 0 --threads 2 --compressed 0 -v 3
#
# Database size: 195450 type: Aminoacid
# Reduced amino acid alphabet: (A S T) (C) (D B N) (E Q Z) (F Y) (G) (H) (I V) (K R) (L J M) (P) (W) (X)
#
# Generate k-mers list for 1 split
# [=================================================================] 100.00% 195.45K 2s 889ms
# Sort kmer 0h 0m 0s 672ms
# Sort by rep. sequence 0h 0m 0s 294ms
# Time for fill: 0h 0m 0s 57ms
# Time for merging to pref: 0h 0m 0s 0ms
# Time for processing: 0h 0m 4s 70ms
# rescorediagonal tmp/9744998586962423055/input tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 0 --wrapped-scoring 0 --filter-hits 0 -e 0.001 -c 0.5 -a 0 --cov-mode 5 --min-seq-id 0.5 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 195.45K 0s 457ms
# Time for merging to pref_rescore1: 0h 0m 0s 55ms
# Time for processing: 0h 0m 0s 589ms
# clust tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore1 tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pre_clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 195.45K 0s 172ms
# Sort entries
# Find missing connections
# Found 316509 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 195.45K 0s 315ms
# Add missing connections
# [=================================================================] 100.00% 195.45K 0s 43ms
#
# Time for read in: 0h 0m 0s 607ms
# Total time: 0h 0m 0s 737ms
#
# Size of the sequence database: 195450
# Size of the alignment database: 195450
# Number of clusters: 86735
#
# Writing results 0h 0m 0s 28ms
# Time for merging to pre_clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 821ms
# createsubdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/order_redundancy tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 53ms
# createsubdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/order_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter1 -v 3 --subdb-mode 1
#
# Time for merging to pref_filter1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 150ms
# filterdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter1 tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter2 --filter-file tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/order_redundancy --threads 2 --compressed 0 -v 3
#
# Filtering using file(s)
# [=================================================================] 100.00% 86.74K 0s 236ms
# Time for merging to pref_filter2: 0h 0m 0s 92ms
# Time for processing: 0h 0m 0s 568ms
# rescorediagonal tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter2 tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --rescore-mode 1 --wrapped-scoring 0 --filter-hits 1 -e 0.001 -c 0.25 -a 0 --cov-mode 5 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --add-self-matches 0 --sort-results 0 --db-load-mode 0 --threads 2 --compressed 0 -v 3
#
# [=================================================================] 100.00% 86.74K 0s 688ms
# Time for merging to pref_rescore2: 0h 0m 0s 120ms
# Time for processing: 0h 0m 1s 105ms
# align tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore2 tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/aln --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.25 --cov-mode 5 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 86735 type: Aminoacid
# Target database size: 86735 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 86.74K 1m 22s 354ms
# Time for merging to aln: 0h 0m 0s 29ms
# 138724 alignments calculated
# 131148 sequence pairs passed the thresholds (0.945388 of overall calculated)
# 1.512054 hits per query sequence
# Time for processing: 0h 1m 22s 509ms
# clust tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/aln tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/clust --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 86.74K 0s 47ms
# Sort entries
# Find missing connections
# Found 44413 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 86.74K 0s 112ms
# Add missing connections
# [=================================================================] 100.00% 86.74K 0s 6ms
#
# Time for read in: 0h 0m 0s 195ms
# Total time: 0h 0m 0s 216ms
#
# Size of the sequence database: 86735
# Size of the alignment database: 86735
# Number of clusters: 61304
#
# Writing results 0h 0m 0s 13ms
# Time for merging to clust: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 253ms
# mergeclusters tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pre_clust tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/clust --threads 2 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 86.74K 0s 46ms
# Clustering step 2
# [=================================================================] 100.00% 61.30K 0s 142ms
# Write merged clustering
# [=================================================================] 100.00% 195.45K 0s 236ms
# Time for merging to clu_redundancy: 0h 0m 0s 20ms
# Time for processing: 0h 0m 0s 293ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pre_clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_filter2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/pref_rescore2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/aln -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/linclust/2575301786481264389/clust -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createsubdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_redundancy tmp/9744998586962423055/input tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy -v 3 --subdb-mode 1
#
# Time for merging to input_step_redundancy: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 32ms
# prefilter tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 1 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.25 --cov-mode 5 --comp-bias-corr 0 --comp-bias-corr-scale 1 --diag-score 0 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 0 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 61304 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 61304 type: Aminoacid
# Index table k-mer threshold: 154 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 61.30K 6s 167ms
# Index table: Masked residues: 748335
# Index table: fill
# [=================================================================] 100.00% 61.30K 6s 412ms
# Index statistics
# Entries:          12815327
# DB size:          561 MB
# Avg k-mer size:   0.200239
# Top 10 k-mers
#     IHDKNI	208
#     GPGGTL	154
#     LGGFVY	123
#     IGGFVY	85
#     HSGIAY	75
#     GRDQIR	66
#     IHDKNV	66
#     GGDCDS	58
#     EKDYGV	55
#     DVSGLW	51
# Time for index table init: 0h 0m 13s 801ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 154
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 61304
# Target db start 1 to 61304
# [=================================================================] 100.00% 61.30K 8s 694ms
#
# 2.049645 k-mers per position
# 490 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 6 sequences passed prefiltering per query sequence
# 4 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step0: 0h 0m 0s 17ms
# Time for processing: 0h 0m 27s 262ms
# align tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step0 tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step0 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.25 --cov-mode 5 --max-seq-len 65535 --comp-bias-corr 0 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 61304 type: Aminoacid
# Target database size: 61304 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 61.30K 9m 21s 981ms
# Time for merging to aln_step0: 0h 0m 0s 107ms
# 382490 alignments calculated
# 194836 sequence pairs passed the thresholds (0.509389 of overall calculated)
# 3.178194 hits per query sequence
# Time for processing: 0h 9m 22s 164ms
# clust tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step0 tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step0 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 61.30K 0s 102ms
# Sort entries
# Find missing connections
# Found 12218 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 61.30K 0s 158ms
# Add missing connections
# [=================================================================] 100.00% 61.30K 0s 20ms
#
# Time for read in: 0h 0m 0s 387ms
# Total time: 0h 0m 0s 452ms
#
# Size of the sequence database: 61304
# Size of the alignment database: 61304
# Number of clusters: 39767
#
# Writing results 0h 0m 0s 29ms
# Time for merging to clu_step0: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 586ms
# createsubdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step0 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 -v 3 --subdb-mode 1
#
# Time for merging to input_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 19ms
# prefilter tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 4 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.25 --cov-mode 5 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 39767 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 39767 type: Aminoacid
# Index table k-mer threshold: 127 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 39.77K 5s 561ms
# Index table: Masked residues: 518276
# Index table: fill
# [=================================================================] 100.00% 39.77K 4s 639ms
# Index statistics
# Entries:          17746385
# DB size:          589 MB
# Avg k-mer size:   0.277287
# Top 10 k-mers
#     TSSGKG	111
#     IHDKNI	89
#     FTGTPK	88
#     YTGTPK	79
#     GPGGTL	75
#     SSPSSS	46
#     PSSSSS	40
#     SGTKGV	38
#     RGREEV	36
#     IGGFVY	36
# Time for index table init: 0h 0m 11s 497ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 127
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 39767
# Target db start 1 to 39767
# [=================================================================] 100.00% 39.77K 1m 20s 740ms
#
# 56.447299 k-mers per position
# 5981 DB matches per sequence
# 0 overflows
# 0 queries produce too many hits (truncated result)
# 16 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step1: 0h 0m 0s 12ms
# Time for processing: 0h 1m 37s 152ms
# align tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step1 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.25 --cov-mode 5 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 39767 type: Aminoacid
# Target database size: 39767 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 39.77K 5m 14s 303ms
# Time for merging to aln_step1: 0h 0m 0s 12ms
# 549757 alignments calculated
# 55046 sequence pairs passed the thresholds (0.100128 of overall calculated)
# 1.384213 hits per query sequence
# Time for processing: 0h 5m 14s 342ms
# clust tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step1 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 39.77K 0s 96ms
# Sort entries
# Find missing connections
# Found 2755 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 39.77K 0s 107ms
# Add missing connections
# [=================================================================] 100.00% 39.77K 0s 3ms
#
# Time for read in: 0h 0m 0s 220ms
# Total time: 0h 0m 0s 230ms
#
# Size of the sequence database: 39767
# Size of the alignment database: 39767
# Number of clusters: 34103
#
# Writing results 0h 0m 0s 7ms
# Time for merging to clu_step1: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 249ms
# createsubdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 -v 3 --subdb-mode 1
#
# Time for merging to input_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 10ms
# prefilter tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' --seed-sub-mat 'aa:VTML80.out,nucl:nucleotide.out' -s 7 -k 0 --k-score seq:2147483647,prof:2147483647 --alph-size aa:21,nucl:5 --max-seq-len 65535 --max-seqs 20 --split 0 --split-mode 2 --split-memory-limit 0 -c 0.25 --cov-mode 5 --comp-bias-corr 1 --comp-bias-corr-scale 1 --diag-score 1 --exact-kmer-matching 0 --mask 1 --mask-prob 0.9 --mask-lower-case 0 --min-ungapped-score 15 --add-self-matches 0 --spaced-kmer-mode 1 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --threads 2 --compressed 0 -v 3
#
# Query database size: 34103 type: Aminoacid
# Estimated memory consumption: 1G
# Target database size: 34103 type: Aminoacid
# Index table k-mer threshold: 100 at k-mer size 6
# Index table: counting k-mers
# [=================================================================] 100.00% 34.10K 4s 132ms
# Index table: Masked residues: 420915
# Index table: fill
# [=================================================================] 100.00% 34.10K 5s 876ms
# Index statistics
# Entries:          15641527
# DB size:          577 MB
# Avg k-mer size:   0.244399
# Top 10 k-mers
#     TSSGKG	108
#     FTGTPK	85
#     SSSSSS	79
#     GPGGTL	59
#     SSSSSL	40
#     GRDQIR	39
#     SSPSSS	38
#     SGTKGV	37
#     RGREEV	35
#     SGTTGV	34
# Time for index table init: 0h 0m 11s 528ms
# Process prefiltering step 1 of 1
#
# k-mer similarity threshold: 100
# Starting prefiltering scores calculation (step 1 of 1)
# Query db start 1 to 34103
# Target db start 1 to 34103
# [=================================================================] 100.00% 34.10K 14m 27s 724ms
#
# 993.214376 k-mers per position
# 111797 DB matches per sequence
# 12 overflows
# 0 queries produce too many hits (truncated result)
# 19 sequences passed prefiltering per query sequence
# 20 median result list length
# 0 sequences with 0 size result lists
# Time for merging to pref_step2: 0h 0m 0s 74ms
# Time for processing: 0h 14m 45s 265ms
# align tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step2 --sub-mat 'aa:blosum62.out,nucl:nucleotide.out' -a 0 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 0.001 --min-seq-id 0.4 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0.25 --cov-mode 5 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 1 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:11,nucl:5 --gap-extend aa:1,nucl:2 --zdrop 40 --threads 2 --compressed 0 -v 3
#
# Compute score, coverage and sequence identity
# Query database size: 34103 type: Aminoacid
# Target database size: 34103 type: Aminoacid
# Calculation of alignments
# [=================================================================] 100.00% 34.10K 4m 54s 41ms
# Time for merging to aln_step2: 0h 0m 0s 10ms
# 529981 alignments calculated
# 35929 sequence pairs passed the thresholds (0.067793 of overall calculated)
# 1.053544 hits per query sequence
# Time for processing: 0h 4m 54s 160ms
# clust tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step2 tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step2 --cluster-mode 0 --max-iterations 1000 --similarity-type 2 --threads 2 --compressed 0 -v 3
#
# Clustering mode: Set Cover
# [=================================================================] 100.00% 34.10K 0s 93ms
# Sort entries
# Find missing connections
# Found 574 new connections.
# Reconstruct initial order
# [=================================================================] 100.00% 34.10K 0s 111ms
# Add missing connections
# [=================================================================] 100.00% 34.10K 0s 1ms
#
# Time for read in: 0h 0m 0s 220ms
# Total time: 0h 0m 0s 226ms
#
# Size of the sequence database: 34103
# Size of the alignment database: 34103
# Number of clusters: 33071
#
# Writing results 0h 0m 0s 6ms
# Time for merging to clu_step2: 0h 0m 0s 0ms
# Time for processing: 0h 0m 0s 243ms
# mergeclusters tmp/9744998586962423055/input tmp/9744998586962423055/clu tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_redundancy tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step0 tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step1 tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step2 --threads 2 --compressed 0 -v 3
#
# Clustering step 1
# [=================================================================] 100.00% 61.30K 0s 62ms
# Clustering step 2
# [=================================================================] 100.00% 39.77K 0s 164ms
# Clustering step 3
# [=================================================================] 100.00% 34.10K 0s 243ms
# Clustering step 4
# [=================================================================] 100.00% 33.07K 0s 352ms
# Write merged clustering
# [=================================================================] 100.00% 195.45K 0s 446ms
# Time for merging to clu: 0h 0m 0s 10ms
# Time for processing: 0h 0m 0s 503ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step_redundancy_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step0 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step0 -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step0 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step1 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/pref_step2 -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/aln_step2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/clu_step2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step1_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2 -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/9744998586962423055/clu_tmp/1195587908146683084/input_step2_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# createtsv tmp/9744998586962423055/input tmp/9744998586962423055/input tmp/9744998586962423055/clu tmp/9744998586962423055/cluster.tsv --threads 2 -v 3
#
# Time for merging to cluster.tsv: 0h 0m 0s 15ms
# Time for processing: 0h 0m 0s 193ms
# result2repseq tmp/9744998586962423055/input tmp/9744998586962423055/clu tmp/9744998586962423055/clu_rep --db-load-mode 0 --compressed 0 --threads 2 -v 3
#
# [=================================================================] 100.00% 33.07K 0s 25ms
# Time for merging to clu_rep: 0h 0m 0s 33ms
# Time for processing: 0h 0m 0s 121ms
# result2flat tmp/9744998586962423055/input tmp/9744998586962423055/input tmp/9744998586962423055/clu_rep tmp/9744998586962423055/rep_seq.fasta --use-fasta-header -v 3
#
# Time for processing: 0h 0m 0s 129ms
# createseqfiledb tmp/9744998586962423055/input tmp/9744998586962423055/clu tmp/9744998586962423055/clu_seqs --threads 2 -v 3
#
# [=================================================================] 100.00% 33.07K 0s 264ms
# Time for merging to clu_seqs: 0h 0m 0s 65ms
# Time for processing: 0h 0m 0s 576ms
# result2flat tmp/9744998586962423055/input tmp/9744998586962423055/input tmp/9744998586962423055/clu_seqs tmp/9744998586962423055/all_seqs.fasta -v 3
#
# Time for processing: 0h 0m 0s 709ms
# rmdb tmp/9744998586962423055/input -v 3
#
# Time for processing: 0h 0m 0s 15ms
# rmdb tmp/9744998586962423055/input_h -v 3
#
# Time for processing: 0h 0m 0s 4ms
# rmdb tmp/9744998586962423055/clu_seqs -v 3
#
# Time for processing: 0h 0m 0s 19ms
# rmdb tmp/9744998586962423055/clu_rep -v 3
#
# Time for processing: 0h 0m 0s 3ms
# rmdb tmp/9744998586962423055/clu -v 3
#
# Time for processing: 0h 0m 0s 0ms

# %% [markdown]
# # Reading data

# %% [markdown]
# ## reading dataset and annotations

# %% [markdown]
# acc: protein accessions in combined.fasta

# %%
acc, _ = fasta2acc_seq_ls("combined.fasta")

# %% [markdown]
# anno: the annotation dataframe POS_TRAIN_FULL.tsv

# %%
anno = pd.read_csv('POS_TRAIN.tsv', sep='\t')
anno
# Out:
#       Accession     Evidence     ChEBI-ID  Position
# 0        Q8INK9  ECO:0000269  CHEBI:29105       157
# 1        Q8INK9  ECO:0000269  CHEBI:29105        96
# 2        Q1QT89  ECO:0000269  CHEBI:18420       263
# 3        P07327  ECO:0000269  CHEBI:29105       101
# 4        P07327  ECO:0007744  CHEBI:29105       104
# ...         ...          ...          ...       ...
# 18038    P62339  ECO:0000269  CHEBI:60240        43
# 18039    P62339  ECO:0000269  CHEBI:60240        23
# 18040    P62339  ECO:0007744  CHEBI:60240        32
# 18041    P62339  ECO:0000269  CHEBI:60240        40
# 18042    P62339  ECO:0000269  CHEBI:60240         4
#
# [18043 rows x 4 columns]

# %% [markdown]
# metal_count_df: metal and the number of residues binding that metal from POS_TRAIN_FULL

# %%
metal_count_df = anno['ChEBI-ID'].value_counts().to_frame().reset_index()
metal_count_df.columns = ['ChEBI-ID', 'count']
metal_count_df
# Out:
#         ChEBI-ID  count
# 0    CHEBI:29105   5788
# 1    CHEBI:29108   4768
# 2    CHEBI:18420   2140
# 3    CHEBI:29035   1136
# 4    CHEBI:24875    919
# 5    CHEBI:49883    885
# 6    CHEBI:60240    738
# 7    CHEBI:23378    561
# 8   CHEBI:190135    348
# 9    CHEBI:29103    163
# 10   CHEBI:29101    142
# 11   CHEBI:29034    136
# 12   CHEBI:49786     77
# 13   CHEBI:48828     50
# 14   CHEBI:48775     50
# 15   CHEBI:21137     36
# 16   CHEBI:29036     33
# 17   CHEBI:49552     27
# 18   CHEBI:29033     22
# 19   CHEBI:47739     12
# 20  CHEBI:177874      6
# 21   CHEBI:49415      4
# 22   CHEBI:16793      2

# %%
class_enc = retrieve_json('/content/drive/MyDrive/FYP/dicts/class_encode.json')

# %%
temp_cnt = []
for i in metal_count_df['ChEBI-ID']:
  temp_cnt.append(check_metal_num(acc, i, anno))
metal_count_df = pd.DataFrame({'ChEBI-ID': metal_count_df['ChEBI-ID'], 'count': temp_cnt})
metal_count_df
# Out:
#         ChEBI-ID  count
# 0    CHEBI:29105   5788
# 1    CHEBI:29108   4768
# 2    CHEBI:18420   2140
# 3    CHEBI:29035   1136
# 4    CHEBI:24875    919
# 5    CHEBI:49883    885
# 6    CHEBI:60240    738
# 7    CHEBI:23378    561
# 8   CHEBI:190135    348
# 9    CHEBI:29103    163
# 10   CHEBI:29101    142
# 11   CHEBI:29034    136
# 12   CHEBI:49786     77
# 13   CHEBI:48828     50
# 14   CHEBI:48775     50
# 15   CHEBI:21137     36
# 16   CHEBI:29036     33
# 17   CHEBI:49552     27
# 18   CHEBI:29033     22
# 19   CHEBI:47739     12
# 20  CHEBI:177874      6
# 21   CHEBI:49415      4
# 22   CHEBI:16793      2

# %% [markdown]
# ## retrive cluster results

# %%
print('number of prot seqs:', len(list(SeqIO.parse("combined.fasta", "fasta"))))
# 262004
# Out:
# number of prot seqs: 195450

# %%
print('number of clusters:', len(list(SeqIO.parse("assembly_clustered_rep_seq.fasta", "fasta"))))
# 38717
# Out:
# number of clusters: 33071

# %% [markdown]
# clusters: dataframe of [rep accession, a protein accession in the rep's cluster]

# %%
clusters = pd.read_csv('assembly_clustered_cluster.tsv', sep='\t', header=None)
clusters.columns = ['Rep', 'Accession']
clusters
# Out:
#                Rep   Accession
# 0       A0A0K0IP23  A0A0K0IP23
# 1       A0A0K0IP23      P22085
# 2           A5GNU1      A5GNU1
# 3           A5GNU1      Q7V5D4
# 4           A5GNU1      Q0I762
# ...            ...         ...
# 195445      Q94252      Q93789
# 195446      Q94252      O16956
# 195447      Q99L85      Q99L85
# 195448      Q99L85      Q6IUP3
# 195449      Q99L85      Q8TE02
#
# [195450 rows x 2 columns]

# %%
print('number of reps: %d' % len(clusters['Rep'].unique())) # check if #rep == #cluster
# Out:
# number of reps: 33071

# %%
print('number of clustered seqs: %d' % len(clusters)) # check if #clustered seqs == #seqs
# Out:
# number of clustered seqs: 195450

# %%
33071/195450
# Out:
# 0.16920440010232796

# %% [markdown]
# ## Extract metal binding information of the clusters

# %% [markdown]
# cluster_label: merging cluster with annotations, **drop clusters where there is no metal-binding sequence at all**. \
# dataframe of [rep acc, protein acc, evidence of the protein, metal binding to the protein, position of binding site]

# %%
cluster_label = pd.merge(clusters, anno, on = 'Accession', how = "outer")
cluster_label.dropna(axis=0, how='any', inplace=True)
cluster_label
# Out:
#            Rep Accession     Evidence     ChEBI-ID  Position
# 1073    B1XI84    P80373  ECO:0000269  CHEBI:29105      31.0
# 1074    B1XI84    P80373  ECO:0000269  CHEBI:29105      12.0
# 1075    B1XI84    P80373  ECO:0000269  CHEBI:29105       9.0
# 1076    B1XI84    P80373  ECO:0000269  CHEBI:29105      26.0
# 1475    P12453    P04608  ECO:0000269  CHEBI:29105      37.0
# ...        ...       ...          ...          ...       ...
# 209731  Q2UNX8    Q4WW81  ECO:0007744  CHEBI:29105     252.0
# 209732  Q2UNX8    Q4WW81  ECO:0000269  CHEBI:29105     244.0
# 209733  Q2UNX8    Q4WW81  ECO:0007744  CHEBI:29105     244.0
# 209734  Q2UNX8    Q4WW81  ECO:0000269  CHEBI:29105     252.0
# 209735  Q2UNX8    Q4WW81  ECO:0007744  CHEBI:29105     246.0
#
# [18043 rows x 5 columns]

# %% [markdown]
# ## Record the number of binding residues with different metals for clusters and sequences

# %% [markdown]
# For each cluster (represented by the rep prot accession) where there are metal-binding sequences, count the number of binding residues with each metal. \
#
# rep_metal: dataframe of [cluster rep, metal type, number of binding residues with the metal in the cluster] \
#
# Used as a record table for future data splitting.

# %%
rep_metal = cluster_label[['Rep', 'ChEBI-ID']].value_counts().to_frame().reset_index()
rep_metal.columns = ['Rep', 'ChEBI-ID', 'count']
rep_metal
# Out:
#          Rep     ChEBI-ID  count
# 0     P04355  CHEBI:60240    204
# 1     O31527  CHEBI:29108    164
# 2     P63098  CHEBI:29108    160
# 3     P0DP23  CHEBI:29108    153
# 4     Q9NQV7  CHEBI:29105    112
# ...      ...          ...    ...
# 1792  P9WLU3  CHEBI:29035      1
# 1793  Q8NK92  CHEBI:29108      1
# 1794  P05987  CHEBI:18420      1
# 1795  P9WLU3  CHEBI:18420      1
# 1796  Q9X1H5  CHEBI:29035      1
#
# [1797 rows x 3 columns]

# %% [markdown]
# rep_Allmetal: a temporary dataframe of [rep of a cluster, number of binding residues in the cluster regardless of metal type]

# %% [markdown]
# reps: a list containing the accessions of all reps whose cluster contains metal-binding sequences, shuffle it for future data splitting.

# %%
rep_Allmetal = cluster_label['Rep'].value_counts().to_frame().reset_index()
rep_Allmetal.columns = ['Rep', 'count']
reps = list(rep_Allmetal['Rep'].unique())
import random
random.seed(42)
random.shuffle(reps)
reps[:10]
# Out:
# ['O95486',
#  'O60494',
#  'O64332',
#  'P0AES2',
#  'O13833',
#  'P69380',
#  'Q3YW59',
#  'O61142',
#  'Q94GM9',
#  'Q96PN6']

# %% [markdown]
# For each metal-binding sequence, count the number of binding residues with each metal. \
#
# seq_metal: dataframe of [prot sequence, metal type, number of binding residues with the metal] \
#
# Used as a record table for future data splitting.

# %%
seq_metal = cluster_label[['Accession', 'ChEBI-ID']].value_counts().to_frame().reset_index()
seq_metal.columns = ['Accession', 'ChEBI-ID', 'count']
seq_metal
# Out:
#      Accession     ChEBI-ID  count
# 0       O31526  CHEBI:29108     88
# 1       O31527  CHEBI:29108     76
# 2       E0VIU9  CHEBI:29105     64
# 3       Q51817  CHEBI:29108     56
# 4       O75592  CHEBI:29105     48
# ...        ...          ...    ...
# 2547    P15848  CHEBI:29108      1
# 2548    P0A9G6  CHEBI:18420      1
# 2549    P00971  CHEBI:18420      1
# 2550    A5W059  CHEBI:18420      1
# 2551    Q8NQ97  CHEBI:18420      1
#
# [2552 rows x 3 columns]

# %% [markdown]
# seq_Allmetal: a temporary dataframe of [a prot seq, number of binding residues to the seq regardless of metal type]

# %% [markdown]
# seqs: a list containing the accessions of all metal-binding protein seqs in POS_TRAIN_FULL.fasta, shuffle it for future data splitting.

# %%
seq_Allmetal = cluster_label['Accession'].value_counts().to_frame().reset_index()
seq_Allmetal.columns = ['Accession', 'count']
seqs = list(seq_Allmetal['Accession'].unique())
random.shuffle(seqs)
seqs[:10]
# Out:
# ['Q5SK67',
#  'E9AE57',
#  'Q29437',
#  'Q9V099',
#  'O43813',
#  'Q8GXV5',
#  'P23532',
#  'Q9X0H1',
#  'P51688',
#  'P46976']

# %%
print('number of clusters containing metalloprotein: %d' % len(reps))
# Out:
# number of clusters containing metalloprotein: 1588

# %% [markdown]
# non_metal_reps: all reps whose cluster contains no metal-binding sequences at all.

# %%
non_metal_reps = []
for i in clusters['Rep'].unique():
  if i not in reps:
    non_metal_reps.append(i)
print('number of clusters not containing metalloprotein: %d' % len(non_metal_reps))
# Out:
# number of clusters not containing metalloprotein: 31483

# %% [markdown]
# # Data splitting

# %% [markdown]
# - Goal: split a test dataset from the whole dataset with a test:trainval ratio 1:9, making sure that in the test set, the number of metal-binding residues for each metal type is roughly 1:9 of the trainval set, this also ensures that metal-binding residues for each metal type appears at least once in the test set. \
#
#
# - procedure
#   1. establish a table (metal_count_df) from the annotation POS_TRAIN_FULL.fasta. The table records every metal and the number of residues binding to the metal.
#   2. establish a table (metal_count_test) from the annotation POS_TRAIN_FULL.fasta. The table records every metal and the number of residues binding to the metal * 0.1, rounded.
#   3. iterate random shuffled clusters containing at least one metal-binding protein, for each cluster, decide if it should go to trainval or test set by: \
#     a. for each metal type
#       - retrive the number of residues binding to it in that cluster.
#       - compare the number to the record in metal_count_test, if the number is greater than the record (+10 flexibility), append to trainval set.
#       - compare the number to the record in metal_count_df, if the number equals the record, mearning all residues binding to the metal belong to this cluster, append to trainval set.
#
#     b. If the cluster is not appended to trainvalset in a., append to test set, update metal_count_test by subtracting the numbers of newly added residues of each metal type from the corresponding records.
#   4. For clusters containing no metal-binding protein at all, randomly assign them to trainval or test set with probs 0.9, 0.1.
#   5. replace clusters in the trainval and test set by proteins in the clusters.
#   6. For each metal, check the #binding residues in test set/#binding residues in full set, if the proportion is smaller than 0.99, randomly grab to test set a protein from trainval set that binds the metal, this is done iteratively until the proportion hits 0.99.

# %% [markdown]
# ## cluster splitting

# %%
import numpy as np

# %%
import math

metal_count_test = metal_count_df.copy()
metal_count_test['count'] = metal_count_test['count']*0.9//1+1

metal_test = set()
test = []
trainval = []
for i in reps:
  print(f'----- decide for cluster {i} -----')

  temp = rep_metal[rep_metal['Rep'] == i].reset_index()
  print(f'cluster {i} has annotations:\n{temp}')
  flag = 1
  for m in temp['ChEBI-ID']:
    num = temp[temp['ChEBI-ID']==m].iloc[0,3]
    cur = metal_count_test.loc[metal_count_test['ChEBI-ID']==m].iloc[0,1]
    max_num = metal_count_df.loc[metal_count_df['ChEBI-ID']==m].iloc[0,1]
    if cur + 5 < num or num == max_num:
      print(f'metal {m} exceed maximum, cluster {i} -> test')
      test.append(i)
      flag = 0
      break
  if flag:
    trainval.append(i)
    print(f'cluster {i} -> trainval')
    for n in temp['ChEBI-ID']: 
        print(f"the cluster has metal {n}, number {temp[temp['ChEBI-ID']==n].iloc[0,3]}")
        print(metal_count_test)
        metal_count_test.loc[metal_count_test['ChEBI-ID']==n, 'count'] -= temp[temp['ChEBI-ID']==n].iloc[0,3]
        print(metal_count_test)
        metal_test.add(n)
        print(f"update metal presented in trainval set: {metal_test}")
  print('\n\n')

randnums = np.random.randint(0, len(non_metal_reps), int(0.1*len(non_metal_reps)))
for i, v in enumerate(non_metal_reps):
  if i in randnums:
    test.append(v)
  else:
    trainval.append(v)
print(test)
print(trainval)
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   91.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   64.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   91.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P00428 -----
# cluster P00428 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1111  P00428  CHEBI:29105      4
# cluster P00428 -> trainval
# the cluster has metal CHEBI:29105, number 4
#         ChEBI-ID  count
# 0    CHEBI:29105   64.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   91.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   91.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P14925 -----
# cluster P14925 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    385  P14925  CHEBI:23378     12
# 1    943  P14925  CHEBI:29108      6
# 2    957  P14925  CHEBI:29105      6
# cluster P14925 -> trainval
# the cluster has metal CHEBI:23378, number 12
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   91.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
# the cluster has metal CHEBI:29108, number 6
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  149.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
# the cluster has metal CHEBI:29105, number 6
#         ChEBI-ID  count
# 0    CHEBI:29105   60.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   54.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P06621 -----
# cluster P06621 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1061  P06621  CHEBI:29105      5
# cluster P06621 -> trainval
# the cluster has metal CHEBI:29105, number 5
#         ChEBI-ID  count
# 0    CHEBI:29105   54.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P38993 -----
# cluster P38993 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    160  P38993  CHEBI:23378     22
# cluster P38993 -> trainval
# the cluster has metal CHEBI:23378, number 22
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   79.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P00512 -----
# cluster P00512 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1715  P00512  CHEBI:18420      2
# cluster P00512 -> trainval
# the cluster has metal CHEBI:18420, number 2
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   55.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   53.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q10663 -----
# cluster Q10663 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1662  Q10663  CHEBI:18420      2
# cluster Q10663 -> trainval
# the cluster has metal CHEBI:18420, number 2
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   53.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   51.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster O95551 -----
# cluster O95551 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    465  O95551  CHEBI:18420     10
# cluster O95551 -> trainval
# the cluster has metal CHEBI:18420, number 10
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   51.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   41.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q9UJA9 -----
# cluster Q9UJA9 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    112  Q9UJA9  CHEBI:29105     28
# cluster Q9UJA9 -> trainval
# the cluster has metal CHEBI:29105, number 28
#         ChEBI-ID  count
# 0    CHEBI:29105   49.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   41.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   41.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster O81086 -----
# cluster O81086 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    455  O81086  CHEBI:18420     10
# cluster O81086 -> trainval
# the cluster has metal CHEBI:18420, number 10
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   41.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P13650 -----
# cluster P13650 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    716  P13650  CHEBI:29108      8
# cluster P13650 -> trainval
# the cluster has metal CHEBI:29108, number 8
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  143.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q51782 -----
# cluster Q51782 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    764  Q51782  CHEBI:29105      7
# cluster Q51782 -> trainval
# the cluster has metal CHEBI:29105, number 7
#         ChEBI-ID  count
# 0    CHEBI:29105   21.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   14.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q9UQQ1 -----
# cluster Q9UQQ1 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    470  Q9UQQ1  CHEBI:29105     10
# 1    633  Q9UQQ1  CHEBI:29108      8
# cluster Q9UQQ1 -> trainval
# the cluster has metal CHEBI:29105, number 10
#         ChEBI-ID  count
# 0    CHEBI:29105   14.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
# the cluster has metal CHEBI:29108, number 8
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  135.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q10583 -----
# cluster Q10583 has annotations:
#    index     Rep     ChEBI-ID  count
# 0     32  Q10583  CHEBI:23378     54
# cluster Q10583 -> trainval
# the cluster has metal CHEBI:23378, number 54
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378   57.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q9NWW6 -----
# cluster Q9NWW6 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1236  Q9NWW6  CHEBI:18420      4
# cluster Q9NWW6 -> trainval
# the cluster has metal CHEBI:18420, number 4
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   31.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   27.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P80306 -----
# cluster P80306 has annotations:
#    index     Rep      ChEBI-ID  count
# 0    579  P80306  CHEBI:190135      8
# cluster P80306 -> trainval
# the cluster has metal CHEBI:190135, number 8
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   27.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135   16.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   27.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q8ZL58 -----
# cluster Q8ZL58 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1612  Q8ZL58  CHEBI:18420      3
# cluster Q8ZL58 -> trainval
# the cluster has metal CHEBI:18420, number 3
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   27.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   24.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster O31527 -----
# cluster O31527 has annotations:
#    index     Rep     ChEBI-ID  count
# 0      1  O31527  CHEBI:29108    164
# metal CHEBI:29108 exceed maximum, cluster O31527 -> test
#
#
#
# ----- decide for cluster Q3J5L6 -----
# cluster Q3J5L6 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1317  Q3J5L6  CHEBI:18420      4
# cluster Q3J5L6 -> trainval
# the cluster has metal CHEBI:18420, number 4
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   24.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   20.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P9WPJ7 -----
# cluster P9WPJ7 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1308  P9WPJ7  CHEBI:29105      4
# cluster P9WPJ7 -> trainval
# the cluster has metal CHEBI:29105, number 4
#         ChEBI-ID  count
# 0    CHEBI:29105    4.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   20.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   20.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster D0E8I5 -----
# cluster D0E8I5 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    332  D0E8I5  CHEBI:24875     14
# metal CHEBI:24875 exceed maximum, cluster D0E8I5 -> test
#
#
#
# ----- decide for cluster O08498 -----
# cluster O08498 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1018  O08498  CHEBI:29105      6
# metal CHEBI:29105 exceed maximum, cluster O08498 -> test
#
#
#
# ----- decide for cluster P14647 -----
# cluster P14647 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1510  P14647  CHEBI:18420      3
# cluster P14647 -> trainval
# the cluster has metal CHEBI:18420, number 3
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   20.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   17.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster O31611 -----
# cluster O31611 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1785  O31611  CHEBI:18420      1
# cluster O31611 -> trainval
# the cluster has metal CHEBI:18420, number 1
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   17.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   16.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P45700 -----
# cluster P45700 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1682  P45700  CHEBI:29108      2
# cluster P45700 -> trainval
# the cluster has metal CHEBI:29108, number 2
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  127.0
# 2    CHEBI:18420   16.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   16.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P09838 -----
# cluster P09838 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1515  P09838  CHEBI:18420      3
# cluster P09838 -> trainval
# the cluster has metal CHEBI:18420, number 3
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   16.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   13.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P0DJZ2 -----
# cluster P0DJZ2 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1569  P0DJZ2  CHEBI:60240      3
# cluster P0DJZ2 -> trainval
# the cluster has metal CHEBI:60240, number 3
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   13.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   92.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   13.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   89.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster Q9FK51 -----
# cluster Q9FK51 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    653  Q9FK51  CHEBI:29105      8
# metal CHEBI:29105 exceed maximum, cluster Q9FK51 -> test
#
#
#
# ----- decide for cluster Q8N465 -----
# cluster Q8N465 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1536  Q8N465  CHEBI:29105      3
# cluster Q8N465 -> trainval
# the cluster has metal CHEBI:29105, number 3
#         ChEBI-ID  count
# 0    CHEBI:29105    0.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   13.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   89.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   -3.0
# 1    CHEBI:29108  125.0
# 2    CHEBI:18420   13.0
# 3    CHEBI:29035    3.0
# 4    CHEBI:24875    1.0
# 5    CHEBI:49883   17.0
# 6    CHEBI:60240   89.0
# 7    CHEBI:23378    3.0
# 8   CHEBI:190135    8.0
# 9    CHEBI:29103   18.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -3.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    9.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# ...
# cluster Q9UPY3 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    867  Q9UPY3  CHEBI:18420      6
# metal CHEBI:18420 exceed maximum, cluster Q9UPY3 -> test
#
#
#
# ----- decide for cluster P0DUV7 -----
# cluster P0DUV7 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1752  P0DUV7  CHEBI:49883      1
# cluster P0DUV7 -> trainval
# the cluster has metal CHEBI:49883, number 1
#         ChEBI-ID  count
# 0    CHEBI:29105   -5.0
# 1    CHEBI:29108   -5.0
# 2    CHEBI:18420   -5.0
# 3    CHEBI:29035   -5.0
# 4    CHEBI:24875   -5.0
# 5    CHEBI:49883    0.0
# 6    CHEBI:60240    2.0
# 7    CHEBI:23378   -3.0
# 8   CHEBI:190135    4.0
# 9    CHEBI:29103    2.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -5.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    6.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
#         ChEBI-ID  count
# 0    CHEBI:29105   -5.0
# 1    CHEBI:29108   -5.0
# 2    CHEBI:18420   -5.0
# 3    CHEBI:29035   -5.0
# 4    CHEBI:24875   -5.0
# 5    CHEBI:49883   -1.0
# 6    CHEBI:60240    2.0
# 7    CHEBI:23378   -3.0
# 8   CHEBI:190135    4.0
# 9    CHEBI:29103    2.0
# 10   CHEBI:29101   -3.0
# 11   CHEBI:29034   -5.0
# 12   CHEBI:49786   -3.0
# 13   CHEBI:48828    6.0
# 14   CHEBI:48775   -4.0
# 15   CHEBI:21137   -3.0
# 16   CHEBI:29036    5.0
# 17   CHEBI:49552   -2.0
# 18   CHEBI:29033    1.0
# 19   CHEBI:47739    5.0
# 20  CHEBI:177874    6.0
# 21   CHEBI:49415    4.0
# 22   CHEBI:16793    2.0
# update metal presented in trainval set: {'CHEBI:18420', 'CHEBI:24875', 'CHEBI:29105', 'CHEBI:23378', 'CHEBI:49552', 'CHEBI:60240', 'CHEBI:49883', 'CHEBI:29034', 'CHEBI:29108', 'CHEBI:29103', 'CHEBI:49786', 'CHEBI:47739', 'CHEBI:21137', 'CHEBI:48828', 'CHEBI:190135', 'CHEBI:48775', 'CHEBI:29036', 'CHEBI:29033', 'CHEBI:29035', 'CHEBI:29101'}
#
#
#
# ----- decide for cluster P76407 -----
# cluster P76407 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1475  P76407  CHEBI:18420      3
# metal CHEBI:18420 exceed maximum, cluster P76407 -> test
#
#
#
# ----- decide for cluster Q9HMP7 -----
# cluster Q9HMP7 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1481  Q9HMP7  CHEBI:24875      3
# metal CHEBI:24875 exceed maximum, cluster Q9HMP7 -> test
#
#
#
# ----- decide for cluster Q9RV46 -----
# cluster Q9RV46 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1635  Q9RV46  CHEBI:18420      2
# metal CHEBI:18420 exceed maximum, cluster Q9RV46 -> test
#
#
#
# ----- decide for cluster Q9UNA4 -----
# cluster Q9UNA4 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    868  Q9UNA4  CHEBI:29035      6
# 1    870  Q9UNA4  CHEBI:18420      6
# metal CHEBI:29035 exceed maximum, cluster Q9UNA4 -> test
#
#
#
# ----- decide for cluster P06988 -----
# cluster P06988 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1171  P06988  CHEBI:29105      4
# metal CHEBI:29105 exceed maximum, cluster P06988 -> test
#
#
#
# ----- decide for cluster Q7CS13 -----
# cluster Q7CS13 has annotations:
#    index     Rep     ChEBI-ID  count
# 0     47  Q7CS13  CHEBI:29105     44
# metal CHEBI:29105 exceed maximum, cluster Q7CS13 -> test
#
#
#
# ----- decide for cluster A0QZY0 -----
# cluster A0QZY0 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1428  A0QZY0  CHEBI:29105      3
# metal CHEBI:29105 exceed maximum, cluster A0QZY0 -> test
#
#
#
# ----- decide for cluster Q2SSG0 -----
# cluster Q2SSG0 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1324  Q2SSG0  CHEBI:29105      4
# metal CHEBI:29105 exceed maximum, cluster Q2SSG0 -> test
#
#
#
# ----- decide for cluster B5HDJ6 -----
# cluster B5HDJ6 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    500  B5HDJ6  CHEBI:18420     10
# metal CHEBI:18420 exceed maximum, cluster B5HDJ6 -> test
#
#
#
# ----- decide for cluster Q5SLC9 -----
# cluster Q5SLC9 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    393  Q5SLC9  CHEBI:29105     12
# metal CHEBI:29105 exceed maximum, cluster Q5SLC9 -> test
#
#
#
# ----- decide for cluster P07846 -----
# cluster P07846 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    169  P07846  CHEBI:29105     21
# metal CHEBI:29105 exceed maximum, cluster P07846 -> test
#
#
#
# ----- decide for cluster P29145 -----
# cluster P29145 has annotations:
#    index     Rep     ChEBI-ID  count
# 0     51  P29145  CHEBI:29108     42
# metal CHEBI:29108 exceed maximum, cluster P29145 -> test
#
#
#
# ----- decide for cluster P62339 -----
# cluster P62339 has annotations:
#    index     Rep     ChEBI-ID  count
# 0     59  P62339  CHEBI:60240     40
# metal CHEBI:60240 exceed maximum, cluster P62339 -> test
#
#
#
# ----- decide for cluster Q949P2 -----
# cluster Q949P2 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    818  Q949P2  CHEBI:29105      6
# metal CHEBI:29105 exceed maximum, cluster Q949P2 -> test
#
#
#
# ----- decide for cluster P60003 -----
# cluster P60003 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1217  P60003  CHEBI:29105      4
# metal CHEBI:29105 exceed maximum, cluster P60003 -> test
#
#
#
# ----- decide for cluster P12821 -----
# cluster P12821 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    162  P12821  CHEBI:29105     22
# metal CHEBI:29105 exceed maximum, cluster P12821 -> test
#
#
#
# ----- decide for cluster F8GV06 -----
# cluster F8GV06 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1267  F8GV06  CHEBI:29105      4
# metal CHEBI:29105 exceed maximum, cluster F8GV06 -> test
#
#
#
# ----- decide for cluster O13833 -----
# cluster O13833 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1718  O13833  CHEBI:18420      2
# metal CHEBI:18420 exceed maximum, cluster O13833 -> test
#
#
#
# ----- decide for cluster Q22942 -----
# cluster Q22942 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1503  Q22942  CHEBI:29108      3
# metal CHEBI:29108 exceed maximum, cluster Q22942 -> test
#
#
#
# ----- decide for cluster P09148 -----
# cluster P09148 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    351  P09148  CHEBI:29105     12
# 1    634  P09148  CHEBI:24875      8
# metal CHEBI:29105 exceed maximum, cluster P09148 -> test
#
#
#
# ----- decide for cluster O94753 -----
# cluster O94753 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1710  O94753  CHEBI:29035      2
# metal CHEBI:29035 exceed maximum, cluster O94753 -> test
#
#
#
# ----- decide for cluster Q8IZD2 -----
# cluster Q8IZD2 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    229  Q8IZD2  CHEBI:29105     16
# metal CHEBI:29105 exceed maximum, cluster Q8IZD2 -> test
#
#
#
# ----- decide for cluster P05806 -----
# cluster P05806 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    672  P05806  CHEBI:29108      8
# 1   1561  P05806  CHEBI:29105      3
# metal CHEBI:29108 exceed maximum, cluster P05806 -> test
#
#
#
# ----- decide for cluster P29719 -----
# cluster P29719 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    504  P29719  CHEBI:29108     10
# metal CHEBI:29108 exceed maximum, cluster P29719 -> test
#
#
#
# ----- decide for cluster O95251 -----
# cluster O95251 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    729  O95251  CHEBI:29105      8
# metal CHEBI:29105 exceed maximum, cluster O95251 -> test
#
#
#
# ----- decide for cluster Q57815 -----
# cluster Q57815 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1730  Q57815  CHEBI:18420      2
# metal CHEBI:18420 exceed maximum, cluster Q57815 -> test
#
#
#
# ----- decide for cluster P07598 -----
# cluster P07598 has annotations:
#    index     Rep      ChEBI-ID  count
# 0     56  P07598   CHEBI:49883     40
# 1   1178  P07598  CHEBI:190135      4
# 2   1564  P07598   CHEBI:29033      3
# metal CHEBI:49883 exceed maximum, cluster P07598 -> test
#
#
#
# ----- decide for cluster Q9HYC5 -----
# cluster Q9HYC5 has annotations:
#    index     Rep     ChEBI-ID  count
# 0    208  Q9HYC5  CHEBI:29108     18
# metal CHEBI:29108 exceed maximum, cluster Q9HYC5 -> test
#
#
#
# ----- decide for cluster A0RZH5 -----
# cluster A0RZH5 has annotations:
#    index     Rep     ChEBI-ID  count
# 0   1429  A0RZH5  CHEBI:18420      3
# metal CHEBI:18420 exceed maximum, cluster A0RZH5 -> test
#
#
#
# ['Q9F8A8', 'Q7SID2', 'P04129', 'Q9WYZ1', 'O31527', 'D0E8I5', 'O08498', 'Q9FK51', 'Q845S7', 'P45211', 'D0EM77', 'Q94ID1', 'P0ABS1', 'O43819', 'P28320', 'Q97VT7', 'P57083', 'Q06241', 'P21642', 'P15919', 'I3LM39', 'Q9KEI9', 'Q3M6C3', 'E6LHV5', 'Q5TAX3', 'Q70IY1', 'A0Q5Y3', 'Q8VXY9', 'P03265', 'E9Q555', 'Q8GZ45', 'O87198', 'A0A0H3KB22', 'Q9LJL3', 'P0DO17', 'Q55415', 'P50591', 'Q9ZP19', 'Q1QT89', 'P81114', 'O95989', 'O34714', 'P05987', 'Q01693', 'P55020', 'P77324', 'O83774', 'Q9BU89', 'Q56254', 'Q53WD3', 'Q10MK2', 'Q9VB68', 'F4KIN4', 'P35813', 'P08200', 'Q8W453', 'P58242', 'Q97H19', 'P0DUH5', 'Q06835', 'Q9HBH9', 'P11444', 'Q16790', 'P03354', 'P9WPX9', 'P37064', 'O75874', 'O60184', 'D6WI29', 'Q97UA0', 'P0AF24', 'I0DF35', 'P38797', 'P00727', 'P00971', 'Q07008', 'Q9C5Q8', 'P40115', 'P39116', 'Q46342', 'Q9ZCD3', 'P27431', 'Q80TS3', 'Q9UBV7', 'G5ECQ8', 'K5B7F3', 'P13988', 'P27608', 'Q46938', 'P05186', 'A0NLY7', 'A0A1C7D1B7', 'P0AC81', 'P53184', 'Q9SJG2', 'P19921', 'I6XD65', 'P29208', 'P9WH69', 'Q52078', 'P9WPH3', 'Q99W51', 'P33025', 'P0AB87', 'Q9NRW3', 'P29218', 'Q01770', 'Q9X2H6', 'P9WNV3', 'Q9ZHI1', 'Q91VB2', 'P50743', 'Q86500', 'P55263', 'P62617', 'Q9UPY3', 'P76407', 'Q9HMP7', 'Q9RV46', 'Q9UNA4', 'P06988', 'Q7CS13', 'A0QZY0', 'Q2SSG0', 'B5HDJ6', 'Q5SLC9', 'P07846', 'P29145', 'P62339', 'Q949P2', 'P60003', 'P12821', 'F8GV06', 'O13833', 'Q22942', 'P09148', 'O94753', 'Q8IZD2', 'P05806', 'P29719', 'O95251', 'Q57815', 'P07598', 'Q9HYC5', 'A0RZH5', 'Q15849', 'Q8LPG1', 'Q40465', 'P13669', 'P0A990', 'Q8TEB1', 'Q83GK0', 'Q9KVI7', 'Q5SXH7', 'Q9V3R1', 'Q10496', 'Q96J65', 'F4JMJ1', 'Q0T900', 'P40048', 'Q9RQQ9', 'Q55GN6', 'Q55FF3', 'A0QQV6', 'P17379', 'Q9UTL8', 'Q01567', 'Q9USR4', 'G3YG17', 'Q28EN2', 'P82689', 'P0C424', 'H9IWW7', 'Q8N912', 'Q9UHQ1', 'B1ZUV7', 'O95613', 'Q10MX4', 'Q18807', 'Q3V1H1', 'Q71RG4', 'B2CW77', 'P9WGN9', 'Q9CPV5', 'B6HTR9', 'P36167', 'P0CU66', 'Q9FIN1', 'P0DQN0', 'Q4PI64', 'Q9VH89', 'Q6WNP1', 'P40169', 'Q59N20', 'P53061', 'A6MWS9', 'Q27309', 'O17581', 'P53253', 'Q9RN59', 'Q59X49', 'Q04499', 'P85456', 'O61307', 'D9I2G3', 'P94514', 'P05798', 'D5LX59', 'Q96329', 'Q2RFX3', 'P86395', 'P12747', 'Q9YGA7', 'P52624', 'Q84VV6', 'Q4WMJ7', 'Q9M081', 'Q3U0P1', 'O07515', 'P77249', 'P12546', 'Q8ZBM0', 'A0A2I1C3W6', 'Q9V3I8', 'Q9VN13', 'P90245', 'Q9HYG2', 'Q6ZRQ5', 'Q9XIA7', 'Q54G43', 'O32323', 'Q2EES9', 'Q9HGL5', 'Q9HLE2', 'Q67653', 'Q84MQ9', 'Q9P1A6', 'P36636', 'O95424', 'Q7YZT0', 'Q9VSE7', 'D0NUQ3', 'Q8SY61', 'O28596', 'Q96QZ0', 'P28791', 'Q02I31', 'Q0VC80', 'G4ZKT3', 'Q9FJB4', 'A1AH34', 'Q5ZAY0', 'Q9LTX2', 'P82952', 'Q54I60', 'Q9U9R7', 'Q9HPD9', 'B8NM75', 'Q8T9Z7', 'A9WBG7', 'O87694', 'Q03430', 'P81916', 'P37558', 'P60062', 'P64512', 'P0C054', 'Q6LV39', 'Q8R1P4', 'Q96SL1', 'P0A9G2', 'P18393', 'E7FHX6', 'Q92349', 'P21634', 'Q9BV40', 'P0AD44', 'P23643', 'P98193', 'Q9VSL3', 'Q07730', 'Q95X94', 'F4KIA8', 'Q6NYT1', 'Q8VC65', 'B5RRS4', 'T0CUB8', 'C0HKX7', 'Q2JCJ1', 'P85120', 'P70261', 'Q83BR8', 'Q31CD7', 'Q558Z2', 'Q22747', 'Q8BUE4', 'Q9VKA4', 'Q24702', 'P58402', 'Q8IPX7', 'O07344', 'Q9Z6M4', 'T2KN85', 'Q8NHS4', 'Q967U1', 'Q6Q8B3', 'O74919', 'O14131', 'A0A1L2F565', 'Q53U15', 'Q0P8J7', 'A8NVB7', 'S0DL65', 'A2R616', 'P43069', 'Q695T9', 'P38127', 'O46200', 'P47514', 'Q8N8X9', 'C4YCC3', 'P05546', 'P04888', 'Q46065', 'A7LXT4', 'B2HSU8', 'Q9V3W6', 'B3VA59', 'P53949', 'Q0Q2J6', 'Q78JN3', 'Q0J4D4', 'Q00022', 'Q9FL44', 'P87027', 'Q6E3K9', 'Q9VKY1', 'O74974', 'P46088', 'A1Z6S7', 'Q99109', 'P0C8I9', 'Q03063', 'Q03085', 'A9CES5', 'Q9VBL7', 'Q9FL17', 'P37675', 'Q58842', 'P64426', 'P15364', 'Q86UN6', 'Q13296', 'Q9SRW1', 'Q1WUM1', 'O45523', 'P0DL39', 'Q9BQ75', 'Q9CQU5', 'D0N8M5', 'Q8CV14', 'O05516', 'P80197', 'Q9YHB5', 'O86683', 'Q2LRA9', 'Q6P9Q6', 'P28993', 'Q05515', 'Q5XI99', 'P65666', 'Q47208', 'Q2NL17', 'Q3V1M1', 'F4IDY7', 'A8WX15', 'O33478', 'P18345', 'P73161', 'Q3A9J4', 'Q9SYJ8', 'Q6P2P2', 'Q04299', 'P0A2J5', 'Q09848', 'P54191', 'P77231', 'D4GU62', 'Q8R3W5', 'P42060', 'O80669', 'O74387', 'Q49434', 'Q9GPF0', 'Q6NUT7', 'Q9BWT1', 'P41391', 'P98091', 'Q3 ...
# ['P51402', 'P0AFJ5', 'Q8GXV5', 'Q8N543', 'Q8KNP3', 'Q8WYH8', 'O82504', 'Q9STM3', 'P04183', 'Q60365', 'Q76IQ9', 'A5K464', 'P43005', 'P0CX04', 'P47708', 'Q0III6', 'Q934F5', 'P03695', 'P62623', 'P69166', 'Q46E79', 'O68196', 'P13382', 'P04063', 'P28720', 'Q8CX61', 'Q99972', 'P76014', 'G5EBX9', 'Q56062', 'Q8IWL3', 'G8GER6', 'P80882', 'Q9QYJ4', 'Q81X77', 'P54952', 'Q8LAM0', 'P32254', 'C7UDU4', 'P43313', 'Q556Y2', 'C6ZDB5', 'P46327', 'Q99ZW2', 'P26745', 'Q6GWS6', 'Q20646', 'Q9I0N5', 'P0AC47', 'Q81EJ6', 'P24203', 'Q60364', 'P84074', 'P50213', 'Q08758', 'Q47746', 'Q9ZHI0', 'P13709', 'Q4K423', 'Q0H8Y3', 'P16692', 'O74859', 'Q9RFD6', 'P02621', 'Q9VE86', 'P04386', 'P13423', 'P86938', 'Q21A54', 'Q6CJ86', 'P56690', 'Q93YN9', 'P07464', 'Q97TX9', 'P07003', 'Q46891', 'Q9W197', 'P23532', 'Q8X151', 'P16952', 'O34788', 'P0DSP2', 'Q51817', 'T2KM26', 'Q58635', 'D0CY60', 'P46995', 'Q9X0Z6', 'P42849', 'O44249', 'Q14061', 'P0C558', 'Q9H2H0', 'P13513', 'Q9SN73', 'P58335', 'Q0TTH1', 'P45548', 'S0HPF7', 'O68195', 'P00581', 'P27708', 'P17978', 'P06999', 'Q02360', 'P08164', 'P07658', 'P35559', 'P69922', 'Q06278', 'Q04924', 'P9WJN3', 'Q9I2N0', 'Q72IW9', 'P80176', 'Q9SU24', 'P04037', 'Q9NWT6', 'P71335', 'Q46856', 'Q03304', 'O75844', 'Q680B9', 'O66129', 'Q72H18', 'O95843', 'A1YYW7', 'A8YZP8', 'P46881', 'P35853', 'P00488', 'Q7T291', 'O59580', 'Q9RBY6', 'P60487', 'P17846', 'P32170', 'A9CKY2', 'Q81EK9', 'P77366', 'Q8BW10', 'Q9RVK2', 'Q9SR62', 'P21327', 'Q8U1S6', 'Q65140', 'Q39034', 'P0ABN1', 'A0FGR8', 'D6R8X8', 'Q8PDX2', 'O95271', 'Q03529', 'P27958', 'Q28146', 'I6X235', 'Q93LQ6', 'Q99549', 'P14789', 'Q4A724', 'Q45298', 'P13507', 'P14300', 'O84616', 'P24197', 'Q9UK39', 'O29867', 'Q17R31', 'P10820', 'Q75UV1', 'Q8R5C8', 'P30331', 'Q96PE7', 'Q05957', 'O30033', 'G0S8G9', 'P04718', 'P32626', 'C1CZ84', 'Q9XTW2', 'C5G6D7', 'P51691', 'B8YB53', 'Q5ZTK6', 'Q5AR34', 'Q9ALJ4', 'P49594', 'B9KDD4', 'Q47CX0', 'Q9BWP8', 'A1B8Z1', 'D6WMX4', 'P32056', 'P0AB85', 'O32445', 'W6KHH6', 'Q9NRN7', 'G3XD28', 'P31460', 'Q05514', 'Q8A6L0', 'P80366', 'O58038', 'O52063', 'Q82IZ1', 'Q9X6W9', 'Q8NHM5', 'P40482', 'O43194', 'I6Y4D2', 'P32356', 'P30429', 'Q9BT23', 'P0AB58', 'P50899', 'P9WI99', 'P0A725', 'Q8N6T7', 'P14565', 'P20807', 'Q6YMS4', 'P46883', 'Q3UGR5', 'E8MGH8', 'P82974', 'A9CH28', 'P27907', 'B1XI84', 'B1IV40', 'Q9FJH5', 'Q9WYQ4', 'P07814', 'Q9XWG3', 'Q02818', 'Q9NQV7', 'P0AFQ7', 'P03606', 'P10507', 'C0KTJ6', 'O60494', 'O09053', 'P78325', 'F9VMT6', 'P74334', 'P93836', 'P11349', 'Q9NVH0', 'Q9I1X7', 'O15392', 'A7N805', 'Q38882', 'P86912', 'O94923', 'P56271', 'P45568', 'Q8TXW1', 'P08192', 'Q977U7', 'P49598', 'Q6XGD8', 'Q3MIT2', 'Q5AR53', 'P10964', 'G8GV69', 'Q9UGP5', 'Q1LRY0', 'O76074', 'P27815', 'P26276', 'Q6GGU4', 'P83772', 'P08648', 'P54644', 'A5F5Y4', 'Q7WTU0', 'Q9H4M9', 'Q9I4K6', 'Q6QLQ4', 'P17752', 'Q6IMN6', 'P0DUV9', 'P0C9C6', 'P55792', 'O14773', 'Q08211', 'P82242', 'K4ZRC1', 'O34508', 'Q79FS8', 'Q6CPU0', 'Q08603', 'Q9NY33', 'P0A111', 'D4AEP7', 'C7BKP9', 'O67648', 'P02246', 'P0A415', 'P12530', 'P9WFX1', 'O74856', 'H3BCW1', 'Q9EYX5', 'T2KPK5', 'O33336', 'P09992', 'Q9NWX6', 'Q45588', 'Q8TD43', 'P96578', 'Q07340', 'P25910', 'Q5S3I3', 'O97366', 'Q8A1G3', 'Q9RUZ0', 'O33832', 'Q753P9', 'P03680', 'P23905', 'Q9D020', 'Q5DX34', 'Q8ZRM2', 'Q6MQC7', 'Q96DE0', 'O24872', 'O61142', 'P38524', 'P16109', 'P00691', 'Q9H040', 'Q55389', 'O67911', 'Q56185', 'Q8S9G8', 'P00445', 'Q7N561', 'P84138', 'P04509', 'A7T1N0', 'Q64444', 'Q3JNA0', 'Q381M1', 'P31353', 'Q6MLJ0', 'P9WP21', 'Q9K8U9', 'O60568', 'O67883', 'P62273', 'P0A9N4', 'P02672', 'O60658', 'Q9LZF1', 'Q9GZZ9', 'P81177', 'P0C7P0', 'P12807', 'Q8RQN1', 'P46952', 'Q8NQE1', 'Q45071', 'Q76NL8', 'Q8ZPZ9', 'Q3JUN4', 'P50848', 'P70158', 'Q46822', 'Q04656', 'A0A0H2VDN9', 'Q9UL01', 'Q4QAU9', 'P10787', 'Q91XB0', 'P0A407', 'Q0QLE9', 'O95486', 'C7C422', 'O31788', 'O67045', 'P51016', 'P9WKZ1', 'P09172', 'P75430', 'Q5U780', 'Q6DWK3', 'Q8CWX6', 'P11101', 'P15085', 'Q6NS38', 'A0A0H3JNB0', 'Q9Y235', 'P25126', 'Q04519', 'Q9I5I9', 'Q8NFU7', 'Q6JXI5', 'T2KN75', 'Q2IMC5', ' ...

# %%
print(len(test))
# Out:
# 3148

# %%
print(len(trainval))
# Out:
# 29923

# %%
list(set(test) & set(trainval)) # check no intersection
# Out:
# []

# %% [markdown]
# ## Helper function
# `check_Allmetal` counts, for each metal type, how many residues are bond with that metal in test set, and the proportion: #residues bond by the metal in test set/#residues bond by the metal in full set.

# %%
# for i in cluster_label[cluster_label['Rep'] == 'Q8HUH0']['ChEBI-ID']:
#       print(i)
def check_Allmetal(reps):
  stat = {}
  metals = metal_count_df['ChEBI-ID'].unique()
  metal_dic = dict(zip(metals, [0 for i in range(len(metals))]))
  for rep in reps:
    for i, row in rep_metal[rep_metal['Rep'] == rep].iterrows():
      metal_dic[row['ChEBI-ID']] += row['count']
  for i in metal_dic:
    per = metal_dic[i] / int(metal_count_df[metal_count_df['ChEBI-ID'] == i]['count'])
    stat[i] = [metal_dic[i], per]
    print(f'metal: {i}, num: {metal_dic[i]}, percentage: {per}')
  return stat

def check_metal(seqs, metal):
  cnt = 0
  temp = cluster_label.loc[cluster_label['Accession'].isin(seqs)]
  temp1 = temp['ChEBI-ID'].value_counts().to_frame().reset_index()
  row = temp1[temp1['index'] == metal]['ChEBI-ID']
  cnt = 0 if len(row) == 0 else int(row)
  per = cnt / int(metal_count_df[metal_count_df['ChEBI-ID'] == metal]['count'])
  return per

# %%
init_stat = check_Allmetal(test)
# Out:
# metal: CHEBI:29105, num: 569, percentage: 0.09830684174153421
# metal: CHEBI:29108, num: 468, percentage: 0.09815436241610738
# metal: CHEBI:18420, num: 203, percentage: 0.09485981308411215
# metal: CHEBI:29035, num: 103, percentage: 0.09066901408450705
# metal: CHEBI:24875, num: 83, percentage: 0.09031556039173014
# metal: CHEBI:49883, num: 78, percentage: 0.08813559322033898
# metal: CHEBI:60240, num: 64, percentage: 0.08672086720867209
# metal: CHEBI:23378, num: 50, percentage: 0.08912655971479501
# metal: CHEBI:190135, num: 38, percentage: 0.10919540229885058
# metal: CHEBI:29103, num: 18, percentage: 0.11042944785276074
# metal: CHEBI:29101, num: 8, percentage: 0.056338028169014086
# metal: CHEBI:29034, num: 8, percentage: 0.058823529411764705
# metal: CHEBI:49786, num: 0, percentage: 0.0
# metal: CHEBI:48828, num: 10, percentage: 0.2
# metal: CHEBI:48775, num: 0, percentage: 0.0
# metal: CHEBI:21137, num: 0, percentage: 0.0
# metal: CHEBI:29036, num: 8, percentage: 0.24242424242424243
# metal: CHEBI:49552, num: 0, percentage: 0.0
# metal: CHEBI:29033, num: 3, percentage: 0.13636363636363635
# metal: CHEBI:47739, num: 6, percentage: 0.5
# metal: CHEBI:177874, num: 6, percentage: 1.0
# metal: CHEBI:49415, num: 4, percentage: 1.0
# metal: CHEBI:16793, num: 2, percentage: 1.0

# %% [markdown]
# ## replace clusters by proteins in trainval and test set

# %%
test_seqs = []
trainval_seqs = []
test_seqs = list(clusters.loc[clusters['Rep'].isin(test)]['Accession'])
trainval_seqs = list(clusters.loc[clusters['Rep'].isin(trainval)]['Accession'])
# for i in test:
#   for ind, seq in clusters[clusters['Rep'] == i].iterrows():
#     test_seqs.append(seq['Accession'])

# for i in trainval:
#   for ind, seq in clusters[clusters['Rep'] == i].iterrows():
#     trainval_seqs.append(seq['Accession'])
print(test_seqs)
print(trainval_seqs)
# Out:
# ['C0HKX3', 'Q92374', 'Q9CS74', 'O95905', 'A0A2H3CSB7', 'P35220', 'Q6GLP0', 'A4IGI7', 'B7ZC77', 'P26232', 'P30997', 'Q5R416', 'Q61301', 'Q3MHM6', 'Q59I72', 'P35221', 'P26231', 'Q9UI47', 'Q65CL1', 'P90947', 'Q5AL27', 'Q6BP80', 'B7M7P4', 'C4ZXB6', 'B6I5B4', 'B1XB16', 'Q83QJ8', 'B7NRJ0', 'B7N6C8', 'Q31XU9', 'Q8XA72', 'B5Z114', 'B1IVT6', 'P0CI31', 'Q3YZ12', 'B1LNJ7', 'A8A347', 'P0CI32', 'Q0T1X8', 'B7LDD3', 'A7ZPY4', 'P47227', 'P50206', 'P08694', 'P72220', 'Q46381', 'Q9WXG7', 'Q7N4V7', 'P08088', 'P47230', 'O04547', 'Q50036', 'P9WHF9', 'A0R4C9', 'Q7TX80', 'Q72JV2', 'D4GYM0', 'P13597', 'Q00238', 'Q95132', 'Q9UMF0', 'Q60625', 'Q28730', 'Q5NKU6', 'P32942', 'Q28125', 'Q5NKV4', 'Q5NKV6', 'Q5NKV9', 'Q28806', 'P05362', 'P33729', 'Q38042', 'A0A1U9YI02', 'Q0CS62', 'Q4WMJ5', 'Q2UPB3', 'Q2UPA6', 'A5GTL6', 'Q8DLG1', 'Q5N128', 'Q31KU1', 'B0CAE7', 'B1WUV7', 'B0JRV0', 'B7K970', 'B7JZG7', 'P73554', 'B1XL12', 'Q8YZT2', 'Q3M9A3', 'A9KNV9', 'C4Z030', 'Q08334', 'Q61190', 'Q13428', 'O08784', 'Q58997', 'P52986', 'P37144', 'P29365', 'P37143', 'Q5XGL8', 'Q3B8E8', 'Q5M905', 'Q5ZKD4', 'Q6NYR8', 'Q9BXD5', 'Q66H59', 'Q5RDY1', 'Q29RY9', 'Q9DCJ9', 'Q9BEC7', 'Q7YR76', 'Q8R5I7', 'Q8IZQ8', 'Q8VIM5', 'Q89ZX0', 'Q8K2T8', 'Q8N7H5', 'Q5RAX0', 'Q4U0S5', 'Q2KJ14', 'Q4V886', 'Q6P2Y1', 'Q8VYA1', 'Q9SKB3', 'P94842', 'O10363', 'P41684', 'P07254', 'P21169', 'P24169', 'P43099', 'P56119', 'Q56S04', 'Q9ZJX8', 'B6JN89', 'B5Z8P5', 'Q1CS13', 'Q17Z34', 'Q7VGS3', 'Q86KC1', 'Q54BQ8', 'Q54BL8', 'Q27650', 'Q95RI5', 'Q7BU69', 'B4J8Z9', 'B3MFC2', 'B5A5T4', 'B4QBL6', 'B4GAN3', 'B4MQJ1', 'B3NSF6', 'B4HNI3', 'B4KR21', 'B4LQ44', 'B5E022', 'B4P641', 'C7CM32', 'B7KWT3', 'B1ZB19', 'C5B0U5', 'A9W3H7', 'A1A9R2', 'Q83LK9', 'C4ZQD5', 'Q32HQ4', 'B1IV90', 'Q48MQ8', 'C6UFB8', 'D5CZG7', 'A7ZKB2', 'Q6FFZ4', 'C8TNB7', 'Q8XAV0', 'A1JMW4', 'B7MIF4', 'Q3Z3A6', 'C8U5G9', 'D3QPK0', 'B1X9C8', 'B7M8Z2', 'D2NGI4', 'D3H120', 'C8UMM3', 'Q89Q06', 'B7NLB9', 'B7LFB7', 'Q0TJ60', 'Q0T627', 'D2AC38', 'B1LIZ8', 'Q1RDL0', 'B5YU49', 'B7N3G3', 'C6EHK0', 'B6I983', 'P75893', 'A7ZYW2', 'Q8FJ45', 'B7UNZ0', 'C6UPM9', 'C9QZ69', 'B7MQ18', 'A9CHR3', 'O87008', 'O15287', 'Q9EQR6', 'Q7UZG2', 'A2BZ92', 'A8G7L0', 'A2BTT7', 'Q317T6', 'A3PFJ4', 'P39297', 'Q10663', 'Q7XUG1', 'P28344', 'P28345', 'A6ZRW6', 'P21826', 'P30952', 'P9WKK7', 'Q02216', 'P08997', 'Q9LZC3', 'P0A9G6', 'P76446', 'P19896', 'P53939', 'P9WIH9', 'Q54EQ8', 'Q57916', 'Q62227', 'Q15466', 'P97947', 'Q8N1N2', 'Q59516', 'B1H285', 'Q8NFY9', 'Q3UQV5', 'A0A1B8YAB1', 'Q08CL3', 'O54974', 'P47929', 'P97590', 'P56470', 'Q29058', 'P38552', 'Q8K419', 'P60096', 'P28520', 'P60098', 'P48857', 'P92532', 'P60099', 'Q96033', 'Q96008', 'Q36665', 'P60097', 'C0ZIH3', 'A3MRU9', 'Q9CDF9', 'B5YDT8', 'A4IJI4', 'A4YSI7', 'P66380', 'Q04QJ1', 'P0A0H0', 'B2SQQ3', 'Q53538', 'B6JN36', 'Q8GH23', 'Q9Z9L9', 'P0A7S6', 'Q3AW56', 'C1CB44', 'P9WH63', 'Q83FN9', 'A8M534', 'Q5P337', 'P09901', 'P0A7S3', 'Q1BRU3', 'A7HM57', 'Q3BWY9', 'B1I8Z7', 'Q890N6', 'B2T756', 'B3EP66', 'A3CQM4', 'O51348', 'P62127', 'Q5M2M4', 'Q839H1', 'P0C563', 'B5Z8J2', 'B5ZC34', 'Q13TG5', 'B1AJG6', 'B8ELG8', 'Q4URD4', 'P47333', 'Q034X6', 'B1YRC5', 'B8E1C8', 'Q02VK8', 'P0A7S8', 'Q5L8A5', 'Q1CS69', 'Q8A472', 'Q3JMQ7', 'A4VSN1', 'Q6MJ11', 'Q1AU24', 'O70089', 'B4SKV8', 'P59164', 'Q9CL86', 'P0A7S4', 'Q72UA6', 'P62128', 'Q8PC54', 'P0A7S5', 'Q6A6L2', 'C1CC60', 'A2C4U8', 'P66379', 'Q65PB2', 'Q62GK0', 'Q0RRS6', 'A3NEI4', 'P0A0X4', 'Q83ES9', 'B1JU17', 'P9WH62', 'B0JSE3', 'P02368', 'Q9HWD0', 'A9KD36', 'A2SLG2', 'P0A4A7', 'A9ADI8', 'Q04ED4', 'A9NEN1', 'B0SSI2', 'P0A0X5', 'P62126', 'Q9X1J3', 'P30060', 'A5V607', 'Q054E0', 'P59165', 'B2FQ40', 'B2ISJ7', 'Q8VMU2', 'A2RP74', 'Q8PNS8', 'Q5GWS8', 'B1LBP5', 'Q64NK4', 'Q7V503', 'A0K3M0', 'A3P0B8', 'Q2S3R9', 'P30766', 'A4JAN5', 'B2JIH1', 'Q9XQE1', 'Q85BW6', 'Q4L3K6', 'A2CC84', 'B1HMZ3', 'Q39KH2', 'B3PMF1', 'P0A7S7', 'P63200', 'Q01W87', 'A5IM78', 'P12340', 'Q9F0R4', 'Q5WLR7', 'P63196', 'B0U5X5', 'P66370', 'A7Z0N2', 'Q2SU22', 'Q7NAV1', 'A4XBQ1', 'Q8CTS8', 'P74230', 'A2S7H1', 'Q04MH9', 'Q9PPW5', 'Q5L402', 'B4E5B5', 'C1A6P1 ...
# ['A0A0K0IP23', 'P22085', 'A5GNU1', 'Q7V5D4', 'Q0I762', 'Q46HU0', 'A2C698', 'A2BZQ6', 'Q7VEB3', 'Q3AH85', 'Q7U4A1', 'Q3AZX9', 'A9B9H1', 'A8FLR4', 'A1VZJ8', 'Q5HUU1', 'A7H3N3', 'Q0PA35', 'A6Q2W6', 'Q30RJ0', 'Q47ZE0', 'Q5WCI9', 'Q6F8N7', 'A3M846', 'Q5V630', 'Q3IRX3', 'Q18GK1', 'Q5V3D9', 'Q9HPY4', 'Q0AFN2', 'Q82XC3', 'B7KEP3', 'B2J442', 'B8HXS0', 'B0JUP8', 'Q8Z086', 'B1WRW8', 'Q3M9M0', 'Q7NJE8', 'B3EJG9', 'B4S820', 'A2BRP7', 'A2BX55', 'Q7TU81', 'Q31AF6', 'A8G5D8', 'A3PDH3', 'B4F1G5', 'A8GAY2', 'A4W7J0', 'Q8XCT6', 'B7L7F6', 'A4TP60', 'A8FTH7', 'B7NL23', 'B4RV70', 'B7N983', 'A6T5R4', 'B5EYE2', 'Q7CJY7', 'B2TTB0', 'Q8K979', 'B1JHI9', 'Q6D2E6', 'B5YPP4', 'B5R6X5', 'P24186', 'B1IZ72', 'Q5QWH6', 'Q3Z4P8', 'B7MRJ2', 'B6I0H4', 'A9MW26', 'Q89A92', 'Q8FK41', 'A6WLP9', 'A7ZIT8', 'B1KLT9', 'B5BCZ5', 'B8GNT6', 'C6DAX0', 'Q0HH99', 'A0KYM1', 'Q66DK7', 'Q32JK7', 'A1A8J4', 'B5FLQ2', 'Q83SC8', 'C4ZUX7', 'B4TN64', 'P58688', 'B0USU2', 'A1JNX2', 'Q0I3S5', 'B1XGC7', 'Q60006', 'Q324Y6', 'A1SUX5', 'A9R256', 'B7UKK6', 'C4K7E4', 'Q1QVV9', 'Q57S24', 'Q65RF1', 'C4LG01', 'Q1RF04', 'Q1C4U4', 'Q1CKX8', 'P57557', 'A7ZXI3', 'A8AJS4', 'P51696', 'Q493A0', 'A3QFX8', 'Q7MZH1', 'A9KWH5', 'B7ME52', 'B7LJI7', 'B1LKE8', 'Q5PCE5', 'C0PVJ3', 'B5Y0K4', 'B8E5F1', 'A7FL44', 'B4TA94', 'B7VL71', 'B4SXP7', 'B5QUV5', 'B7M4N2', 'A8H616', 'Q0TKB2', 'Q0T773', 'C5B8V3', 'B2K7N4', 'A9MLA4', 'A7MJZ6', 'A3DEE6', 'B9M769', 'Q74EU7', 'Q39WH4', 'A2C873', 'Q7TVA3', 'Q3AIB3', 'A9BB39', 'Q7TUV8', 'Q7TTW4', 'A5GM31', 'Q0IBG9', 'A5GRZ3', 'Q3AYX2', 'Q0BX67', 'Q6F9E6', 'Q0ATP0', 'B8E335', 'Q03YZ6', 'B1N044', 'A9KLS3', 'A1WJ68', 'Q21WC0', 'Q1AXT3', 'A1AL91', 'A8LWI0', 'Q82QG3', 'A1K589', 'Q47IX6', 'Q5P922', 'Q64RB7', 'A6L2G2', 'Q5LAX0', 'Q7MVE9', 'A6L8J2', 'Q8A7B8', 'B2A532', 'Q7VVW3', 'Q7W4Z7', 'B8I761', 'Q2GHD8', 'Q5HAK8', 'Q5FG00', 'Q3YRE3', 'Q7UNN9', 'Q11UD1', 'Q050D8', 'Q04SB2', 'Q8F523', 'Q72QT3', 'Q6MI74', 'Q14NV1', 'A0B8J7', 'Q2GCV3', 'O65271', 'O65269', 'A2RVV7', 'Q03FZ5', 'Q88WM8', 'Q03RR1', 'Q88LI7', 'Q73HK3', 'B3CLT4', 'C0R2N7', 'Q5GTK9', 'Q46A53', 'Q8PZQ1', 'Q12V26', 'Q8TK95', 'Q8EQ43', 'C5CXD8', 'A9NE96', 'A0RTU3', 'A9A4N5', 'B3ESU1', 'A8GNK0', 'A5IBF0', 'Q5ZVZ1', 'Q5X5Q9', 'Q5WX38', 'Q4ULM3', 'Q1RHV0', 'A8F1N1', 'Q9ZD32', 'C4K0H2', 'Q68WL9', 'A8GW74', 'Q92HY4', 'B0BXN7', 'C3PNI9', 'A8GS71', 'A8EYV5', 'A5CF58', 'B3CTT4', 'Q04FB7', 'Q7WAC0', 'A9ISZ5', 'Q7VZC8', 'Q7WJG1', 'Q8WZJ7', 'O43007', 'A6UB98', 'A9BWT7', 'A1W7S2', 'B9MIU6', 'A9AZP9', 'Q4ZUA4', 'B0KLM9', 'Q883B5', 'Q48HJ1', 'A4XY05', 'Q2SRE7', 'Q6F1V0', 'Q6MSL3', 'Q74GN1', 'Q39Z32', 'Q2S1I0', 'Q8RAD0', 'Q2YC56', 'Q7M8X1', 'A1BBS1', 'B9KLK2', 'A8LIR3', 'A1B5A7', 'Q3J049', 'A4WQ13', 'A8I5P5', 'Q2VYZ7', 'Q167Y9', 'A3PM50', 'Q1GE28', 'Q160C1', 'Q5LNV2', 'B1XUA6', 'A4SWT5', 'Q5FJG5', 'A8YVX0', 'Q1D7Y2', 'Q2P3R1', 'Q9PAR4', 'Q4UVC7', 'Q8PK86', 'B0RSB3', 'Q8P8Q4', 'Q3BSP5', 'B2SLG3', 'Q5H0S4', 'Q87BK4', 'A6VMD8', 'A5UAS4', 'A5UHL4', 'Q4QMI7', 'P44313', 'Q9CJR1', 'Q1J0I3', 'Q5M0P7', 'A5G1W5', 'Q03LK0', 'Q5M583', 'P96050', 'Q836W7', 'B9DUU0', 'Q04L84', 'Q3K2M6', 'B5XM84', 'Q8DVC1', 'C0R292', 'A7HDC5', 'Q2IQE1', 'Q1G9H1', 'Q049N0', 'Q2FI15', 'A8Z1K5', 'Q5HH21', 'A6QFS2', 'Q2FZJ6', 'Q4L572', 'Q49WI7', 'Q8CPP4', 'B9EAY2', 'Q6GAF0', 'Q99V34', 'Q5HQA7', 'Q6GI21', 'B9DQ45', 'A6U0N1', 'Q8NX95', 'A5IRV0', 'Q7A697', 'A7X0V3', 'Q2YX11', 'Q8RDM4', 'Q38XU9', 'Q057D7', 'Q17W13', 'P56467', 'Q1CTU9', 'Q9ZLQ4', 'B9L952', 'B2V9R3', 'B0KJG3', 'B7VB83', 'Q9I2U6', 'A6V726', 'Q4ZVN1', 'A1KWF4', 'Q02KT7', 'A4VL74', 'Q88KM5', 'B4RQN5', 'Q9JWI9', 'C1D5X9', 'B1J675', 'Q4K9J4', 'P0C277', 'Q47XL6', 'Q87YR0', 'C1DHE7', 'Q15R43', 'Q5F5D0', 'A9M068', 'A0KJD4', 'A5W638', 'Q3K9W7', 'Q48KZ8', 'Q1ICB3', 'Q3J8Z0', 'A4XTZ3', 'A9KGQ5', 'B6J1Z2', 'A9NB47', 'Q3SKX9', 'Q83EK7', 'Q1GXE6', 'Q7VGF6', 'Q10X46', 'B0C3J3', 'B7JVV5', 'B6YRQ9', 'A5WGG4', 'B3PHG5', 'Q1QD30', 'Q4FTX6', 'C1F683', 'A6W1T1', 'C5BI30', 'Q0VQ92', 'Q21JE9', 'C4L3F6', 'O67736', 'B8F605', 'Q31FY5', 'Q6G4F1', 'Q6G0I9', 'A9IQD2', 'A1URL6', 'B5YA73', 'A8MKZ5', 'Q189R8', 'C4ZBG7', 'C0QAY0', 'Q3AAY6', 'A7FT56', 'C1FK ...

# %% [markdown]
# proteins in test set/#proteins in full set, should be roughly 0.1.

# %%
cnt = len(clusters.loc[clusters['Accession'].isin(test_seqs)])

cnt / len(clusters)
# Out:
# 0.07944742900997698

# %%
list(set(test_seqs) & set(trainval_seqs)) # check no intersection
# Out:
# []

# %%
# check if the two sets contain all data
len(test_seqs) + len(trainval_seqs)
# Out:
# 177794

# %%
[i for i in trainval_seqs if i in test_]
# Out:
# []

# %% [markdown]
# # refine the test set
# make sure every metal label appears in the test set.

# %%
new_test_seqs = test_seqs.copy()
new_trainval_seqs = trainval_seqs.copy()


for i, v in init_stat.items():
  print(f'check for {i}')
  print(f'initial number is {v[0]}, percentage is {v[1]}')
  if v[1] == 0 and v[0]:
    for seq in seqs:
      if seq in new_trainval_seqs:
        if ((seq_metal['Accession'] == seq) & (seq_metal['ChEBI-ID'] == i)).any():
          new_trainval_seqs.remove(seq)
          new_test_seqs.append(seq)
          print(f'{seq} -> test')
          new_per = check_metal(new_test_seqs, i)
          print(f'updated percentage is {new_per}')
          break
# Out:
# check for CHEBI:29105
# initial number is 573, percentage is 0.09899792674498964
# check for CHEBI:29108
# initial number is 471, percentage is 0.09878355704697987
# check for CHEBI:18420
# initial number is 208, percentage is 0.09719626168224299
# check for CHEBI:29035
# initial number is 108, percentage is 0.09507042253521127
# check for CHEBI:24875
# initial number is 88, percentage is 0.0957562568008705
# check for CHEBI:49883
# initial number is 84, percentage is 0.09491525423728814
# check for CHEBI:60240
# initial number is 68, percentage is 0.0921409214092141
# check for CHEBI:23378
# initial number is 60, percentage is 0.10695187165775401
# check for CHEBI:190135
# initial number is 29, percentage is 0.08333333333333333
# check for CHEBI:29103
# initial number is 24, percentage is 0.147239263803681
# check for CHEBI:29101
# initial number is 22, percentage is 0.15492957746478872
# check for CHEBI:29034
# initial number is 20, percentage is 0.14705882352941177
# check for CHEBI:49786
# initial number is 18, percentage is 0.23376623376623376
# check for CHEBI:48828
# initial number is 4, percentage is 0.08
# check for CHEBI:48775
# initial number is 0, percentage is 0.0
# I6X7F9 -> test
# updated percentage is 0.08
# Q9LZF1 -> test
# updated percentage is 0.16
# P33187 -> test
# updated percentage is 0.88
# P54512 -> test
# updated percentage is 1.0
# check for CHEBI:21137
# initial number is 6, percentage is 0.16666666666666666
# check for CHEBI:29036
# initial number is 0, percentage is 0.0
# P0C178 -> test
# updated percentage is 0.24242424242424243
# P05067 -> test
# updated percentage is 0.5151515151515151
# E3YBA4 -> test
# updated percentage is 0.6363636363636364
# P56274 -> test
# updated percentage is 0.8787878787878788
# P02771 -> test
# updated percentage is 0.9090909090909091
# P04156 -> test
# updated percentage is 1.0
# check for CHEBI:49552
# initial number is 4, percentage is 0.14814814814814814
# check for CHEBI:29033
# initial number is 0, percentage is 0.0
# P05326 -> test
# updated percentage is 0.13636363636363635
# Q9BV57 -> test
# updated percentage is 0.3181818181818182
# P29166 -> test
# updated percentage is 0.36363636363636365
# P25524 -> test
# updated percentage is 0.5454545454545454
# Q9ZFE7 -> test
# updated percentage is 0.9090909090909091
# P07598 -> test
# updated percentage is 1.0
# check for CHEBI:47739
# initial number is 6, percentage is 0.5
# check for CHEBI:177874
# initial number is 6, percentage is 1.0
# check for CHEBI:49415
# initial number is 4, percentage is 1.0
# check for CHEBI:16793
# initial number is 2, percentage is 1.0

# %%
list(set(new_test_seqs) & set(new_trainval_seqs)) # check no intersection
# Out:
# []

# %% [markdown]
# ## Final proportions

# %%
dataset_metal_binding_summary(trainval_seqs, source = 'POS_TRAIN_FULL.tsv')
pass
# Out:
# total seq in the set: 162266
# CHEBI:29105  |Zn(2+)                        |#p:        630|#residue:   5777|%residue/all: 0.0432
# CHEBI:18420  |Mg(2+)                        |#p:        454|#residue:   2160|%residue/all: 0.0242
# CHEBI:49883  |[4Fe-4S] cluster              |#p:         96|#residue:    832|%residue/all: 0.0161
# CHEBI:29108  |Ca(2+)                        |#p:        346|#residue:   4647|%residue/all:  0.11
# CHEBI:29035  |Mn(2+)                        |#p:        164|#residue:   1072|%residue/all: 0.0478
# CHEBI:60240  |a divalent metal cation       |#p:         74|#residue:    664|%residue/all: 0.0365
# CHEBI:24875  |Fe cation                     |#p:        149|#residue:    945|%residue/all: 0.0542
# CHEBI:190135 |[2Fe-2S] cluster              |#p:         47|#residue:    327|%residue/all: 0.0362
# CHEBI:23378  |Cu cation                     |#p:         66|#residue:    434|%residue/all: 0.0587
# CHEBI:29103  |K(+)                          |#p:         21|#residue:    155|%residue/all: 0.0247
# CHEBI:49786  |Ni(2+)                        |#p:         14|#residue:     87|%residue/all: 0.0256
# CHEBI:29101  |Na(+)                         |#p:         17|#residue:    130|%residue/all: 0.0582
# CHEBI:29034  |Fe(3+)                        |#p:         13|#residue:    162|%residue/all: 0.0976
# CHEBI:30408  |iron-sulfur cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:29036  |Cu(2+)                        |#p:          6|#residue:     41|%residue/all: 0.0439
# CHEBI:29033  |Fe(2+)                        |#p:          4|#residue:     22|%residue/all: 0.0264
# CHEBI:21137  |[3Fe-4S] cluster              |#p:          5|#residue:     24|%residue/all: 0.0471
# CHEBI:49552  |Cu(+)                         |#p:          5|#residue:     51|%residue/all: 0.139
# CHEBI:48775  |Cd(2+)                        |#p:          3|#residue:     50|%residue/all: 0.139
# CHEBI:48828  |Co(2+)                        |#p:         10|#residue:     43|%residue/all: 0.188
# CHEBI:21143  |[8Fe-7S] cluster              |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:25213  |a metal cation                |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:47739  |[Ni-4Fe-4S] cluster           |#p:          1|#residue:     10|%residue/all: 0.0943
# CHEBI:16793  |Hg(2+)                        |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:177874 |[Ni-4Fe-5S] cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:60400  |[Ni-Fe-S] cluster             |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49415  |Co(3+)                        |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:60504  |[8Fe-9S-C-homocitryl] cluster |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49713  |Li(+)                         |#p:          1|#residue:      2|%residue/all: 0.333
# #non-binding protein: 160390

# %%
dataset_metal_binding_summary(test_seqs, source = 'POS_TRAIN_FULL.tsv')
pass
# Out:
# total seq in the set: 15528
# CHEBI:29105  |Zn(2+)                        |#p:         80|#residue:    680|%residue/all: 0.00508
# CHEBI:18420  |Mg(2+)                        |#p:         54|#residue:    263|%residue/all: 0.00294
# CHEBI:49883  |[4Fe-4S] cluster              |#p:         14|#residue:    102|%residue/all: 0.00198
# CHEBI:29108  |Ca(2+)                        |#p:         53|#residue:    522|%residue/all: 0.0124
# CHEBI:29035  |Mn(2+)                        |#p:         20|#residue:    119|%residue/all: 0.0053
# CHEBI:60240  |a divalent metal cation       |#p:          5|#residue:     92|%residue/all: 0.00506
# CHEBI:24875  |Fe cation                     |#p:         14|#residue:    103|%residue/all: 0.0059
# CHEBI:190135 |[2Fe-2S] cluster              |#p:          6|#residue:     54|%residue/all: 0.00598
# CHEBI:23378  |Cu cation                     |#p:         11|#residue:    129|%residue/all: 0.0174
# CHEBI:29103  |K(+)                          |#p:          1|#residue:     12|%residue/all: 0.00192
# CHEBI:49786  |Ni(2+)                        |#p:          1|#residue:      6|%residue/all: 0.00177
# CHEBI:29101  |Na(+)                         |#p:          3|#residue:     22|%residue/all: 0.00985
# CHEBI:29034  |Fe(3+)                        |#p:          3|#residue:     14|%residue/all: 0.00844
# CHEBI:30408  |iron-sulfur cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:29036  |Cu(2+)                        |#p:          1|#residue:      1|%residue/all: 0.00107
# CHEBI:29033  |Fe(2+)                        |#p:          1|#residue:      4|%residue/all: 0.00481
# CHEBI:21137  |[3Fe-4S] cluster              |#p:          2|#residue:     19|%residue/all: 0.0373
# CHEBI:49552  |Cu(+)                         |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:48775  |Cd(2+)                        |#p:          1|#residue:      4|%residue/all: 0.0111
# CHEBI:48828  |Co(2+)                        |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:21143  |[8Fe-7S] cluster              |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:25213  |a metal cation                |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:47739  |[Ni-4Fe-4S] cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:16793  |Hg(2+)                        |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:177874 |[Ni-4Fe-5S] cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:60400  |[Ni-Fe-S] cluster             |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49415  |Co(3+)                        |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:60504  |[8Fe-9S-C-homocitryl] cluster |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49713  |Li(+)                         |#p:          0|#residue:      0|%residue/all:   0.0
# #non-binding protein: 15311

# %%
cnt = len(clusters.loc[clusters['Accession'].isin(new_test_seqs)])

cnt / len(clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-d575029402cf> in <module>
# ----> 1 cnt = len(clusters.loc[clusters['Accession'].isin(new_test_seqs)])
#       2
#       3 cnt / len(clusters)
#
# NameError: name 'new_test_seqs' is not defined

# %%
len(new_test_seqs)
# Out:
# 16838

# %%
len(new_trainval_seqs)
# Out:
# 178612

# %% [markdown]
# # Write trainval and test set in fasta format
# TEST_POS_NEG.fasta: test proteins \
# MY_TRAIN_POS_NEG.fasta: trainval proteins

# %%
dataset_metal_binding_summary(new_test_seqs, source = 'POS_TRAIN_FULL.tsv')
pass
# Out:
# total seq in the set: 16838
# CHEBI:29105  |Zn(2+)                        |#p:         86|#residue:    738|%residue/all: 0.00552
# CHEBI:18420  |Mg(2+)                        |#p:         68|#residue:    286|%residue/all: 0.0032
# CHEBI:49883  |[4Fe-4S] cluster              |#p:         16|#residue:    110|%residue/all: 0.00213
# CHEBI:29108  |Ca(2+)                        |#p:         31|#residue:    575|%residue/all: 0.0136
# CHEBI:29035  |Mn(2+)                        |#p:         22|#residue:    140|%residue/all: 0.00624
# CHEBI:60240  |a divalent metal cation       |#p:         12|#residue:    102|%residue/all: 0.00561
# CHEBI:24875  |Fe cation                     |#p:         17|#residue:    115|%residue/all: 0.00659
# CHEBI:190135 |[2Fe-2S] cluster              |#p:          8|#residue:     51|%residue/all: 0.00564
# CHEBI:23378  |Cu cation                     |#p:          9|#residue:     78|%residue/all: 0.0105
# CHEBI:29103  |K(+)                          |#p:          3|#residue:     24|%residue/all: 0.00383
# CHEBI:49786  |Ni(2+)                        |#p:          2|#residue:     12|%residue/all: 0.00353
# CHEBI:29101  |Na(+)                         |#p:          3|#residue:     22|%residue/all: 0.00985
# CHEBI:29034  |Fe(3+)                        |#p:          3|#residue:     20|%residue/all: 0.0121
# CHEBI:30408  |iron-sulfur cluster           |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:29036  |Cu(2+)                        |#p:          3|#residue:     12|%residue/all: 0.0128
# CHEBI:29033  |Fe(2+)                        |#p:          2|#residue:      8|%residue/all: 0.00962
# CHEBI:21137  |[3Fe-4S] cluster              |#p:          2|#residue:     12|%residue/all: 0.0235
# CHEBI:49552  |Cu(+)                         |#p:          1|#residue:      4|%residue/all: 0.0109
# CHEBI:48775  |Cd(2+)                        |#p:          1|#residue:      6|%residue/all: 0.0166
# CHEBI:48828  |Co(2+)                        |#p:          2|#residue:     10|%residue/all: 0.0437
# CHEBI:21143  |[8Fe-7S] cluster              |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:25213  |a metal cation                |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:47739  |[Ni-4Fe-4S] cluster           |#p:          1|#residue:      6|%residue/all: 0.0566
# CHEBI:16793  |Hg(2+)                        |#p:          1|#residue:      4|%residue/all: 0.0444
# CHEBI:177874 |[Ni-4Fe-5S] cluster           |#p:          1|#residue:      6|%residue/all: 0.118
# CHEBI:60400  |[Ni-Fe-S] cluster             |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49415  |Co(3+)                        |#p:          1|#residue:      4|%residue/all:  0.25
# CHEBI:60504  |[8Fe-9S-C-homocitryl] cluster |#p:          0|#residue:      0|%residue/all:   0.0
# CHEBI:49713  |Li(+)                         |#p:          0|#residue:      0|%residue/all:   0.0
# #non-binding protein: 16602

# %%
file_out = 'TEST_POS_NEG1.fasta'
write_seq_ls2fasta(file_out, new_test_seqs, 'combined.fasta')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# writing Q5UQ35 to train fasta file.
# writing Q5UQC3 to train fasta file.
# writing Q5UQG2 to train fasta file.
# writing Q5UQW2 to train fasta file.
# writing Q5UR69 to train fasta file.
# writing Q5UX65 to train fasta file.
# writing Q5UYF3 to train fasta file.
# writing Q5UYQ8 to train fasta file.
# writing Q5UZ63 to train fasta file.
# writing Q5UZW0 to train fasta file.
# writing Q5V0S8 to train fasta file.
# writing Q5V1N9 to train fasta file.
# writing Q5V2D3 to train fasta file.
# writing Q5V2S1 to train fasta file.
# writing Q5V3P6 to train fasta file.
# writing Q5V474 to train fasta file.
# writing Q5V4R4 to train fasta file.
# writing Q5V518 to train fasta file.
# writing Q5V5G2 to train fasta file.
# writing Q5VVJ2 to train fasta file.
# writing Q5W283 to train fasta file.
# writing Q5WBJ6 to train fasta file.
# writing Q5WCF2 to train fasta file.
# writing Q5WDF8 to train fasta file.
# writing Q5WDH1 to train fasta file.
# writing Q5WDX3 to train fasta file.
# writing Q5WDZ8 to train fasta file.
# writing Q5WE80 to train fasta file.
# writing Q5WEJ5 to train fasta file.
# writing Q5WEM4 to train fasta file.
# writing Q5WEN5 to train fasta file.
# writing Q5WER0 to train fasta file.
# writing Q5WFA2 to train fasta file.
# writing Q5WFI3 to train fasta file.
# writing Q5WGA3 to train fasta file.
# writing Q5WGS7 to train fasta file.
# writing Q5WHE2 to train fasta file.
# writing Q5WIY8 to train fasta file.
# writing Q5WJ32 to train fasta file.
# writing Q5WJ86 to train fasta file.
# writing Q5WJU6 to train fasta file.
# writing Q5WKB6 to train fasta file.
# writing Q5WKE7 to train fasta file.
# writing Q5WKJ3 to train fasta file.
# writing Q5WKY5 to train fasta file.
# writing Q5WL08 to train fasta file.
# writing Q5WL39 to train fasta file.
# writing Q5WLE9 to train fasta file.
# writing Q5WLP9 to train fasta file.
# writing Q5WNE3 to train fasta file.
# writing Q5WPZ8 to train fasta file.
# writing Q5WSL6 to train fasta file.
# writing Q5WT82 to train fasta file.
# writing Q5WT86 to train fasta file.
# writing Q5WTD7 to train fasta file.
# writing Q5WTW4 to train fasta file.
# writing Q5WTW9 to train fasta file.
# writing Q5WTX7 to train fasta file.
# writing Q5WV18 to train fasta file.
# writing Q5WVI4 to train fasta file.
# writing Q5WW59 to train fasta file.
# writing Q5WW88 to train fasta file.
# writing Q5WWH4 to train fasta file.
# writing Q5WXX1 to train fasta file.
# writing Q5WXX5 to train fasta file.
# writing Q5WYJ0 to train fasta file.
# writing Q5WYK1 to train fasta file.
# writing Q5WYQ0 to train fasta file.
# writing Q5WZJ9 to train fasta file.
# writing Q5WZW1 to train fasta file.
# writing Q5X0U5 to train fasta file.
# writing Q5X1H3 to train fasta file.
# writing Q5X1H7 to train fasta file.
# writing Q5X1M8 to train fasta file.
# writing Q5X240 to train fasta file.
# writing Q5X245 to train fasta file.
# writing Q5X252 to train fasta file.
# writing Q5X3N0 to train fasta file.
# writing Q5X446 to train fasta file.
# writing Q5X516 to train fasta file.
# writing Q5X5A1 to train fasta file.
# writing Q5X5C5 to train fasta file.
# writing Q5X5H7 to train fasta file.
# writing Q5X6G6 to train fasta file.
# writing Q5X6H0 to train fasta file.
# writing Q5X739 to train fasta file.
# writing Q5X741 to train fasta file.
# writing Q5X752 to train fasta file.
# writing Q5X7A1 to train fasta file.
# writing Q5X846 to train fasta file.
# writing Q5X8H6 to train fasta file.
# writing Q5X9V1 to train fasta file.
# writing Q5XAA2 to train fasta file.
# writing Q5XAP6 to train fasta file.
# writing Q5XAQ1 to train fasta file.
# writing Q5XAZ6 to train fasta file.
# writing Q5XBJ6 to train fasta file.
# writing Q5XCH0 to train fasta file.
# writing Q5XCL9 to train fasta file.
# writing Q5XCM6 to train fasta file.
# writing Q5XCX4 to train fasta file.
# writing Q5XD71 to train fasta file.
# writing Q5XD73 to train fasta file.
# writing Q5XDG5 to train fasta file.
# writing Q5XDN3 to train fasta file.
# writing Q5XDP8 to train fasta file.
# writing Q5XEC2 to train fasta file.
# writing Q5XEL6 to train fasta file.
# writing Q5XEN5 to train fasta file.
# writing Q5XF51 to train fasta file.
# writing Q5XH73 to train fasta file.
# writing Q5XID1 to train fasta file.
# writing Q5XIP6 to train fasta file.
# writing Q5XJA0 to train fasta file.
# writing Q5XUN4 to train fasta file.
# writing Q5XUW8 to train fasta file.
# writing Q5XXA6 to train fasta file.
# writing Q5YB40 to train fasta file.
# writing Q5YNI2 to train fasta file.
# writing Q5YQW3 to train fasta file.
# writing Q5YQZ5 to train fasta file.
# writing Q5YRX2 to train fasta file.
# writing Q5YRY0 to train fasta file.
# writing Q5YS67 to train fasta file.
# writing Q5YTN0 to train fasta file.
# writing Q5YUH4 to train fasta file.
# writing Q5YV93 to train fasta file.
# writing Q5YW75 to train fasta file.
# writing Q5YXN4 to train fasta file.
# writing Q5YYB6 to train fasta file.
# writing Q5YYH7 to train fasta file.
# writing Q5YYS5 to train fasta file.
# writing Q5YZ37 to train fasta file.
# writing Q5YZ95 to train fasta file.
# writing Q5Z0D8 to train fasta file.
# writing Q5Z0V0 to train fasta file.
# writing Q5Z0Z3 to train fasta file.
# writing Q5Z1R9 to train fasta file.
# writing Q5Z2C3 to train fasta file.
# writing Q5Z2N2 to train fasta file.
# writing Q5Z380 to train fasta file.
# writing Q5Z6F5 to train fasta file.
# writing Q5Z818 to train fasta file.
# writing Q5ZCK5 to train fasta file.
# writing Q5ZD81 to train fasta file.
# writing Q5ZE00 to train fasta file.
# writing Q5ZE07 to train fasta file.
# writing Q5ZJA2 to train fasta file.
# writing Q5ZK03 to train fasta file.
# writing Q5ZL43 to train fasta file.
# writing Q5ZLN4 to train fasta file.
# writing Q5ZLP2 to train fasta file.
# writing Q5ZLY5 to train fasta file.
# writing Q5ZM25 to train fasta file.
# writing Q5ZM44 to train fasta file.
# writing Q5ZM96 to train fasta file.
# writing Q5ZMD4 to train fasta file.
# writing Q5ZPI9 to train fasta file.
# writing Q5ZRE9 to train fasta file.
# writing Q5ZS05 to train fasta file.
# writing Q5ZS08 to train fasta file.
# writing Q5ZS58 to train fasta file.
# writing Q5ZSM8 to train fasta file.
# writing Q5ZSN3 to train fasta file.
# writing Q5ZSP1 to train fasta file.
# writing Q5ZSQ2 to train fasta file.
# writing Q5ZTK6 to train fasta file.
# writing Q5ZTY6 to train fasta file.
# writing Q5ZUD5 to train fasta file.
# writing Q5ZV93 to train fasta file.
# writing Q5ZVH7 to train fasta file.
# writing Q5ZVK0 to train fasta file.
# writing Q5ZWZ6 to train fasta file.
# writing Q5ZX00 to train fasta file.
# writing Q5ZXM2 to train fasta file.
# writing Q5ZXN3 to train fasta file.
# writing Q5ZXT1 to train fasta file.
# writing Q5ZYN0 to train fasta file.
# writing Q5ZYZ5 to train fasta file.
# writing Q601K1 to train fasta file.
# writing Q601U6 to train fasta file.
# writing Q602K0 to train fasta file.
# writing Q602P0 to train fasta file.
# writing Q60316 to train fasta file.
# writing Q60337 to train fasta file.
# writing Q60338 to train fasta file.
# writing Q603C0 to train fasta file.
# writing Q603C7 to train fasta file.
# writing Q60452 to train fasta file.
# writing Q604W0 to train fasta file.
# writing Q60560 to train fasta file.
# writing Q60561 to train fasta file.
# writing Q605H0 to train fasta file.
# writing Q605M0 to train fasta file.
# writing Q605M7 to train fasta file.
# writing Q606C8 to train fasta file.
# writing Q606F2 to train fasta file.
# writing Q60790 to train fasta file.
# writing Q607S5 to train fasta file.
# writing Q60857 to train fasta file.
# writing Q608M7 to train fasta file.
# writing Q608N3 to train fasta file.
# writing Q609C6 to train fasta file.
# writing Q60AZ0 to train fasta file.
# writing Q60AZ3 to train fasta file.
# writing Q60B95 to train fasta file.
# writing Q60BF9 to train fasta file.
# writing Q60BY2 to train fasta file.
# writing Q60BZ1 to train fasta file.
# writing Q60CG7 to train fasta file.
# writing Q60CT7 to train fasta file.
# writing Q61147 to train fasta file.
# writing Q61233 to train fasta file.
# writing Q61282 to train fasta file.
# writing Q61327 to train fasta file.
# writing Q61409 to train fasta file.
# writing Q61824 to train fasta file.
# writing Q61909 to train fasta file.
# writing Q61CX7 to train fasta file.
# writing Q61P40 to train fasta file.
# writing Q61UC4 to train fasta file.
# writing Q61XX9 to train fasta file.
# writing Q62158 to train fasta file.
# writing Q62240 to train fasta file.
# writing Q626B1 to train fasta file.
# writing Q62865 to train fasta file.
# writing Q62897 to train fasta file.
# writing Q62976 to train fasta file.
# writing Q62AI6 to train fasta file.
# writing Q62CD5 to train fasta file.
# writing Q62EN9 to train fasta file.
# writing Q62EZ1 to train fasta file.
# writing Q62GA9 to train fasta file.
# writing Q62GB0 to train fasta file.
# writing Q62GS9 to train fasta file.
# writing Q62HD8 to train fasta file.
# writing Q62HL4 to train fasta file.
# writing Q62HM6 to train fasta file.
# writing Q62HU9 to train fasta file.
# writing Q62HZ7 to train fasta file.
# writing Q62IG0 to train fasta file.
# writing Q62JI6 to train fasta file.
# writing Q62JM7 to train fasta file.
# writing Q62JW2 to train fasta file.
# writing Q62KI6 to train fasta file.
# writing Q62LZ2 to train fasta file.
# writing Q62ML1 to train fasta file.
# writing Q63085 to train fasta file.
# writing Q631G4 to train fasta file.
# writing Q631J0 to train fasta file.
# writing Q632S5 to train fasta file.
# writing Q63321 to train fasta file.
# writing Q633N4 to train fasta file.
# writing Q633Q1 to train fasta file.
# writing Q633V5 to train fasta file.
# writing Q633X5 to train fasta file.
# writing Q633Z0 to train fasta file.
# writing Q634M8 to train fasta file.
# writing Q634N8 to train fasta file.
# writing Q63598 to train fasta file.
# writing Q635G3 to train fasta file.
# writing Q635G7 to train fasta file.
# writing Q635S6 to train fasta file.
# writing Q636D1 to train fasta file.
# writing Q636G2 to train fasta file.
# writing Q63713 to train fasta file.
# writing Q637V9 to train fasta file.
# writing Q63802 to train fasta file.
# writing Q63810 to train fasta file.
# writing Q63811 to train fasta file.
# writing Q63871 to train fasta file.
# writing Q63881 to train fasta file.
# writing Q63AC7 to train fasta file.
# writing Q63CC5 to train fasta file.
# writing Q63DJ3 to train fasta file.
# writing Q63DL5 to train fasta file.
# writing Q63DN3 to train fasta file.
# writing Q63DX6 to train fasta file.
# writing Q63EM3 to train fasta file.
# writing Q63FR0 to train fasta file.
# writing Q63GK3 to train fasta file.
# writing Q63GS5 to train fasta file.
# writing Q63GT3 to train fasta file.
# writing Q63GW6 to train fasta file.
# writing Q63H77 to train fasta file.
# writing Q63HN8 to train fasta file.
# writing Q63JB1 to train fasta file.
# writing Q63JK9 to train fasta file.
# writing Q63KP6 to train fasta file.
# writing Q63L05 to train fasta file.
# writing Q63NL2 to train fasta file.
# writing Q63Q56 to train fasta file.
# writing Q63Q57 to train fasta file.
# writing Q63QJ9 to train fasta file.
# writing Q63R49 to train fasta file.
# writing Q63RP1 to train fasta file.
# writing Q63RV4 to train fasta file.
# writing Q63RX6 to train fasta file.
# writing Q63T71 to train fasta file.
# writing Q63TM6 to train fasta file.
# writing Q63UT5 to train fasta file.
# writing Q63V22 to train fasta file.
# writing Q63VY0 to train fasta file.
# writing Q63WI3 to train fasta file.
# writing Q63X65 to train fasta file.
# writing Q63Y74 to train fasta file.
# writing Q63YH5 to train fasta file.
# writing Q640V9 to train fasta file.
# writing Q641A1 to train fasta file.
# writing Q641Y7 to train fasta file.
# writing Q641Z8 to train fasta file.
# writing Q64442 to train fasta file.
# writing Q64521 to train fasta file.
# writing Q64620 to train fasta file.
# writing Q64898 to train fasta file.
# writing Q64962 to train fasta file.
# writing Q64MA3 to train fasta file.
# writing Q64MG2 to train fasta file.
# writing Q64QP1 to train fasta file.
# writing Q64R71 to train fasta file.
# writing Q64SX6 to train fasta file.
# writing Q64U20 to train fasta file.
# writing Q64UB9 to train fasta file.
# writing Q64UN4 to train fasta file.
# writing Q64V41 to train fasta file.
# writing Q64VP2 to train fasta file.
# writing Q64XF4 to train fasta file.
# writing Q64XF8 to train fasta file.
# writing Q64XI2 to train fasta file.
# writing Q64YJ1 to train fasta file.
# writing Q650L4 to train fasta file.
# writing Q65217 to train fasta file.
# writing Q652Z7 to train fasta file.
# writing Q653T6 to train fasta file.
# writing Q653Z5 to train fasta file.
# writing Q65CX5 to train fasta file.
# writing Q65D09 to train fasta file.
# writing Q65DK0 to train fasta file.
# writing Q65DU5 to train fasta file.
# writing Q65E18 to train fasta file.
# writing Q65EC5 to train fasta file.
# writing Q65EF0 to train fasta file.
# writing Q65FV8 to train fasta file.
# writing Q65GC3 to train fasta file.
# writing Q65GD2 to train fasta file.
# writing Q65GG3 to train fasta file.
# writing Q65GJ0 to train fasta file.
# writing Q65GJ7 to train fasta file.
# writing Q65GL3 to train fasta file.
# writing Q65H70 to train fasta file.
# writing Q65I10 to train fasta file.
# writing Q65I29 to train fasta file.
# writing Q65I56 to train fasta file.
# writing Q65IJ4 to train fasta file.
# writing Q65JP3 to train fasta file.
# writing Q65JS3 to train fasta file.
# writing Q65JV7 to train fasta file.
# writing Q65KJ5 to train fasta file.
# writing Q65KT8 to train fasta file.
# writing Q65L57 to train fasta file.
# writing Q65LN0 to train fasta file.
# writing Q65MK9 to train fasta file.
# writing Q65ML0 to train fasta file.
# writing Q65MR4 to train fasta file.
# writing Q65MS8 to train fasta file.
# writing Q65N43 to train fasta file.
# writing Q65P94 to train fasta file.
# writing Q65PY0 to train fasta file.
# writing Q65Q25 to train fasta file.
# writing Q65Q26 to train fasta file.
# writing Q65R35 to train fasta file.
# writing Q65R87 to train fasta file.
# writing Q65RB5 to train fasta file.
# writing Q65RQ2 to train fasta file.
# writing Q65RQ6 to train fasta file.
# writing Q65RX3 to train fasta file.
# writing Q65RY9 to train fasta file.
# writing Q65SC6 to train fasta file.
# writing Q65T54 to train fasta file.
# writing Q65TL2 to train fasta file.
# writing Q65TL6 to train fasta file.
# writing Q65TQ0 to train fasta file.
# writing Q65US7 to train fasta file.
# writing Q65UT4 to train fasta file.
# writing Q65V07 to train fasta file.
# writing Q65VF5 to train fasta file.
# writing Q65VN5 to train fasta file.
# writing Q65VP5 to train fasta file.
# writing Q65VS0 to train fasta file.
# writing Q65VS6 to train fasta file.
# writing Q65W13 to train fasta file.
# writing Q65W71 to train fasta file.
# writing Q65WK8 to train fasta file.
# writing Q65X71 to train fasta file.
# writing Q65XK0 to train fasta file.
# writing Q660F3 to train fasta file.
# writing Q660S3 to train fasta file.
# writing Q660X2 to train fasta file.
# writing Q661C9 to train fasta file.
# writing Q661P3 to train fasta file.
# writing Q661Q3 to train fasta file.
# writing Q662B8 to train fasta file.
# writing Q662L1 to train fasta file.
# writing Q662V4 to train fasta file.
# writing Q662W7 to train fasta file.
# writing Q663A2 to train fasta file.
# writing Q663Y3 to train fasta file.
# writing Q66431 to train fasta file.
# writing Q664K0 to train fasta file.
# writing Q664M0 to train fasta file.
# writing Q665I5 to train fasta file.
# writing Q66662 to train fasta file.
# writing Q666P5 to train fasta file.
# writing Q667S4 to train fasta file.
# writing Q667V1 to train fasta file.
# writing Q667V4 to train fasta file.
# writing Q667Y0 to train fasta file.
# writing Q667Z6 to train fasta file.
# writing Q668B9 to train fasta file.
# writing Q669E1 to train fasta file.
# writing Q669K2 to train fasta file.
# writing Q669P5 to train fasta file.
# writing Q669Z0 to train fasta file.
# writing Q669Z5 to train fasta file.
# writing Q66A78 to train fasta file.
# writing Q66AP0 to train fasta file.
# writing Q66BW8 to train fasta file.
# writing Q66C80 to train fasta file.
# writing Q66DD5 to train fasta file.
# writing Q66DS5 to train fasta file.
# writing Q66DY2 to train fasta file.
# writing Q66ED3 to train fasta file.
# writing Q66EG0 to train fasta file.
# writing Q66EG3 to train fasta file.
# writing Q66EJ3 to train fasta file.
# writing Q66EJ6 to train fasta file.
# writing Q66EK3 to train fasta file.
# writing Q66EM3 to train fasta file.
# writing Q66ES4 to train fasta file.
# writing Q66EU4 to train fasta file.
# writing Q66FF4 to train fasta file.
# writing Q66FF5 to train fasta file.
# writing Q66FP0 to train fasta file.
# writing Q66FS1 to train fasta file.
# writing Q66FT7 to train fasta file.
# writing Q66G37 to train fasta file.
# writing Q66G80 to train fasta file.
# writing Q66GD6 to train fasta file.
# writing Q66H71 to train fasta file.
# writing Q66H96 to train fasta file.
# writing Q66I75 to train fasta file.
# writing Q66JG0 to train fasta file.
# writing Q66JG8 to train fasta file.
# writing Q66JT0 to train fasta file.
# writing Q66L17 to train fasta file.
# writing Q66S03 to train fasta file.
# writing Q66V72 to train fasta file.
# writing Q67590 to train fasta file.
# writing Q67591 to train fasta file.
# writing Q67622 to train fasta file.
# writing Q67704 to train fasta file.
# writing Q67878 to train fasta file.
# writing Q67925 to train fasta file.
# writing Q67JV6 to train fasta file.
# writing Q67KF8 to train fasta file.
# writing Q67LA3 to train fasta file.
# writing Q67MD4 to train fasta file.
# writing Q67MJ2 to train fasta file.
# writing Q67N09 to train fasta file.
# writing Q67N10 to train fasta file.
# writing Q67NT4 to train fasta file.
# writing Q67PQ7 to train fasta file.
# writing Q67Q27 to train fasta file.
# writing Q67QF3 to train fasta file.
# writing Q67S27 to train fasta file.
# writing Q67SI7 to train fasta file.
# writing Q67SL4 to train fasta file.
# writing Q67T48 to train fasta file.
# writing Q67T83 to train fasta file.
# writing Q67T90 to train fasta file.
# writing Q67TD7 to train fasta file.
# writing Q67UX7 to train fasta file.
# writing Q67VC8 to train fasta file.
# writing Q67Z07 to train fasta file.
# writing Q680A5 to train fasta file.
# writing Q680K2 to train fasta file.
# writing Q682T9 to train fasta file.
# writing Q68BJ6 to train fasta file.
# writing Q68BJ7 to train fasta file.
# writing Q68D06 to train fasta file.
# writing Q68DK2 to train fasta file.
# writing Q68EI3 to train fasta file.
# writing Q68FU1 to train fasta file.
# writing Q68RV5 to train fasta file.
# writing Q68S16 to train fasta file.
# writing Q68VQ4 to train fasta file.
# writing Q68W16 to train fasta file.
# writing Q68W99 to train fasta file.
# writing Q68WF1 to train fasta file.
# writing Q68WF9 to train fasta file.
# writing Q68WW1 to train fasta file.
# writing Q68WW2 to train fasta file.
# writing Q68XC0 to train fasta file.
# writing Q68XW9 to train fasta file.
# writing Q68Y04 to train fasta file.
# writing Q69028 to train fasta file.
# writing Q69091 to train fasta file.
# writing Q69467 to train fasta file.
# writing Q694A3 to train fasta file.
# writing Q69602 to train fasta file.
# writing Q69605 to train fasta file.
# writing Q698K8 to train fasta file.
# writing Q69HT9 to train fasta file.
# writing Q69LX2 to train fasta file.
# writing Q69Z66 to train fasta file.
# writing Q6A5T8 to train fasta file.
# writing Q6A6C0 to train fasta file.
# writing Q6A6N9 to train fasta file.
# writing Q6A760 to train fasta file.
# writing Q6A7K4 to train fasta file.
# writing Q6A7V5 to train fasta file.
# writing Q6A7V7 to train fasta file.
# writing Q6A7Y1 to train fasta file.
# writing Q6A8B4 to train fasta file.
# writing Q6A8H3 to train fasta file.
# writing Q6A8U3 to train fasta file.
# writing Q6A908 to train fasta file.
# writing Q6ACC3 to train fasta file.
# writing Q6AEL0 to train fasta file.
# writing Q6AEP6 to train fasta file.
# writing Q6AF79 to train fasta file.
# writing Q6AFC3 to train fasta file.
# writing Q6AFH4 to train fasta file.
# writing Q6AFK7 to train fasta file.
# writing Q6AGD7 to train fasta file.
# writing Q6AIT0 to train fasta file.
# writing Q6AJ44 to train fasta file.
# writing Q6AJM4 to train fasta file.
# writing Q6AK45 to train fasta file.
# writing Q6ALW1 to train fasta file.
# writing Q6ANC1 to train fasta file.
# writing Q6AP58 to train fasta file.
# writing Q6AQ43 to train fasta file.
# writing Q6AQD7 to train fasta file.
# writing Q6ARX9 to train fasta file.
# writing Q6AT12 to train fasta file.
# writing Q6ATV4 to train fasta file.
# writing Q6AUR2 to train fasta file.
# writing Q6AXU9 to train fasta file.
# writing Q6AY80 to train fasta file.
# writing Q6AZB3 to train fasta file.
# writing Q6AZZ1 to train fasta file.
# writing Q6B8M0 to train fasta file.
# writing Q6BF17 to train fasta file.
# writing Q6BFF6 to train fasta file.
# writing Q6BIT7 to train fasta file.
# writing Q6BK77 to train fasta file.
# writing Q6BKD4 to train fasta file.
# writing Q6BLF4 to train fasta file.
# writing Q6BLU6 to train fasta file.
# writing Q6BMM5 to train fasta file.
# writing Q6BP10 to train fasta file.
# writing Q6BQ02 to train fasta file.
# writing Q6BQT6 to train fasta file.
# writing Q6BQZ1 to train fasta file.
# writing Q6BRY4 to train fasta file.
# writing Q6BS75 to train fasta file.
# writing Q6BSE2 to train fasta file.
# writing Q6BTW5 to train fasta file.
# writing Q6BUI4 to train fasta file.
# writing Q6BVB8 to train fasta file.
# writing Q6BWS8 to train fasta file.
# writing Q6BXJ4 to train fasta file.
# writing Q6C0G3 to train fasta file.
# writing Q6C116 to train fasta file.
# writing Q6C253 to train fasta file.
# writing Q6C2J1 to train fasta file.
# writing Q6C462 to train fasta file.
# writing Q6C5L5 to train fasta file.
# writing Q6CA79 to train fasta file.
# writing Q6CBH3 to train fasta file.
# writing Q6CCV4 to train fasta file.
# writing Q6CDL9 to train fasta file.
# writing Q6CEJ6 to train fasta file.
# writing Q6CG11 to train fasta file.
# writing Q6CGE6 to train fasta file.
# writing Q6CII3 to train fasta file.
# writing Q6CJS8 to train fasta file.
# writing Q6CJU4 to train fasta file.
# writing Q6CLH4 to train fasta file.
# writing Q6CMG4 to train fasta file.
# writing Q6CNT6 to train fasta file.
# writing Q6CP80 to train fasta file.
# writing Q6CPH3 to train fasta file.
# writing Q6CPU0 to train fasta file.
# writing Q6CT57 to train fasta file.
# writing Q6CTY3 to train fasta file.
# writing Q6CV82 to train fasta file.
# writing Q6CW75 to train fasta file.
# writing Q6CY37 to train fasta file.
# writing Q6CYT9 to train fasta file.
# writing Q6CZ96 to train fasta file.
# writing Q6CZD1 to train fasta file.
# writing Q6CZQ9 to train fasta file.
# writing Q6D081 to train fasta file.
# writing Q6D0A1 to train fasta file.
# writing Q6D0C3 to train fasta file.
# writing Q6D0G6 to train fasta file.
# writing Q6D0I5 to train fasta file.
# writing Q6D0J2 to train fasta file.
# writing Q6D0J4 to train fasta file.
# writing Q6D0W9 to train fasta file.
# writing Q6D0X0 to train fasta file.
# writing Q6D178 to train fasta file.
# writing Q6D1A2 to train fasta file.
# writing Q6D1X6 to train fasta file.
# writing Q6D1X9 to train fasta file.
# writing Q6D1Z1 to train fasta file.
# writing Q6D219 to train fasta file.
# writing Q6D222 to train fasta file.
# writing Q6D258 to train fasta file.
# writing Q6D273 to train fasta file.
# writing Q6D2A2 to train fasta file.
# writing Q6D3B3 to train fasta file.
# writing Q6D3F5 to train fasta file.
# writing Q6D3H7 to train fasta file.
# writing Q6D4G8 to train fasta file.
# writing Q6D4H2 to train fasta file.
# writing Q6D4L1 to train fasta file.
# writing Q6D5P6 to train fasta file.
# writing Q6D662 to train fasta file.
# writing Q6D698 to train fasta file.
# writing Q6D796 to train fasta file.
# writing Q6D7K8 to train fasta file.
# writing Q6D872 to train fasta file.
# writing Q6D8V3 to train fasta file.
# writing Q6DA24 to train fasta file.
# writing Q6DA25 to train fasta file.
# writing Q6DA74 to train fasta file.
# writing Q6DAP8 to train fasta file.
# writing Q6DAQ1 to train fasta file.
# writing Q6DAS2 to train fasta file.
# writing Q6DAV7 to train fasta file.
# writing Q6DB05 to train fasta file.
# writing Q6DC93 to train fasta file.
# writing Q6DCF6 to train fasta file.
# writing Q6DDR3 to train fasta file.
# writing Q6DF96 to train fasta file.
# writing Q6DFA8 to train fasta file.
# writing Q6DFE0 to train fasta file.
# writing Q6DFW5 to train fasta file.
# writing Q6DJC2 to train fasta file.
# writing Q6DN52 to train fasta file.
# writing Q6DNV6 to train fasta file.
# writing Q6DNW3 to train fasta file.
# writing Q6DNX6 to train fasta file.
# writing Q6DNX7 to train fasta file.
# writing Q6DNX8 to train fasta file.
# writing Q6DNX9 to train fasta file.
# writing Q6DNY0 to train fasta file.
# writing Q6E2N3 to train fasta file.
# writing Q6EH52 to train fasta file.
# writing Q6EN45 to train fasta file.
# writing Q6ENA6 to train fasta file.
# writing Q6ENI2 to train fasta file.
# writing Q6ENP6 to train fasta file.
# writing Q6ENX1 to train fasta file.
# writing Q6EVZ9 to train fasta file.
# writing Q6EW58 to train fasta file.
# writing Q6F165 to train fasta file.
# writing Q6F166 to train fasta file.
# writing Q6F175 to train fasta file.
# writing Q6F1K1 to train fasta file.
# writing Q6F1M6 to train fasta file.
# writing Q6F1Y1 to train fasta file.
# writing Q6F230 to train fasta file.
# writing Q6F332 to train fasta file.
# writing Q6F334 to train fasta file.
# writing Q6F3F0 to train fasta file.
# writing Q6F3F1 to train fasta file.
# writing Q6F3F3 to train fasta file.
# writing Q6F598 to train fasta file.
# writing Q6F705 to train fasta file.
# writing Q6F7E5 to train fasta file.
# writing Q6F7W6 to train fasta file.
# writing Q6F7Z8 to train fasta file.
# writing Q6F854 to train fasta file.
# writing Q6F860 to train fasta file.
# writing Q6F872 to train fasta file.
# writing Q6F8Q3 to train fasta file.
# writing Q6F9C2 to train fasta file.
# writing Q6FAA5 to train fasta file.
# writing Q6FAQ6 to train fasta file.
# writing Q6FCX7 to train fasta file.
# writing Q6FD29 to train fasta file.
# writing Q6FEE0 to train fasta file.
# writing Q6FEM6 to train fasta file.
# writing Q6FEQ1 to train fasta file.
# writing Q6FEQ6 to train fasta file.
# writing Q6FEW0 to train fasta file.
# writing Q6FEZ6 to train fasta file.
# writing Q6FF12 to train fasta file.
# writing Q6FFC0 to train fasta file.
# writing Q6FFL8 to train fasta file.
# writing Q6FG02 to train fasta file.
# writing Q6FI81 to train fasta file.
# writing Q6FIR8 to train fasta file.
# writing Q6FIS9 to train fasta file.
# writing Q6FIY7 to train fasta file.
# writing Q6FLU4 to train fasta file.
# writing Q6FM28 to train fasta file.
# writing Q6FM49 to train fasta file.
# writing Q6FM81 to train fasta file.
# writing Q6FPK7 to train fasta file.
# writing Q6FPX3 to train fasta file.
# writing Q6FRT2 to train fasta file.
# writing Q6FSI6 to train fasta file.
# writing Q6FSK3 to train fasta file.
# writing Q6FTJ8 to train fasta file.
# writing Q6FUV2 to train fasta file.
# writing Q6FV12 to train fasta file.
# writing Q6FXS6 to train fasta file.
# writing Q6FZ74 to train fasta file.
# writing Q6FZI9 to train fasta file.
# writing Q6FZZ7 to train fasta file.
# writing Q6G078 to train fasta file.
# writing Q6G082 to train fasta file.
# writing Q6G084 to train fasta file.
# writing Q6G0N3 to train fasta file.
# writing Q6G0P7 to train fasta file.
# writing Q6G0Y4 to train fasta file.
# writing Q6G1C0 to train fasta file.
# writing Q6G1E6 to train fasta file.
# writing Q6G1H5 to train fasta file.
# writing Q6G1N9 to train fasta file.
# writing Q6G2Q8 to train fasta file.
# writing Q6G335 to train fasta file.
# writing Q6G3K1 to train fasta file.
# writing Q6G459 to train fasta file.
# writing Q6G461 to train fasta file.
# writing Q6G4V8 to train fasta file.
# writing Q6G565 to train fasta file.
# writing Q6G592 to train fasta file.
# writing Q6G5E1 to train fasta file.
# writing Q6G5E3 to train fasta file.
# writing Q6G5F8 to train fasta file.
# writing Q6G5H3 to train fasta file.
# writing Q6G677 to train fasta file.
# writing Q6G6B2 to train fasta file.
# writing Q6G6B6 to train fasta file.
# writing Q6G6P6 to train fasta file.
# writing Q6G6X4 to train fasta file.
# writing Q6G784 to train fasta file.
# writing Q6G7I5 to train fasta file.
# writing Q6G7L9 to train fasta file.
# writing Q6G7N3 to train fasta file.
# writing Q6G7P7 to train fasta file.
# writing Q6G7P9 to train fasta file.
# writing Q6G813 to train fasta file.
# writing Q6G827 to train fasta file.
# writing Q6G846 to train fasta file.
# writing Q6G8E3 to train fasta file.
# writing Q6G8H6 to train fasta file.
# writing Q6G8M9 to train fasta file.
# writing Q6G8Q2 to train fasta file.
# writing Q6G8R5 to train fasta file.
# writing Q6G8Z7 to train fasta file.
# writing Q6G9T8 to train fasta file.
# writing Q6G9Z5 to train fasta file.
# writing Q6GA19 to train fasta file.
# writing Q6GA63 to train fasta file.
# writing Q6GA76 to train fasta file.
# writing Q6GAC3 to train fasta file.
# writing Q6GAC5 to train fasta file.
# writing Q6GAE4 to train fasta file.
# writing Q6GAV8 to train fasta file.
# writing Q6GB70 to train fasta file.
# writing Q6GB77 to train fasta file.
# writing Q6GBA4 to train fasta file.
# writing Q6GBX8 to train fasta file.
# writing Q6GCB6 to train fasta file.
# writing Q6GCP9 to train fasta file.
# writing Q6GD71 to train fasta file.
# writing Q6GDK4 to train fasta file.
# writing Q6GDP0 to train fasta file.
# writing Q6GE08 to train fasta file.
# writing Q6GE88 to train fasta file.
# writing Q6GEA2 to train fasta file.
# writing Q6GEJ6 to train fasta file.
# writing Q6GEV0 to train fasta file.
# writing Q6GEY4 to train fasta file.
# writing Q6GEZ7 to train fasta file.
# writing Q6GF11 to train fasta file.
# writing Q6GF14 to train fasta file.
# writing Q6GFD7 to train fasta file.
# writing Q6GFF1 to train fasta file.
# writing Q6GFG9 to train fasta file.
# writing Q6GFR6 to train fasta file.
# writing Q6GFV0 to train fasta file.
# writing Q6GG09 to train fasta file.
# writing Q6GG32 to train fasta file.
# writing Q6GGD0 to train fasta file.
# writing Q6GHG0 to train fasta file.
# writing Q6GHL7 to train fasta file.
# writing Q6GHP2 to train fasta file.
# writing Q6GHT4 to train fasta file.
# writing Q6GHU7 to train fasta file.
# writing Q6GHZ4 to train fasta file.
# writing Q6GHZ6 to train fasta file.
# writing Q6GI15 to train fasta file.
# writing Q6GIC0 to train fasta file.
# writing Q6GIN1 to train fasta file.
# writing Q6GIN8 to train fasta file.
# writing Q6GIR5 to train fasta file.
# writing Q6GIX3 to train fasta file.
# writing Q6GJG1 to train fasta file.
# writing Q6GJW2 to train fasta file.
# writing Q6GK89 to train fasta file.
# writing Q6GKN3 to train fasta file.
# writing Q6GKS6 to train fasta file.
# writing Q6GMI7 to train fasta file.
# writing Q6GML7 to train fasta file.
# writing Q6GPB5 to train fasta file.
# writing Q6GPM3 to train fasta file.
# writing Q6GQD9 to train fasta file.
# writing Q6GV10 to train fasta file.
# writing Q6GWS6 to train fasta file.
# writing Q6GZR3 to train fasta file.
# writing Q6H509 to train fasta file.
# writing Q6H7M3 to train fasta file.
# writing Q6H941 to train fasta file.
# writing Q6HB99 to train fasta file.
# writing Q6HBC6 to train fasta file.
# writing Q6HCB4 to train fasta file.
# writing Q6HCW7 to train fasta file.
# writing Q6HCY5 to train fasta file.
# writing Q6HD43 to train fasta file.
# writing Q6HD57 to train fasta file.
# writing Q6HD72 to train fasta file.
# writing Q6HDK8 to train fasta file.
# writing Q6HDL8 to train fasta file.
# writing Q6HE47 to train fasta file.
# writing Q6HE51 to train fasta file.
# writing Q6HEG3 to train fasta file.
# writing Q6HER9 to train fasta file.
# writing Q6HEV1 to train fasta file.
# writing Q6HFT0 to train fasta file.
# writing Q6HHR6 to train fasta file.
# writing Q6HJT7 to train fasta file.
# writing Q6HL16 to train fasta file.
# writing Q6HL38 to train fasta file.
# writing Q6HL56 to train fasta file.
# writing Q6HLF1 to train fasta file.
# writing Q6HM28 to train fasta file.
# writing Q6HM44 to train fasta file.
# writing Q6HN78 to train fasta file.
# writing Q6HP17 to train fasta file.
# writing Q6HP96 to train fasta file.
# writing Q6HPA4 to train fasta file.
# writing Q6HPD7 to train fasta file.
# writing Q6HPP5 to train fasta file.
# writing Q6I576 to train fasta file.
# writing Q6I6F4 to train fasta file.
# writing Q6I7B6 to train fasta file.
# writing Q6INA9 to train fasta file.
# writing Q6IP91 to train fasta file.
# writing Q6IQX0 to train fasta file.
# writing Q6IQX7 to train fasta file.
# writing Q6IR85 to train fasta file.
# writing Q6IS24 to train fasta file.
# writing Q6IT78 to train fasta file.
# writing Q6IUF7 to train fasta file.
# writing Q6J1J1 to train fasta file.
# writing Q6J3Q7 to train fasta file.
# writing Q6J835 to train fasta file.
# writing Q6J844 to train fasta file.
# writing Q6K2E8 to train fasta file.
# writing Q6K8J4 to train fasta file.
# writing Q6KAQ7 to train fasta file.
# writing Q6KFX9 to train fasta file.
# writing Q6KHC8 to train fasta file.
# writing Q6KHN3 to train fasta file.
# writing Q6KI42 to train fasta file.
# writing Q6KNA9 to train fasta file.
# writing Q6KZ41 to train fasta file.
# writing Q6L0K5 to train fasta file.
# writing Q6L0R7 to train fasta file.
# writing Q6L3A5 to train fasta file.
# writing Q6L3D9 to train fasta file.
# writing Q6L4D4 to train fasta file.
# writing Q6L5C4 to train fasta file.
# writing Q6L5F4 to train fasta file.
# writing Q6LHK5 to train fasta file.
# writing Q6LHY2 to train fasta file.
# writing Q6LM59 to train fasta file.
# writing Q6LMG3 to train fasta file.
# writing Q6LMG5 to train fasta file.
# writing Q6LMJ6 to train fasta file.
# writing Q6LMJ9 to train fasta file.
# writing Q6LML4 to train fasta file.
# writing Q6LMM8 to train fasta file.
# writing Q6LMS2 to train fasta file.
# writing Q6LMS5 to train fasta file.
# writing Q6LMS7 to train fasta file.
# writing Q6LNA3 to train fasta file.
# writing Q6LP05 to train fasta file.
# writing Q6LPI7 to train fasta file.
# writing Q6LQ72 to train fasta file.
# writing Q6LQM6 to train fasta file.
# writing Q6LR31 to train fasta file.
# writing Q6LRC2 to train fasta file.
# writing Q6LSD6 to train fasta file.
# writing Q6LU52 to train fasta file.
# writing Q6LU63 to train fasta file.
# writing Q6LUG1 to train fasta file.
# writing Q6LUL1 to train fasta file.
# writing Q6LUX1 to train fasta file.
# writing Q6LUX5 to train fasta file.
# writing Q6LUY7 to train fasta file.
# writing Q6LV26 to train fasta file.
# writing Q6LVF5 to train fasta file.
# writing Q6LVH8 to train fasta file.
# writing Q6LVN4 to train fasta file.
# writing Q6LVZ5 to train fasta file.
# writing Q6LWL2 to train fasta file.
# writing Q6LX56 to train fasta file.
# writing Q6LX63 to train fasta file.
# writing Q6LXF3 to train fasta file.
# writing Q6LXJ8 to train fasta file.
# writing Q6LXQ9 to train fasta file.
# writing Q6LY39 to train fasta file.
# writing Q6LYB4 to train fasta file.
# writing Q6LYD7 to train fasta file.
# writing Q6M079 to train fasta file.
# writing Q6M0P3 to train fasta file.
# writing Q6M0P4 to train fasta file.
# writing Q6M6E7 to train fasta file.
# writing Q6M923 to train fasta file.
# writing Q6M9L0 to train fasta file.
# writing Q6MAB0 to train fasta file.
# writing Q6MAG4 to train fasta file.
# writing Q6MBU0 to train fasta file.
# writing Q6MDC0 to train fasta file.
# writing Q6MDD0 to train fasta file.
# writing Q6MDE6 to train fasta file.
# writing Q6MDG7 to train fasta file.
# writing Q6MDK2 to train fasta file.
# writing Q6MED6 to train fasta file.
# writing Q6MEP0 to train fasta file.
# writing Q6MF40 to train fasta file.
# writing Q6MF52 to train fasta file.
# writing Q6MFZ5 to train fasta file.
# writing Q6MGL5 to train fasta file.
# writing Q6MGU3 to train fasta file.
# writing Q6MHI3 to train fasta file.
# writing Q6MJE4 to train fasta file.
# writing Q6MJP9 to train fasta file.
# writing Q6MJR8 to train fasta file.
# writing Q6MKZ5 to train fasta file.
# writing Q6MLE7 to train fasta file.
# writing Q6MMJ1 to train fasta file.
# writing Q6MMJ2 to train fasta file.
# writing Q6MML0 to train fasta file.
# writing Q6MMY3 to train fasta file.
# writing Q6MPK2 to train fasta file.
# writing Q6MPV7 to train fasta file.
# writing Q6MT17 to train fasta file.
# writing Q6MT18 to train fasta file.
# writing Q6MT28 to train fasta file.
# writing Q6MTB6 to train fasta file.
# writing Q6MTE7 to train fasta file.
# writing Q6MTH8 to train fasta file.
# writing Q6MZM0 to train fasta file.
# writing Q6N0K6 to train fasta file.
# writing Q6N461 to train fasta file.
# writing Q6N4D3 to train fasta file.
# writing Q6N509 to train fasta file.
# writing Q6N583 to train fasta file.
# writing Q6N5D5 to train fasta file.
# writing Q6N6C1 to train fasta file.
# writing Q6N6C3 to train fasta file.
# writing Q6N765 to train fasta file.
# writing Q6N7A6 to train fasta file.
# writing Q6N9F2 to train fasta file.
# writing Q6N9K3 to train fasta file.
# writing Q6NCG2 to train fasta file.
# writing Q6NCG8 to train fasta file.
# writing Q6NCM6 to train fasta file.
# writing Q6NCS3 to train fasta file.
# writing Q6NCY9 to train fasta file.
# writing Q6ND69 to train fasta file.
# writing Q6NDI4 to train fasta file.
# writing Q6NDR7 to train fasta file.
# writing Q6NEB7 to train fasta file.
# writing Q6NEZ1 to train fasta file.
# writing Q6NFN7 to train fasta file.
# writing Q6NG98 to train fasta file.
# writing Q6NGK9 to train fasta file.
# writing Q6NGW2 to train fasta file.
# writing Q6NH62 to train fasta file.
# writing Q6NHE6 to train fasta file.
# writing Q6NHH2 to train fasta file.
# writing Q6NHL0 to train fasta file.
# writing Q6NHM7 to train fasta file.
# writing Q6NJY9 to train fasta file.
# writing Q6NRB5 to train fasta file.
# writing Q6NW85 to train fasta file.
# writing Q6NYB4 to train fasta file.
# writing Q6NZ36 to train fasta file.
# writing Q6P1E1 to train fasta file.
# writing Q6P1N9 to train fasta file.
# writing Q6P3D0 to train fasta file.
# writing Q6P698 to train fasta file.
# writing Q6P6C2 to train fasta file.
# writing Q6P861 to train fasta file.
# writing Q6P8K8 to train fasta file.
# writing Q6P8M1 to train fasta file.
# writing Q6P9A2 to train fasta file.
# writing Q6P9J9 to train fasta file.
# writing Q6P9U1 to train fasta file.
# writing Q6PCE3 to train fasta file.
# writing Q6PDK2 to train fasta file.
# writing Q6PEE3 to train fasta file.
# writing Q6PFJ9 to train fasta file.
# writing Q6PI52 to train fasta file.
# writing Q6PIY7 to train fasta file.
# writing Q6Q4G4 to train fasta file.
# writing Q6QGD2 to train fasta file.
# writing Q6QUY7 to train fasta file.
# writing Q6R520 to train fasta file.
# writing Q6SSJ3 to train fasta file.
# writing Q6SYB9 to train fasta file.
# writing Q6T267 to train fasta file.
# writing Q6T271 to train fasta file.
# writing Q6T5K2 to train fasta file.
# writing Q6T5K3 to train fasta file.
# writing Q6T6K9 to train fasta file.
# writing Q6TEC1 to train fasta file.
# writing Q6TLJ0 to train fasta file.
# writing Q6TNU4 to train fasta file.
# writing Q6TQR6 to train fasta file.
# writing Q6TUJ8 to train fasta file.
# writing Q6UEH6 to train fasta file.
# writing Q6UQ17 to train fasta file.
# writing Q6VUC1 to train fasta file.
# writing Q6W2G5 to train fasta file.
# writing Q6W3E5 to train fasta file.
# writing Q6X1T6 to train fasta file.
# writing Q6XK03 to train fasta file.
# writing Q6XMH6 to train fasta file.
# writing Q6XMH7 to train fasta file.
# writing Q6XPR3 to train fasta file.
# writing Q6XTB1 to train fasta file.
# writing Q6XTB6 to train fasta file.
# writing Q6XU35 to train fasta file.
# writing Q6XYX5 to train fasta file.
# writing Q6XZR0 to train fasta file.
# writing Q6Y1R6 to train fasta file.
# writing Q6YNX6 to train fasta file.
# writing Q6YPV1 to train fasta file.
# writing Q6YPX7 to train fasta file.
# writing Q6YPX9 to train fasta file.
# writing Q6YR36 to train fasta file.
# writing Q6YWF1 to train fasta file.
# writing Q6YXQ2 to train fasta file.
# writing Q6YZE8 to train fasta file.
# writing Q6Z1I5 to train fasta file.
# writing Q6Z1J6 to train fasta file.
# writing Q6Z244 to train fasta file.
# writing Q6Z2J1 to train fasta file.
# writing Q6Z461 to train fasta file.
# writing Q6Z6M4 to train fasta file.
# writing Q6Z8M8 to train fasta file.
# writing Q6ZD95 to train fasta file.
# writing Q6ZEA5 to train fasta file.
# writing Q6ZEC6 to train fasta file.
# writing Q6ZEI1 to train fasta file.
# writing Q6ZFT5 to train fasta file.
# writing Q6ZN17 to train fasta file.
# writing Q6ZPS6 to train fasta file.
# writing Q6ZT98 to train fasta file.
# writing Q6ZVD8 to train fasta file.
# writing Q6ZVK8 to train fasta file.
# writing Q700C2 to train fasta file.
# writing Q700W2 to train fasta file.
# writing Q703G9 to train fasta file.
# writing Q703I2 to train fasta file.
# writing Q70IA6 to train fasta file.
# writing Q70IA8 to train fasta file.
# writing Q70JZ1 to train fasta file.
# writing Q70KY3 to train fasta file.
# writing Q70XW3 to train fasta file.
# writing Q710E8 to train fasta file.
# writing Q71EW5 to train fasta file.
# writing Q71RR4 to train fasta file.
# writing Q71UH5 to train fasta file.
# writing Q71UH6 to train fasta file.
# writing Q71VR4 to train fasta file.
# writing Q71VR5 to train fasta file.
# writing Q71W90 to train fasta file.
# writing Q71WF9 to train fasta file.
# writing Q71WR8 to train fasta file.
# writing Q71WU4 to train fasta file.
# writing Q71Y01 to train fasta file.
# writing Q71Y33 to train fasta file.
# writing Q71Y88 to train fasta file.
# writing Q71YB3 to train fasta file.
# writing Q71YJ5 to train fasta file.
# writing Q71YP9 to train fasta file.
# writing Q71YQ8 to train fasta file.
# writing Q71YY6 to train fasta file.
# writing Q71Z03 to train fasta file.
# writing Q71ZB0 to train fasta file.
# writing Q71ZC0 to train fasta file.
# writing Q71ZK5 to train fasta file.
# writing Q71ZM2 to train fasta file.
# writing Q71ZR3 to train fasta file.
# writing Q71ZT7 to train fasta file.
# writing Q71ZZ0 to train fasta file.
# writing Q720J0 to train fasta file.
# writing Q720K8 to train fasta file.
# writing Q721B5 to train fasta file.
# writing Q721R7 to train fasta file.
# writing Q723G9 to train fasta file.
# writing Q723Y9 to train fasta file.
# writing Q724J4 to train fasta file.
# writing Q725Q3 to train fasta file.
# writing Q726F4 to train fasta file.
# writing Q726X4 to train fasta file.
# writing Q727E3 to train fasta file.
# writing Q727F1 to train fasta file.
# writing Q727P4 to train fasta file.
# writing Q728R5 to train fasta file.
# writing Q728R9 to train fasta file.
# writing Q729A3 to train fasta file.
# writing Q729A6 to train fasta file.
# writing Q72AR5 to train fasta file.
# writing Q72BH2 to train fasta file.
# writing Q72CB8 to train fasta file.
# writing Q72CF1 to train fasta file.
# writing Q72CG7 to train fasta file.
# writing Q72CQ9 to train fasta file.
# writing Q72F03 to train fasta file.
# writing Q72HA1 to train fasta file.
# writing Q72HC1 to train fasta file.
# writing Q72HH1 to train fasta file.
# writing Q72I42 to train fasta file.
# writing Q72I53 to train fasta file.
# writing Q72IF6 to train fasta file.
# writing Q72IH7 to train fasta file.
# writing Q72IV9 to train fasta file.
# writing Q72IZ9 to train fasta file.
# writing Q72JB3 to train fasta file.
# writing Q72JK8 to train fasta file.
# writing Q72JP3 to train fasta file.
# writing Q72JR0 to train fasta file.
# writing Q72JT5 to train fasta file.
# writing Q72K91 to train fasta file.
# writing Q72KH8 to train fasta file.
# writing Q72L21 to train fasta file.
# writing Q72LM0 to train fasta file.
# writing Q72M80 to train fasta file.
# writing Q72MA6 to train fasta file.
# writing Q72MK0 to train fasta file.
# writing Q72MN0 to train fasta file.
# writing Q72NH4 to train fasta file.
# writing Q72PK6 to train fasta file.
# writing Q72PR5 to train fasta file.
# writing Q72PR7 to train fasta file.
# writing Q72QK8 to train fasta file.
# writing Q72QT1 to train fasta file.
# writing Q72R93 to train fasta file.
# writing Q72RC4 to train fasta file.
# writing Q72RG8 to train fasta file.
# writing Q72S40 to train fasta file.
# writing Q72S74 to train fasta file.
# writing Q72SM5 to train fasta file.
# writing Q72TM6 to train fasta file.
# writing Q72WF4 to train fasta file.
# writing Q72XS9 to train fasta file.
# writing Q72YV6 to train fasta file.
# writing Q72ZI1 to train fasta file.
# writing Q72ZK2 to train fasta file.
# writing Q72ZT2 to train fasta file.
# writing Q72ZV7 to train fasta file.
# writing Q72ZX2 to train fasta file.
# writing Q730M2 to train fasta file.
# writing Q730N3 to train fasta file.
# writing Q731I2 to train fasta file.
# writing Q731W2 to train fasta file.
# writing Q732H4 to train fasta file.
# writing Q732K6 to train fasta file.
# writing Q733Y5 to train fasta file.
# writing Q736P6 to train fasta file.
# writing Q739D2 to train fasta file.
# writing Q739I4 to train fasta file.
# writing Q739M9 to train fasta file.
# writing Q73AV4 to train fasta file.
# writing Q73AX8 to train fasta file.
# writing Q73AZ6 to train fasta file.
# writing Q73B98 to train fasta file.
# writing Q73C24 to train fasta file.
# writing Q73EM5 to train fasta file.
# writing Q73EN5 to train fasta file.
# writing Q73ET1 to train fasta file.
# writing Q73F83 to train fasta file.
# writing Q73G84 to train fasta file.
# writing Q73GH6 to train fasta file.
# writing Q73GN4 to train fasta file.
# writing Q73GW5 to train fasta file.
# writing Q73H48 to train fasta file.
# writing Q73HA6 to train fasta file.
# writing Q73HK8 to train fasta file.
# writing Q73IC3 to train fasta file.
# writing Q73IM5 to train fasta file.
# writing Q73J26 to train fasta file.
# writing Q73JG6 to train fasta file.
# writing Q73JP8 to train fasta file.
# writing Q73JR4 to train fasta file.
# writing Q73K17 to train fasta file.
# writing Q73KE7 to train fasta file.
# writing Q73KZ3 to train fasta file.
# writing Q73LG6 to train fasta file.
# writing Q73MH0 to train fasta file.
# writing Q73MK4 to train fasta file.
# writing Q73NB3 to train fasta file.
# writing Q73NR2 to train fasta file.
# writing Q73PL9 to train fasta file.
# writing Q73QW4 to train fasta file.
# writing Q73RJ6 to train fasta file.
# writing Q73RN8 to train fasta file.
# writing Q73S96 to train fasta file.
# writing Q73T77 to train fasta file.
# writing Q73V62 to train fasta file.
# writing Q73VI1 to train fasta file.
# writing Q73VI7 to train fasta file.
# writing Q73VR8 to train fasta file.
# writing Q73WE4 to train fasta file.
# writing Q73WJ9 to train fasta file.
# writing Q73X47 to train fasta file.
# writing Q73X89 to train fasta file.
# writing Q73XH8 to train fasta file.
# writing Q73XT9 to train fasta file.
# writing Q73XV0 to train fasta file.
# writing Q73YC1 to train fasta file.
# writing Q73YI6 to train fasta file.
# writing Q73YL5 to train fasta file.
# writing Q740J1 to train fasta file.
# writing Q741G5 to train fasta file.
# writing Q743F0 to train fasta file.
# writing Q743Q8 to train fasta file.
# writing Q743Y3 to train fasta file.
# writing Q745W0 to train fasta file.
# writing Q746F4 to train fasta file.
# writing Q747X9 to train fasta file.
# writing Q748A8 to train fasta file.
# writing Q748D8 to train fasta file.
# writing Q748I9 to train fasta file.
# writing Q748M1 to train fasta file.
# writing Q749A0 to train fasta file.
# writing Q74AR8 to train fasta file.
# writing Q74BJ1 to train fasta file.
# writing Q74BL6 to train fasta file.
# writing Q74BX5 to train fasta file.
# writing Q74C80 to train fasta file.
# writing Q74CG8 to train fasta file.
# writing Q74D00 to train fasta file.
# writing Q74D04 to train fasta file.
# writing Q74DI7 to train fasta file.
# writing Q74DU7 to train fasta file.
# writing Q74E53 to train fasta file.
# writing Q74FK1 to train fasta file.
# writing Q74FS7 to train fasta file.
# writing Q74G62 to train fasta file.
# writing Q74GW7 to train fasta file.
# writing Q74H36 to train fasta file.
# writing Q74IE1 to train fasta file.
# writing Q74IY8 to train fasta file.
# writing Q74JD5 to train fasta file.
# writing Q74JW2 to train fasta file.
# writing Q74JX6 to train fasta file.
# writing Q74KS4 to train fasta file.
# writing Q74KU4 to train fasta file.
# writing Q74MZ1 to train fasta file.
# writing Q74N45 to train fasta file.
# writing Q74NK2 to train fasta file.
# writing Q74Z32 to train fasta file.
# writing Q74ZM9 to train fasta file.
# writing Q74ZR2 to train fasta file.
# writing Q752Z9 to train fasta file.
# writing Q757B7 to train fasta file.
# writing Q758M7 to train fasta file.
# writing Q758X6 to train fasta file.
# writing Q759A9 to train fasta file.
# writing Q75BI3 to train fasta file.
# writing Q75DJ3 to train fasta file.
# writing Q75DS8 to train fasta file.
# writing Q75DY2 to train fasta file.
# writing Q75EE0 to train fasta file.
# writing Q75EL5 to train fasta file.
# writing Q75FG2 to train fasta file.
# writing Q75FW3 to train fasta file.
# writing Q75LH6 to train fasta file.
# writing Q75LI2 to train fasta file.
# writing Q761V0 to train fasta file.
# writing Q763T4 to train fasta file.
# writing Q764S0 to train fasta file.
# writing Q765N2 to train fasta file.
# writing Q768T5 to train fasta file.
# writing Q76F73 to train fasta file.
# writing Q76I22 to train fasta file.
# writing Q76II0 to train fasta file.
# writing Q76IQ3 to train fasta file.
# writing Q79CE8 to train fasta file.
# writing Q79ZY4 to train fasta file.
# writing Q7A018 to train fasta file.
# writing Q7A0N4 to train fasta file.
# writing Q7A115 to train fasta file.
# writing Q7A171 to train fasta file.
# writing Q7A1B6 to train fasta file.
# writing Q7A1G4 to train fasta file.
# writing Q7A1W8 to train fasta file.
# writing Q7A215 to train fasta file.
# writing Q7A2R1 to train fasta file.
# writing Q7A305 to train fasta file.
# writing Q7A3E1 to train fasta file.
# writing Q7A3E5 to train fasta file.
# writing Q7A3R9 to train fasta file.
# writing Q7A522 to train fasta file.
# writing Q7A559 to train fasta file.
# writing Q7A5X6 to train fasta file.
# writing Q7A600 to train fasta file.
# ...
# writing Q9R0E2 to train fasta file.
# writing Q9R1K9 to train fasta file.
# writing Q9R1U9 to train fasta file.
# writing Q9R5V7 to train fasta file.
# writing Q9R6X1 to train fasta file.
# writing Q9RDT3 to train fasta file.
# writing Q9RE09 to train fasta file.
# writing Q9REQ6 to train fasta file.
# writing Q9RFD3 to train fasta file.
# writing Q9RFD4 to train fasta file.
# writing Q9RGS5 to train fasta file.
# writing Q9RHN1 to train fasta file.
# writing Q9RHW9 to train fasta file.
# writing Q9RKK5 to train fasta file.
# writing Q9RKS2 to train fasta file.
# writing Q9RKU5 to train fasta file.
# writing Q9RL99 to train fasta file.
# writing Q9RNM9 to train fasta file.
# writing Q9RPX0 to train fasta file.
# writing Q9RPX1 to train fasta file.
# writing Q9RQ47 to train fasta file.
# writing Q9RQ51 to train fasta file.
# writing Q9RQ55 to train fasta file.
# writing Q9RQ65 to train fasta file.
# writing Q9RQB4 to train fasta file.
# writing Q9RQW2 to train fasta file.
# writing Q9RR81 to train fasta file.
# writing Q9RRB7 to train fasta file.
# writing Q9RRX5 to train fasta file.
# writing Q9RRX8 to train fasta file.
# writing Q9RSN2 to train fasta file.
# writing Q9RSP3 to train fasta file.
# writing Q9RSR1 to train fasta file.
# writing Q9RTI6 to train fasta file.
# writing Q9RTR9 to train fasta file.
# writing Q9RTY9 to train fasta file.
# writing Q9RUV0 to train fasta file.
# writing Q9RUW8 to train fasta file.
# writing Q9RV39 to train fasta file.
# writing Q9RV62 to train fasta file.
# writing Q9RV76 to train fasta file.
# writing Q9RVT6 to train fasta file.
# writing Q9RWM1 to train fasta file.
# writing Q9RWM6 to train fasta file.
# writing Q9RX35 to train fasta file.
# writing Q9RXT4 to train fasta file.
# writing Q9RXX6 to train fasta file.
# writing Q9RY41 to train fasta file.
# writing Q9RZ05 to train fasta file.
# writing Q9RZP0 to train fasta file.
# writing Q9S152 to train fasta file.
# writing Q9S1H5 to train fasta file.
# writing Q9S1M6 to train fasta file.
# writing Q9S1N4 to train fasta file.
# writing Q9S2H9 to train fasta file.
# writing Q9S2N2 to train fasta file.
# writing Q9S306 to train fasta file.
# writing Q9S3S1 to train fasta file.
# writing Q9S3V1 to train fasta file.
# writing Q9S426 to train fasta file.
# writing Q9S744 to train fasta file.
# writing Q9S750 to train fasta file.
# writing Q9S758 to train fasta file.
# writing Q9S764 to train fasta file.
# writing Q9S7A9 to train fasta file.
# writing Q9S7I0 to train fasta file.
# writing Q9S7J8 to train fasta file.
# writing Q9S7J9 to train fasta file.
# writing Q9S7P5 to train fasta file.
# writing Q9S840 to train fasta file.
# writing Q9S9Z7 to train fasta file.
# writing Q9SA73 to train fasta file.
# writing Q9SAF5 to train fasta file.
# writing Q9SBQ5 to train fasta file.
# writing Q9SBQ7 to train fasta file.
# writing Q9SE26 to train fasta file.
# writing Q9SEW4 to train fasta file.
# writing Q9SGG3 to train fasta file.
# writing Q9SH30 to train fasta file.
# writing Q9SI37 to train fasta file.
# writing Q9SIE0 to train fasta file.
# writing Q9SIU8 to train fasta file.
# writing Q9SJL8 to train fasta file.
# writing Q9SJN6 to train fasta file.
# writing Q9SJT1 to train fasta file.
# writing Q9SJZ7 to train fasta file.
# writing Q9SK52 to train fasta file.
# writing Q9SKC2 to train fasta file.
# writing Q9SKC3 to train fasta file.
# writing Q9SKC4 to train fasta file.
# writing Q9SKK4 to train fasta file.
# writing Q9SL49 to train fasta file.
# writing Q9SLI8 to train fasta file.
# writing Q9SLK6 to train fasta file.
# writing Q9SM64 to train fasta file.
# writing Q9SMX9 to train fasta file.
# writing Q9SR62 to train fasta file.
# writing Q9SRE6 to train fasta file.
# writing Q9SRE7 to train fasta file.
# writing Q9SRP4 to train fasta file.
# writing Q9SRP5 to train fasta file.
# writing Q9SRP7 to train fasta file.
# writing Q9SRR7 to train fasta file.
# writing Q9SRV5 to train fasta file.
# writing Q9SS67 to train fasta file.
# writing Q9SSL1 to train fasta file.
# writing Q9SU00 to train fasta file.
# writing Q9SU24 to train fasta file.
# writing Q9SUB4 to train fasta file.
# writing Q9SUF4 to train fasta file.
# writing Q9SUT2 to train fasta file.
# writing Q9SVG9 to train fasta file.
# writing Q9SVS8 to train fasta file.
# writing Q9SX33 to train fasta file.
# writing Q9SXA6 to train fasta file.
# writing Q9SXQ6 to train fasta file.
# writing Q9SZB9 to train fasta file.
# writing Q9SZC9 to train fasta file.
# writing Q9SZE7 to train fasta file.
# writing Q9SZH2 to train fasta file.
# writing Q9SZR1 to train fasta file.
# writing Q9THV5 to train fasta file.
# writing Q9TKV9 to train fasta file.
# writing Q9TL10 to train fasta file.
# writing Q9TLW0 to train fasta file.
# writing Q9TLX6 to train fasta file.
# writing Q9TM34 to train fasta file.
# writing Q9TTT5 to train fasta file.
# writing Q9TW67 to train fasta file.
# writing Q9TZD0 to train fasta file.
# writing Q9U6D3 to train fasta file.
# writing Q9UB37 to train fasta file.
# writing Q9UBG3 to train fasta file.
# writing Q9UBQ6 to train fasta file.
# writing Q9UBS8 to train fasta file.
# writing Q9UBV8 to train fasta file.
# writing Q9UGL1 to train fasta file.
# writing Q9UHY7 to train fasta file.
# writing Q9UI42 to train fasta file.
# writing Q9UJV3 to train fasta file.
# writing Q9UK39 to train fasta file.
# writing Q9UKD1 to train fasta file.
# writing Q9UKQ2 to train fasta file.
# writing Q9ULA0 to train fasta file.
# writing Q9ULJ6 to train fasta file.
# writing Q9ULM6 to train fasta file.
# writing Q9ULU4 to train fasta file.
# writing Q9UPN9 to train fasta file.
# writing Q9UQ26 to train fasta file.
# writing Q9UQX0 to train fasta file.
# writing Q9URU2 to train fasta file.
# writing Q9URY9 to train fasta file.
# writing Q9US53 to train fasta file.
# writing Q9USP8 to train fasta file.
# writing Q9UT19 to train fasta file.
# writing Q9UT33 to train fasta file.
# writing Q9UT49 to train fasta file.
# writing Q9UU89 to train fasta file.
# writing Q9UU93 to train fasta file.
# writing Q9UUF1 to train fasta file.
# writing Q9UVY5 to train fasta file.
# writing Q9UWF0 to train fasta file.
# writing Q9UWR6 to train fasta file.
# writing Q9UX49 to train fasta file.
# writing Q9UXE7 to train fasta file.
# writing Q9UXR9 to train fasta file.
# writing Q9UXW3 to train fasta file.
# writing Q9UY71 to train fasta file.
# writing Q9UYR5 to train fasta file.
# writing Q9UYT3 to train fasta file.
# writing Q9UYT4 to train fasta file.
# writing Q9UZ07 to train fasta file.
# writing Q9UZ57 to train fasta file.
# writing Q9UZ86 to train fasta file.
# writing Q9UZC0 to train fasta file.
# writing Q9UZT5 to train fasta file.
# writing Q9V085 to train fasta file.
# writing Q9V0E1 to train fasta file.
# writing Q9V0J8 to train fasta file.
# writing Q9V0V0 to train fasta file.
# writing Q9V1H9 to train fasta file.
# writing Q9V1J0 to train fasta file.
# writing Q9V1N8 to train fasta file.
# writing Q9V270 to train fasta file.
# writing Q9V288 to train fasta file.
# writing Q9V292 to train fasta file.
# writing Q9V2I3 to train fasta file.
# writing Q9V3N8 to train fasta file.
# writing Q9V3Y2 to train fasta file.
# writing Q9V521 to train fasta file.
# writing Q9VD44 to train fasta file.
# writing Q9VGI8 to train fasta file.
# writing Q9VGQ9 to train fasta file.
# writing Q9VHH7 to train fasta file.
# writing Q9VL13 to train fasta file.
# writing Q9VLJ6 to train fasta file.
# writing Q9VMJ7 to train fasta file.
# writing Q9VMW7 to train fasta file.
# writing Q9VN95 to train fasta file.
# writing Q9VPH2 to train fasta file.
# writing Q9VR05 to train fasta file.
# writing Q9VRJ0 to train fasta file.
# writing Q9VRN5 to train fasta file.
# writing Q9VTH0 to train fasta file.
# writing Q9VUQ5 to train fasta file.
# writing Q9VWH4 to train fasta file.
# writing Q9VXA8 to train fasta file.
# writing Q9VXE6 to train fasta file.
# writing Q9VXG1 to train fasta file.
# writing Q9VYS4 to train fasta file.
# writing Q9VZS6 to train fasta file.
# writing Q9W1V6 to train fasta file.
# writing Q9W252 to train fasta file.
# writing Q9W5Y0 to train fasta file.
# writing Q9W6M5 to train fasta file.
# writing Q9W734 to train fasta file.
# writing Q9W7S2 to train fasta file.
# writing Q9WTR8 to train fasta file.
# writing Q9WVL6 to train fasta file.
# writing Q9WVQ5 to train fasta file.
# writing Q9WXB4 to train fasta file.
# writing Q9WXE6 to train fasta file.
# writing Q9WXK7 to train fasta file.
# writing Q9WY06 to train fasta file.
# writing Q9WYC7 to train fasta file.
# writing Q9WYJ9 to train fasta file.
# writing Q9WYK8 to train fasta file.
# writing Q9WYP7 to train fasta file.
# writing Q9WZ24 to train fasta file.
# writing Q9WZJ9 to train fasta file.
# writing Q9WZP4 to train fasta file.
# writing Q9WZS8 to train fasta file.
# writing Q9X015 to train fasta file.
# writing Q9X0I1 to train fasta file.
# writing Q9X0X3 to train fasta file.
# writing Q9X0X7 to train fasta file.
# writing Q9X112 to train fasta file.
# writing Q9X1P3 to train fasta file.
# writing Q9X1T8 to train fasta file.
# writing Q9X1Y8 to train fasta file.
# writing Q9X1Z5 to train fasta file.
# writing Q9X240 to train fasta file.
# writing Q9X251 to train fasta file.
# writing Q9X2B7 to train fasta file.
# writing Q9X404 to train fasta file.
# writing Q9X406 to train fasta file.
# writing Q9X4A7 to train fasta file.
# writing Q9X4Q2 to train fasta file.
# writing Q9X5V3 to train fasta file.
# writing Q9X712 to train fasta file.
# writing Q9X7E3 to train fasta file.
# writing Q9X7N2 to train fasta file.
# writing Q9X814 to train fasta file.
# writing Q9X8N6 to train fasta file.
# writing Q9X8Z9 to train fasta file.
# writing Q9X9Q0 to train fasta file.
# writing Q9XA06 to train fasta file.
# writing Q9XB59 to train fasta file.
# writing Q9XBR7 to train fasta file.
# writing Q9XCX9 to train fasta file.
# writing Q9XD23 to train fasta file.
# writing Q9XDB4 to train fasta file.
# writing Q9XDN5 to train fasta file.
# writing Q9XDP3 to train fasta file.
# writing Q9XEE8 to train fasta file.
# writing Q9XGA0 to train fasta file.
# writing Q9XGA1 to train fasta file.
# writing Q9XGH7 to train fasta file.
# writing Q9XGR4 to train fasta file.
# writing Q9XIE6 to train fasta file.
# writing Q9XIV8 to train fasta file.
# writing Q9XPS9 to train fasta file.
# writing Q9XS41 to train fasta file.
# writing Q9XSL6 to train fasta file.
# writing Q9XT27 to train fasta file.
# writing Q9XT49 to train fasta file.
# writing Q9XTB2 to train fasta file.
# writing Q9XTQ5 to train fasta file.
# writing Q9XTQ6 to train fasta file.
# writing Q9XTT8 to train fasta file.
# writing Q9XTW2 to train fasta file.
# writing Q9XW79 to train fasta file.
# writing Q9XWG3 to train fasta file.
# writing Q9XZ08 to train fasta file.
# writing Q9XZE5 to train fasta file.
# writing Q9XZP2 to train fasta file.
# writing Q9Y253 to train fasta file.
# writing Q9Y2G3 to train fasta file.
# writing Q9Y2I7 to train fasta file.
# writing Q9Y2Q0 to train fasta file.
# writing Q9Y345 to train fasta file.
# writing Q9Y4X5 to train fasta file.
# writing Q9Y5K2 to train fasta file.
# writing Q9Y5P8 to train fasta file.
# writing Q9Y644 to train fasta file.
# writing Q9Y6H3 to train fasta file.
# writing Q9Y6Q6 to train fasta file.
# writing Q9Y783 to train fasta file.
# writing Q9Y7L4 to train fasta file.
# writing Q9Y7M3 to train fasta file.
# writing Q9Y7N3 to train fasta file.
# writing Q9Y7T3 to train fasta file.
# writing Q9Y8H8 to train fasta file.
# writing Q9Y9I3 to train fasta file.
# writing Q9Y9Z0 to train fasta file.
# writing Q9YA91 to train fasta file.
# writing Q9YAZ7 to train fasta file.
# writing Q9YB01 to train fasta file.
# writing Q9YB30 to train fasta file.
# writing Q9YBS3 to train fasta file.
# writing Q9YBY0 to train fasta file.
# writing Q9YDM7 to train fasta file.
# writing Q9YDX7 to train fasta file.
# writing Q9YDY1 to train fasta file.
# writing Q9YE97 to train fasta file.
# writing Q9YEU2 to train fasta file.
# writing Q9YEV3 to train fasta file.
# writing Q9YF00 to train fasta file.
# writing Q9YFM7 to train fasta file.
# writing Q9YFY8 to train fasta file.
# writing Q9YGN5 to train fasta file.
# writing Q9YHB3 to train fasta file.
# writing Q9YI19 to train fasta file.
# writing Q9YMV2 to train fasta file.
# writing Q9YPV8 to train fasta file.
# writing Q9YQR5 to train fasta file.
# writing Q9YUD3 to train fasta file.
# writing Q9YZR5 to train fasta file.
# writing Q9Z0M1 to train fasta file.
# writing Q9Z0V1 to train fasta file.
# writing Q9Z0V2 to train fasta file.
# writing Q9Z0X4 to train fasta file.
# writing Q9Z0Z4 to train fasta file.
# writing Q9Z176 to train fasta file.
# writing Q9Z1K5 to train fasta file.
# writing Q9Z1L5 to train fasta file.
# writing Q9Z1N2 to train fasta file.
# writing Q9Z1T6 to train fasta file.
# writing Q9Z2W0 to train fasta file.
# writing Q9Z5U2 to train fasta file.
# writing Q9Z6J1 to train fasta file.
# writing Q9Z6J2 to train fasta file.
# writing Q9Z6L3 to train fasta file.
# writing Q9Z6M3 to train fasta file.
# writing Q9Z6R6 to train fasta file.
# writing Q9Z6S4 to train fasta file.
# writing Q9Z6X4 to train fasta file.
# writing Q9Z6Y8 to train fasta file.
# writing Q9Z7A0 to train fasta file.
# writing Q9Z7D1 to train fasta file.
# writing Q9Z7E5 to train fasta file.
# writing Q9Z7T3 to train fasta file.
# writing Q9Z7X6 to train fasta file.
# writing Q9Z873 to train fasta file.
# writing Q9Z8M5 to train fasta file.
# writing Q9Z946 to train fasta file.
# writing Q9Z984 to train fasta file.
# writing Q9Z9E3 to train fasta file.
# writing Q9Z9K1 to train fasta file.
# writing Q9Z9T7 to train fasta file.
# writing Q9ZA56 to train fasta file.
# writing Q9ZA98 to train fasta file.
# writing Q9ZAE6 to train fasta file.
# writing Q9ZB06 to train fasta file.
# writing Q9ZBT9 to train fasta file.
# writing Q9ZCC8 to train fasta file.
# writing Q9ZCJ9 to train fasta file.
# writing Q9ZCS6 to train fasta file.
# writing Q9ZCW7 to train fasta file.
# writing Q9ZCX5 to train fasta file.
# writing Q9ZCX7 to train fasta file.
# writing Q9ZD15 to train fasta file.
# writing Q9ZDB4 to train fasta file.
# writing Q9ZDB5 to train fasta file.
# writing Q9ZDB6 to train fasta file.
# writing Q9ZDS6 to train fasta file.
# writing Q9ZE46 to train fasta file.
# writing Q9ZEP8 to train fasta file.
# writing Q9ZFE7 to train fasta file.
# writing Q9ZFV4 to train fasta file.
# writing Q9ZGH1 to train fasta file.
# writing Q9ZI56 to train fasta file.
# writing Q9ZJR1 to train fasta file.
# writing Q9ZJS5 to train fasta file.
# writing Q9ZK89 to train fasta file.
# writing Q9ZKC3 to train fasta file.
# writing Q9ZKF9 to train fasta file.
# writing Q9ZKP2 to train fasta file.
# writing Q9ZKX3 to train fasta file.
# writing Q9ZL01 to train fasta file.
# writing Q9ZL57 to train fasta file.
# writing Q9ZM43 to train fasta file.
# writing Q9ZM56 to train fasta file.
# writing Q9ZMF2 to train fasta file.
# writing Q9ZMG6 to train fasta file.
# writing Q9ZML6 to train fasta file.
# writing Q9ZMN5 to train fasta file.
# writing Q9ZMP1 to train fasta file.
# writing Q9ZMQ6 to train fasta file.
# writing Q9ZMS3 to train fasta file.
# writing Q9ZMV3 to train fasta file.
# writing Q9ZND5 to train fasta file.
# writing Q9ZNE0 to train fasta file.
# writing Q9ZQE6 to train fasta file.
# writing Q9ZQG8 to train fasta file.
# writing Q9ZQZ1 to train fasta file.
# writing Q9ZR02 to train fasta file.
# writing Q9ZSE4 to train fasta file.
# writing Q9ZST4 to train fasta file.
# writing Q9ZT84 to train fasta file.
# writing Q9ZTP3 to train fasta file.
# writing Q9ZTS2 to train fasta file.
# writing Q9ZUJ5 to train fasta file.
# writing Q9ZUN4 to train fasta file.
# writing Q9ZVF1 to train fasta file.
# writing Q9ZW21 to train fasta file.
# writing Q9ZW82 to train fasta file.
# writing Q9ZX29 to train fasta file.
# writing R9WS04 to train fasta file.
# writing R9WTS6 to train fasta file.
# writing S0E627 to train fasta file.
# writing S0EA85 to train fasta file.
# writing S3D784 to train fasta file.
# writing S3D9F9 to train fasta file.
# writing S3DB70 to train fasta file.
# writing S4WUL1 to train fasta file.
# writing T0D3N5 to train fasta file.
# writing T0JRM4 to train fasta file.
# writing T2KMG4 to train fasta file.
# writing U3KRF2 to train fasta file.
# writing U3KRG1 to train fasta file.
# writing U3LW50 to train fasta file.
# writing U5PZ28 to train fasta file.
# writing V5IVB1 to train fasta file.
# writing V6RG22 to train fasta file.
# writing W3X7K0 to train fasta file.
# writing W4VS99 to train fasta file.
# writing W5AWH5 to train fasta file.
# writing W5BGD1 to train fasta file.
# writing W7MLD5 to train fasta file.
# writing W7MSI4 to train fasta file.
# writing W8JWV8 to train fasta file.
# writing X5CFH4 to train fasta file.
# writing X5CWH9 to train fasta file.

# %%
dataset_metal_binding_summary(new_trainval_seqs, source = 'POS_TRAIN_FULL.tsv')
pass
# Out:
# total seq in the set: 246025
# CHEBI:29105  |Zn(2+)                        |#p:      22505|#residue: 106903|%residue/all: 0.799
# CHEBI:18420  |Mg(2+)                        |#p:      26076|#residue:  71517|%residue/all:   0.8
# CHEBI:49883  |[4Fe-4S] cluster              |#p:       8541|#residue:  41221|%residue/all: 0.799
# CHEBI:29108  |Ca(2+)                        |#p:       4584|#residue:  33716|%residue/all: 0.799
# CHEBI:29035  |Mn(2+)                        |#p:       4002|#residue:  17914|%residue/all: 0.798
# CHEBI:60240  |a divalent metal cation       |#p:       3582|#residue:  14543|%residue/all: 0.799
# CHEBI:24875  |Fe cation                     |#p:       3965|#residue:  13948|%residue/all: 0.799
# CHEBI:190135 |[2Fe-2S] cluster              |#p:       2218|#residue:   7218|%residue/all: 0.799
# CHEBI:23378  |Cu cation                     |#p:       1160|#residue:   5905|%residue/all: 0.799
# CHEBI:29103  |K(+)                          |#p:       1358|#residue:   5002|%residue/all: 0.798
# CHEBI:49786  |Ni(2+)                        |#p:        612|#residue:   2651|%residue/all: 0.781
# CHEBI:29101  |Na(+)                         |#p:        587|#residue:   1778|%residue/all: 0.796
# CHEBI:29034  |Fe(3+)                        |#p:        309|#residue:   1327|%residue/all:   0.8
# CHEBI:30408  |iron-sulfur cluster           |#p:        264|#residue:    847|%residue/all: 0.801
# CHEBI:29036  |Cu(2+)                        |#p:         78|#residue:    745|%residue/all: 0.798
# CHEBI:29033  |Fe(2+)                        |#p:        196|#residue:    665|%residue/all: 0.799
# CHEBI:21137  |[3Fe-4S] cluster              |#p:        127|#residue:    398|%residue/all:  0.78
# CHEBI:49552  |Cu(+)                         |#p:         47|#residue:    285|%residue/all: 0.774
# CHEBI:48775  |Cd(2+)                        |#p:         29|#residue:    288|%residue/all: 0.798
# CHEBI:48828  |Co(2+)                        |#p:         54|#residue:    173|%residue/all: 0.755
# CHEBI:21143  |[8Fe-7S] cluster              |#p:         41|#residue:    133|%residue/all: 0.756
# CHEBI:25213  |a metal cation                |#p:         41|#residue:     94|%residue/all: 0.718
# CHEBI:47739  |[Ni-4Fe-4S] cluster           |#p:         13|#residue:     82|%residue/all: 0.774
# CHEBI:16793  |Hg(2+)                        |#p:         20|#residue:     62|%residue/all: 0.689
# CHEBI:177874 |[Ni-4Fe-5S] cluster           |#p:          7|#residue:     40|%residue/all: 0.784
# CHEBI:60400  |[Ni-Fe-S] cluster             |#p:          8|#residue:     32|%residue/all: 0.727
# CHEBI:49415  |Co(3+)                        |#p:          3|#residue:     12|%residue/all:  0.75
# CHEBI:60504  |[8Fe-9S-C-homocitryl] cluster |#p:          3|#residue:      5|%residue/all: 0.714
# CHEBI:49713  |Li(+)                         |#p:          2|#residue:      4|%residue/all: 0.667
# #non-binding protein: 172712

# %%
file_out = 'TRAIN_POS_NEG1.fasta'
write_seq_ls2fasta(file_out, new_trainval_seqs, 'combined.fasta')
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# writing Q97QS2 to train fasta file.
# writing Q97QT2 to train fasta file.
# writing Q97QW0 to train fasta file.
# writing Q97QW8 to train fasta file.
# writing Q97R22 to train fasta file.
# writing Q97R24 to train fasta file.
# writing Q97R31 to train fasta file.
# writing Q97R46 to train fasta file.
# writing Q97R66 to train fasta file.
# writing Q97RC6 to train fasta file.
# writing Q97RI6 to train fasta file.
# writing Q97RS9 to train fasta file.
# writing Q97RW2 to train fasta file.
# writing Q97S25 to train fasta file.
# writing Q97S28 to train fasta file.
# writing Q97S34 to train fasta file.
# writing Q97S93 to train fasta file.
# writing Q97SC7 to train fasta file.
# writing Q97SD7 to train fasta file.
# writing Q97SR2 to train fasta file.
# writing Q97SR4 to train fasta file.
# writing Q97T27 to train fasta file.
# writing Q97T80 to train fasta file.
# writing Q97T98 to train fasta file.
# writing Q97TX9 to train fasta file.
# writing Q97TZ9 to train fasta file.
# writing Q97U21 to train fasta file.
# writing Q97U27 to train fasta file.
# writing Q97U63 to train fasta file.
# writing Q97U96 to train fasta file.
# writing Q97UA0 to train fasta file.
# writing Q97UB2 to train fasta file.
# writing Q97UH6 to train fasta file.
# writing Q97UV1 to train fasta file.
# writing Q97VS5 to train fasta file.
# writing Q97VT7 to train fasta file.
# writing Q97VX5 to train fasta file.
# writing Q97VZ6 to train fasta file.
# writing Q97W51 to train fasta file.
# writing Q97W56 to train fasta file.
# writing Q97W92 to train fasta file.
# writing Q97WE6 to train fasta file.
# writing Q97WF1 to train fasta file.
# writing Q97WG9 to train fasta file.
# writing Q97WH0 to train fasta file.
# writing Q97WH1 to train fasta file.
# writing Q97WI6 to train fasta file.
# writing Q97WJ1 to train fasta file.
# writing Q97WN9 to train fasta file.
# writing Q97WW0 to train fasta file.
# writing Q97WX0 to train fasta file.
# writing Q97X14 to train fasta file.
# writing Q97X43 to train fasta file.
# writing Q97X95 to train fasta file.
# writing Q97Y16 to train fasta file.
# writing Q97Y84 to train fasta file.
# writing Q97Y85 to train fasta file.
# writing Q97YC2 to train fasta file.
# writing Q97YD4 to train fasta file.
# writing Q97YJ8 to train fasta file.
# writing Q97YU3 to train fasta file.
# writing Q97YX6 to train fasta file.
# writing Q97Z86 to train fasta file.
# writing Q97Z88 to train fasta file.
# writing Q97Z92 to train fasta file.
# writing Q97ZC4 to train fasta file.
# writing Q97ZE0 to train fasta file.
# writing Q97ZF5 to train fasta file.
# writing Q97ZG3 to train fasta file.
# writing Q97ZJ3 to train fasta file.
# writing Q97ZQ1 to train fasta file.
# writing Q97ZQ3 to train fasta file.
# writing Q97ZQ5 to train fasta file.
# writing Q97ZX2 to train fasta file.
# writing Q97ZX7 to train fasta file.
# writing Q97ZY7 to train fasta file.
# writing Q97ZY8 to train fasta file.
# writing Q97ZZ0 to train fasta file.
# writing Q97ZZ8 to train fasta file.
# writing Q98031 to train fasta file.
# writing Q980A5 to train fasta file.
# writing Q980A7 to train fasta file.
# writing Q980E8 to train fasta file.
# writing Q980F0 to train fasta file.
# writing Q980J9 to train fasta file.
# writing Q980K2 to train fasta file.
# writing Q980L7 to train fasta file.
# writing Q980N1 to train fasta file.
# writing Q980P7 to train fasta file.
# writing Q980Q6 to train fasta file.
# writing Q980R1 to train fasta file.
# writing Q980R9 to train fasta file.
# writing Q980S6 to train fasta file.
# writing Q980U8 to train fasta file.
# writing Q980V3 to train fasta file.
# writing Q980W4 to train fasta file.
# writing Q980W5 to train fasta file.
# writing Q980W8 to train fasta file.
# writing Q980Z8 to train fasta file.
# writing Q981B9 to train fasta file.
# writing Q981C9 to train fasta file.
# writing Q982F2 to train fasta file.
# writing Q982V5 to train fasta file.
# writing Q983A3 to train fasta file.
# writing Q983I1 to train fasta file.
# writing Q983J4 to train fasta file.
# writing Q983J7 to train fasta file.
# writing Q984S1 to train fasta file.
# writing Q984X8 to train fasta file.
# writing Q985M6 to train fasta file.
# writing Q985W1 to train fasta file.
# writing Q985W3 to train fasta file.
# writing Q985X9 to train fasta file.
# writing Q985Y3 to train fasta file.
# writing Q986A5 to train fasta file.
# writing Q986D0 to train fasta file.
# writing Q98776 to train fasta file.
# writing Q987C6 to train fasta file.
# writing Q98803 to train fasta file.
# writing Q98862 to train fasta file.
# writing Q988B9 to train fasta file.
# writing Q988D0 to train fasta file.
# writing Q988P7 to train fasta file.
# writing Q98931 to train fasta file.
# writing Q98938 to train fasta file.
# writing Q98953 to train fasta file.
# writing Q98996 to train fasta file.
# writing Q989E7 to train fasta file.
# writing Q989L5 to train fasta file.
# writing Q989T9 to train fasta file.
# writing Q98AM3 to train fasta file.
# writing Q98AP7 to train fasta file.
# writing Q98AV7 to train fasta file.
# writing Q98AZ3 to train fasta file.
# writing Q98B65 to train fasta file.
# writing Q98BG5 to train fasta file.
# writing Q98BI3 to train fasta file.
# writing Q98BK3 to train fasta file.
# writing Q98BZ8 to train fasta file.
# writing Q98CL7 to train fasta file.
# writing Q98CQ1 to train fasta file.
# writing Q98CT8 to train fasta file.
# writing Q98CY9 to train fasta file.
# writing Q98D10 to train fasta file.
# writing Q98D52 to train fasta file.
# writing Q98D57 to train fasta file.
# writing Q98D85 to train fasta file.
# writing Q98DD2 to train fasta file.
# writing Q98DK4 to train fasta file.
# writing Q98DZ0 to train fasta file.
# writing Q98E57 to train fasta file.
# writing Q98EC5 to train fasta file.
# writing Q98EI6 to train fasta file.
# writing Q98ER2 to train fasta file.
# writing Q98ET0 to train fasta file.
# writing Q98ET8 to train fasta file.
# writing Q98EZ3 to train fasta file.
# writing Q98F59 to train fasta file.
# writing Q98F72 to train fasta file.
# writing Q98F91 to train fasta file.
# writing Q98F97 to train fasta file.
# writing Q98FG0 to train fasta file.
# writing Q98FW0 to train fasta file.
# writing Q98G02 to train fasta file.
# writing Q98G67 to train fasta file.
# writing Q98GP9 to train fasta file.
# writing Q98GV2 to train fasta file.
# writing Q98H61 to train fasta file.
# writing Q98HR4 to train fasta file.
# writing Q98HW3 to train fasta file.
# writing Q98I56 to train fasta file.
# writing Q98I87 to train fasta file.
# writing Q98JS0 to train fasta file.
# writing Q98KC4 to train fasta file.
# writing Q98KM7 to train fasta file.
# writing Q98KQ6 to train fasta file.
# writing Q98KR4 to train fasta file.
# writing Q98KT9 to train fasta file.
# writing Q98LB3 to train fasta file.
# writing Q98LC9 to train fasta file.
# writing Q98LQ5 to train fasta file.
# writing Q98LQ6 to train fasta file.
# writing Q98LV1 to train fasta file.
# writing Q98LX2 to train fasta file.
# writing Q98MB9 to train fasta file.
# writing Q98MC1 to train fasta file.
# writing Q98ME4 to train fasta file.
# writing Q98MF0 to train fasta file.
# writing Q98MK2 to train fasta file.
# writing Q98MK6 to train fasta file.
# writing Q98ML8 to train fasta file.
# writing Q98MN9 to train fasta file.
# writing Q98MX9 to train fasta file.
# writing Q98MY2 to train fasta file.
# writing Q98MZ3 to train fasta file.
# writing Q98N65 to train fasta file.
# writing Q98NH3 to train fasta file.
# writing Q98NQ5 to train fasta file.
# writing Q98NQ8 to train fasta file.
# writing Q98NW7 to train fasta file.
# writing Q98PE4 to train fasta file.
# writing Q98PH6 to train fasta file.
# writing Q98PI9 to train fasta file.
# writing Q98PL1 to train fasta file.
# writing Q98PN8 to train fasta file.
# writing Q98PQ3 to train fasta file.
# writing Q98PU6 to train fasta file.
# writing Q98PU8 to train fasta file.
# writing Q98PW8 to train fasta file.
# writing Q98Q02 to train fasta file.
# writing Q98Q12 to train fasta file.
# writing Q98Q24 to train fasta file.
# writing Q98Q50 to train fasta file.
# writing Q98Q96 to train fasta file.
# writing Q98QA7 to train fasta file.
# writing Q98QB3 to train fasta file.
# writing Q98QG4 to train fasta file.
# writing Q98QH1 to train fasta file.
# writing Q98QH2 to train fasta file.
# writing Q98QI3 to train fasta file.
# writing Q98QK8 to train fasta file.
# writing Q98QL4 to train fasta file.
# writing Q98QP0 to train fasta file.
# writing Q98QT4 to train fasta file.
# writing Q98QX1 to train fasta file.
# writing Q98QX2 to train fasta file.
# writing Q98R83 to train fasta file.
# writing Q98R92 to train fasta file.
# writing Q98R97 to train fasta file.
# writing Q98RJ5 to train fasta file.
# writing Q98SC7 to train fasta file.
# writing Q98SH2 to train fasta file.
# writing Q98ST7 to train fasta file.
# writing Q98TR3 to train fasta file.
# writing Q98UF6 to train fasta file.
# writing Q98VG9 to train fasta file.
# writing Q98VP9 to train fasta file.
# writing Q99028 to train fasta file.
# writing Q99041 to train fasta file.
# writing Q99044 to train fasta file.
# writing Q99046 to train fasta file.
# writing Q99049 to train fasta file.
# writing Q99055 to train fasta file.
# writing Q99056 to train fasta file.
# writing Q99132 to train fasta file.
# writing Q99148 to train fasta file.
# writing Q99244 to train fasta file.
# writing Q99246 to train fasta file.
# writing Q99258 to train fasta file.
# writing Q99315 to train fasta file.
# writing Q99334 to train fasta file.
# writing Q993T4 to train fasta file.
# writing Q99405 to train fasta file.
# writing Q99502 to train fasta file.
# writing Q99504 to train fasta file.
# writing Q99542 to train fasta file.
# writing Q99584 to train fasta file.
# writing Q99611 to train fasta file.
# writing Q99640 to train fasta file.
# writing Q99674 to train fasta file.
# writing Q99707 to train fasta file.
# writing Q99717 to train fasta file.
# writing Q99727 to train fasta file.
# writing Q99732 to train fasta file.
# writing Q99766 to train fasta file.
# writing Q99797 to train fasta file.
# writing Q99798 to train fasta file.
# writing Q997C2 to train fasta file.
# writing Q99807 to train fasta file.
# writing Q99828 to train fasta file.
# writing Q99829 to train fasta file.
# writing Q99972 to train fasta file.
# writing Q99D35 to train fasta file.
# writing Q99IB8 to train fasta file.
# writing Q99IE5 to train fasta file.
# writing Q99IE6 to train fasta file.
# writing Q99IE7 to train fasta file.
# writing Q99J72 to train fasta file.
# writing Q99J85 to train fasta file.
# writing Q99J87 to train fasta file.
# writing Q99JG7 to train fasta file.
# writing Q99JT9 to train fasta file.
# writing Q99JW2 to train fasta file.
# writing Q99KB8 to train fasta file.
# writing Q99KE1 to train fasta file.
# writing Q99KH8 to train fasta file.
# writing Q99KI0 to train fasta file.
# writing Q99KK7 to train fasta file.
# writing Q99KR3 to train fasta file.
# writing Q99KS6 to train fasta file.
# writing Q99L27 to train fasta file.
# writing Q99LF4 to train fasta file.
# writing Q99LG0 to train fasta file.
# writing Q99LI8 to train fasta file.
# writing Q99LN9 to train fasta file.
# writing Q99LS3 to train fasta file.
# writing Q99LY2 to train fasta file.
# writing Q99M02 to train fasta file.
# writing Q99M04 to train fasta file.
# writing Q99M87 to train fasta file.
# writing Q99MA2 to train fasta file.
# writing Q99MG9 to train fasta file.
# writing Q99MH6 to train fasta file.
# writing Q99ML0 to train fasta file.
# writing Q99ML9 to train fasta file.
# writing Q99MP8 to train fasta file.
# writing Q99MU0 to train fasta file.
# writing Q99MV1 to train fasta file.
# writing Q99MX0 to train fasta file.
# writing Q99MX2 to train fasta file.
# writing Q99N23 to train fasta file.
# writing Q99NF1 to train fasta file.
# writing Q99P21 to train fasta file.
# writing Q99P27 to train fasta file.
# writing Q99P39 to train fasta file.
# writing Q99P99 to train fasta file.
# writing Q99PD2 to train fasta file.
# writing Q99PL7 to train fasta file.
# writing Q99PN3 to train fasta file.
# writing Q99PP6 to train fasta file.
# writing Q99PQ1 to train fasta file.
# writing Q99PW6 to train fasta file.
# writing Q99R80 to train fasta file.
# writing Q99RE2 to train fasta file.
# writing Q99RN7 to train fasta file.
# writing Q99RW4 to train fasta file.
# writing Q99S17 to train fasta file.
# writing Q99SC3 to train fasta file.
# writing Q99SK3 to train fasta file.
# writing Q99SN6 to train fasta file.
# writing Q99SY3 to train fasta file.
# writing Q99SY8 to train fasta file.
# writing Q99SY9 to train fasta file.
# writing Q99SZ3 to train fasta file.
# writing Q99T18 to train fasta file.
# writing Q99TA0 to train fasta file.
# writing Q99TF2 to train fasta file.
# writing Q99TF5 to train fasta file.
# writing Q99TG2 to train fasta file.
# writing Q99TK9 to train fasta file.
# writing Q99U32 to train fasta file.
# writing Q99UI1 to train fasta file.
# writing Q99UJ8 to train fasta file.
# writing Q99UM1 to train fasta file.
# writing Q99US8 to train fasta file.
# writing Q99UW5 to train fasta file.
# writing Q99UW8 to train fasta file.
# writing Q99V14 to train fasta file.
# writing Q99V37 to train fasta file.
# writing Q99VC4 to train fasta file.
# writing Q99VJ0 to train fasta file.
# writing Q99VQ4 to train fasta file.
# writing Q99VR1 to train fasta file.
# writing Q99W07 to train fasta file.
# writing Q99W51 to train fasta file.
# writing Q99W73 to train fasta file.
# writing Q99WA4 to train fasta file.
# writing Q99WE9 to train fasta file.
# writing Q99WQ6 to train fasta file.
# writing Q99WV0 to train fasta file.
# writing Q99X56 to train fasta file.
# writing Q99XQ9 to train fasta file.
# writing Q99XY1 to train fasta file.
# writing Q99XY3 to train fasta file.
# writing Q99XZ5 to train fasta file.
# writing Q99XZ9 to train fasta file.
# writing Q99Y46 to train fasta file.
# writing Q99Y66 to train fasta file.
# writing Q99Y97 to train fasta file.
# writing Q99YE0 to train fasta file.
# writing Q99YK9 to train fasta file.
# writing Q99YL2 to train fasta file.
# writing Q99YP3 to train fasta file.
# writing Q99YR3 to train fasta file.
# writing Q99Z34 to train fasta file.
# writing Q99Z57 to train fasta file.
# writing Q99Z94 to train fasta file.
# writing Q99ZD0 to train fasta file.
# writing Q99ZM6 to train fasta file.
# writing Q99ZP6 to train fasta file.
# writing Q99ZR0 to train fasta file.
# writing Q99ZU0 to train fasta file.
# writing Q99ZV9 to train fasta file.
# writing Q99ZW2 to train fasta file.
# writing Q99ZW8 to train fasta file.
# writing Q9A071 to train fasta file.
# writing Q9A0A5 to train fasta file.
# writing Q9A0C6 to train fasta file.
# writing Q9A0F4 to train fasta file.
# writing Q9A0I0 to train fasta file.
# writing Q9A0J5 to train fasta file.
# writing Q9A0L0 to train fasta file.
# writing Q9A0V7 to train fasta file.
# writing Q9A115 to train fasta file.
# writing Q9A163 to train fasta file.
# writing Q9A1D5 to train fasta file.
# writing Q9A1G2 to train fasta file.
# writing Q9A1H9 to train fasta file.
# writing Q9A1K3 to train fasta file.
# writing Q9A1L6 to train fasta file.
# writing Q9A1P8 to train fasta file.
# writing Q9A1Y7 to train fasta file.
# writing Q9A239 to train fasta file.
# writing Q9A2I0 to train fasta file.
# writing Q9A2M1 to train fasta file.
# writing Q9A2N5 to train fasta file.
# writing Q9A2S6 to train fasta file.
# writing Q9A341 to train fasta file.
# writing Q9A345 to train fasta file.
# writing Q9A3D5 to train fasta file.
# writing Q9A3G6 to train fasta file.
# writing Q9A3M3 to train fasta file.
# writing Q9A3P2 to train fasta file.
# writing Q9A3P3 to train fasta file.
# writing Q9A3U9 to train fasta file.
# writing Q9A4C4 to train fasta file.
# writing Q9A4D6 to train fasta file.
# writing Q9A5B8 to train fasta file.
# writing Q9A5C1 to train fasta file.
# writing Q9A5E1 to train fasta file.
# writing Q9A5I1 to train fasta file.
# writing Q9A5I5 to train fasta file.
# writing Q9A5V1 to train fasta file.
# writing Q9A5Z2 to train fasta file.
# writing Q9A5Z3 to train fasta file.
# writing Q9A6B1 to train fasta file.
# writing Q9A6H4 to train fasta file.
# writing Q9A6M5 to train fasta file.
# writing Q9A6Q5 to train fasta file.
# writing Q9A6T5 to train fasta file.
# writing Q9A6X1 to train fasta file.
# writing Q9A6Y4 to train fasta file.
# writing Q9A6Z1 to train fasta file.
# writing Q9A707 to train fasta file.
# writing Q9A709 to train fasta file.
# writing Q9A710 to train fasta file.
# writing Q9A728 to train fasta file.
# writing Q9A7I5 to train fasta file.
# writing Q9A7I8 to train fasta file.
# writing Q9A7J9 to train fasta file.
# writing Q9A7K3 to train fasta file.
# writing Q9A7M9 to train fasta file.
# writing Q9A7Z2 to train fasta file.
# writing Q9A842 to train fasta file.
# writing Q9A873 to train fasta file.
# writing Q9A884 to train fasta file.
# writing Q9A8G9 to train fasta file.
# writing Q9A8J0 to train fasta file.
# writing Q9A8J2 to train fasta file.
# writing Q9A8M7 to train fasta file.
# writing Q9A9E5 to train fasta file.
# writing Q9A9W0 to train fasta file.
# writing Q9A9Z2 to train fasta file.
# writing Q9AAT8 to train fasta file.
# writing Q9AAU1 to train fasta file.
# writing Q9AAV6 to train fasta file.
# writing Q9AAY2 to train fasta file.
# writing Q9AAY3 to train fasta file.
# writing Q9AAY5 to train fasta file.
# writing Q9AB94 to train fasta file.
# writing Q9ABD2 to train fasta file.
# writing Q9ABF3 to train fasta file.
# writing Q9ABF5 to train fasta file.
# writing Q9ABN3 to train fasta file.
# writing Q9ABV3 to train fasta file.
# writing Q9ABZ9 to train fasta file.
# writing Q9AC20 to train fasta file.
# writing Q9AC48 to train fasta file.
# writing Q9ADA4 to train fasta file.
# writing Q9ADG3 to train fasta file.
# writing Q9ADK0 to train fasta file.
# writing Q9AE11 to train fasta file.
# writing Q9AE55 to train fasta file.
# writing Q9AE63 to train fasta file.
# writing Q9AEM1 to train fasta file.
# writing Q9AEU2 to train fasta file.
# writing Q9AF95 to train fasta file.
# writing Q9AGA6 to train fasta file.
# writing Q9AGC0 to train fasta file.
# writing Q9AGJ6 to train fasta file.
# writing Q9AGR3 to train fasta file.
# writing Q9AGW2 to train fasta file.
# writing Q9AGW3 to train fasta file.
# writing Q9AGY5 to train fasta file.
# writing Q9AGY7 to train fasta file.
# writing Q9AHG2 to train fasta file.
# writing Q9AHG3 to train fasta file.
# writing Q9AHK1 to train fasta file.
# writing Q9AI34 to train fasta file.
# writing Q9AI36 to train fasta file.
# writing Q9AI65 to train fasta file.
# writing Q9AIU7 to train fasta file.
# writing Q9AJD7 to train fasta file.
# writing Q9AJQ8 to train fasta file.
# writing Q9AJU0 to train fasta file.
# writing Q9AJU1 to train fasta file.
# writing Q9AJU2 to train fasta file.
# writing Q9AK25 to train fasta file.
# writing Q9AKC4 to train fasta file.
# writing Q9AKH1 to train fasta file.
# writing Q9AKM6 to train fasta file.
# writing Q9AKT4 to train fasta file.
# writing Q9AKT8 to train fasta file.
# writing Q9AL93 to train fasta file.
# writing Q9AL94 to train fasta file.
# writing Q9AMC5 to train fasta file.
# writing Q9AMS4 to train fasta file.
# writing Q9AMS7 to train fasta file.
# writing Q9ANP1 to train fasta file.
# writing Q9ANP8 to train fasta file.
# writing Q9AQC8 to train fasta file.
# writing Q9AQI0 to train fasta file.
# writing Q9AQS0 to train fasta file.
# writing Q9AR04 to train fasta file.
# writing Q9AR07 to train fasta file.
# writing Q9AR86 to train fasta file.
# writing Q9ARF9 to train fasta file.
# writing Q9ATB4 to train fasta file.
# writing Q9AV71 to train fasta file.
# writing Q9AVJ9 to train fasta file.
# writing Q9AVK0 to train fasta file.
# writing Q9AVK1 to train fasta file.
# writing Q9AVL9 to train fasta file.
# writing Q9AWB2 to train fasta file.
# writing Q9AXK1 to train fasta file.
# writing Q9AXK2 to train fasta file.
# writing Q9B229 to train fasta file.
# writing Q9B6D5 to train fasta file.
# writing Q9B6E7 to train fasta file.
# writing Q9B840 to train fasta file.
# writing Q9B8D8 to train fasta file.
# writing Q9BA49 to train fasta file.
# writing Q9BAE0 to train fasta file.
# writing Q9BBC1 to train fasta file.
# writing Q9BBP0 to train fasta file.
# writing Q9BBS1 to train fasta file.
# writing Q9BBS8 to train fasta file.
# writing Q9BBT0 to train fasta file.
# writing Q9BBT7 to train fasta file.
# writing Q9BBU1 to train fasta file.
# writing Q9BBU3 to train fasta file.
# writing Q9BDE0 to train fasta file.
# writing Q9BDK2 to train fasta file.
# writing Q9BDY7 to train fasta file.
# writing Q9BG99 to train fasta file.
# writing Q9BGI0 to train fasta file.
# writing Q9BGN0 to train fasta file.
# writing Q9BGW0 to train fasta file.
# writing Q9BH41 to train fasta file.
# writing Q9BI88 to train fasta file.
# writing Q9BIC6 to train fasta file.
# writing Q9BIG4 to train fasta file.
# writing Q9BIG5 to train fasta file.
# writing Q9BMK4 to train fasta file.
# writing Q9BN01 to train fasta file.
# writing Q9BPL7 to train fasta file.
# writing Q9BPX6 to train fasta file.
# writing Q9BQ24 to train fasta file.
# writing Q9BQ50 to train fasta file.
# writing Q9BQC3 to train fasta file.
# writing Q9BQG1 to train fasta file.
# writing Q9BQI0 to train fasta file.
# writing Q9BRC7 to train fasta file.
# writing Q9BRK5 to train fasta file.
# writing Q9BRR6 to train fasta file.
# writing Q9BRS2 to train fasta file.
# writing Q9BRZ2 to train fasta file.
# writing Q9BSE5 to train fasta file.
# writing Q9BSJ1 to train fasta file.
# writing Q9BSJ8 to train fasta file.
# writing Q9BSW2 to train fasta file.
# writing Q9BT23 to train fasta file.
# writing Q9BT88 to train fasta file.
# writing Q9BTE6 to train fasta file.
# writing Q9BTP6 to train fasta file.
# writing Q9BU02 to train fasta file.
# writing Q9BU89 to train fasta file.
# writing Q9BUA6 to train fasta file.
# writing Q9BUB4 to train fasta file.
# writing Q9BUD6 to train fasta file.
# writing Q9BUE6 to train fasta file.
# writing Q9BUP0 to train fasta file.
# writing Q9BUY7 to train fasta file.
# writing Q9BV35 to train fasta file.
# writing Q9BV57 to train fasta file.
# writing Q9BV68 to train fasta file.
# writing Q9BW85 to train fasta file.
# writing Q9BWP8 to train fasta file.
# writing Q9BWT3 to train fasta file.
# writing Q9BWV3 to train fasta file.
# writing Q9BX84 to train fasta file.
# writing Q9BX93 to train fasta file.
# writing Q9BXN2 to train fasta file.
# writing Q9BXR0 to train fasta file.
# writing Q9BXR3 to train fasta file.
# writing Q9BXS1 to train fasta file.
# writing Q9BXT4 to train fasta file.
# writing Q9BXU8 to train fasta file.
# writing Q9BXY5 to train fasta file.
# writing Q9BY41 to train fasta file.
# writing Q9BYJ1 to train fasta file.
# writing Q9BYJ4 to train fasta file.
# writing Q9BYM8 to train fasta file.
# writing Q9BYT8 to train fasta file.
# writing Q9BYV2 to train fasta file.
# writing Q9BYV6 to train fasta file.
# writing Q9BYV7 to train fasta file.
# writing Q9BYX4 to train fasta file.
# writing Q9BZB8 to train fasta file.
# writing Q9BZG8 to train fasta file.
# writing Q9BZM1 to train fasta file.
# writing Q9BZM2 to train fasta file.
# writing Q9BZQ6 to train fasta file.
# writing Q9BZY9 to train fasta file.
# writing Q9C019 to train fasta file.
# writing Q9C026 to train fasta file.
# writing Q9C029 to train fasta file.
# writing Q9C030 to train fasta file.
# writing Q9C035 to train fasta file.
# writing Q9C040 to train fasta file.
# writing Q9C0B1 to train fasta file.
# writing Q9C0N4 to train fasta file.
# writing Q9C0T1 to train fasta file.
# writing Q9C0T9 to train fasta file.
# writing Q9C0V7 to train fasta file.
# writing Q9C0W1 to train fasta file.
# writing Q9C102 to train fasta file.
# writing Q9C206 to train fasta file.
# writing Q9C2P2 to train fasta file.
# writing Q9C2U0 to train fasta file.
# writing Q9C2Z0 to train fasta file.
# writing Q9C446 to train fasta file.
# writing Q9C448 to train fasta file.
# writing Q9C4M3 to train fasta file.
# writing Q9C4Z0 to train fasta file.
# writing Q9C510 to train fasta file.
# writing Q9C512 to train fasta file.
# writing Q9C516 to train fasta file.
# writing Q9C5A4 to train fasta file.
# writing Q9C5C4 to train fasta file.
# writing Q9C5C8 to train fasta file.
# writing Q9C5D3 to train fasta file.
# writing Q9C5D7 to train fasta file.
# writing Q9C5G0 to train fasta file.
# writing Q9C5J7 to train fasta file.
# writing Q9C5M8 to train fasta file.
# writing Q9C5Q8 to train fasta file.
# writing Q9C5T3 to train fasta file.
# writing Q9C5U8 to train fasta file.
# writing Q9C5W0 to train fasta file.
# writing Q9C5X4 to train fasta file.
# writing Q9C5X9 to train fasta file.
# writing Q9C5Y0 to train fasta file.
# writing Q9C6B3 to train fasta file.
# writing Q9C6H2 to train fasta file.
# writing Q9C6H3 to train fasta file.
# writing Q9C6H4 to train fasta file.
# writing Q9C6I4 to train fasta file.
# writing Q9C6M9 to train fasta file.
# writing Q9C6P3 to train fasta file.
# writing Q9C6W6 to train fasta file.
# writing Q9C6Z1 to train fasta file.
# writing Q9C6Z2 to train fasta file.
# writing Q9C748 to train fasta file.
# writing Q9C777 to train fasta file.
# writing Q9C7E8 to train fasta file.
# writing Q9C7J6 to train fasta file.
# writing Q9C7Z1 to train fasta file.
# writing Q9C888 to train fasta file.
# writing Q9C899 to train fasta file.
# writing Q9C8E3 to train fasta file.
# writing Q9C8G4 to train fasta file.
# writing Q9C8H3 to train fasta file.
# writing Q9C8L4 to train fasta file.
# writing Q9C8M2 to train fasta file.
# writing Q9C8S6 to train fasta file.
# writing Q9C927 to train fasta file.
# writing Q9C955 to train fasta file.
# writing Q9C975 to train fasta file.
# writing Q9C9A3 to train fasta file.
# writing Q9C9A9 to train fasta file.
# writing Q9C9C4 to train fasta file.
# writing Q9C9F4 to train fasta file.
# writing Q9C9M0 to train fasta file.
# writing Q9C9W3 to train fasta file.
# writing Q9C9W4 to train fasta file.
# writing Q9C9X3 to train fasta file.
# writing Q9C9X7 to train fasta file.
# writing Q9CA40 to train fasta file.
# writing Q9CA74 to train fasta file.
# writing Q9CA83 to train fasta file.
# writing Q9CAB7 to train fasta file.
# writing Q9CAB8 to train fasta file.
# writing Q9CAF2 to train fasta file.
# writing Q9CAI3 to train fasta file.
# writing Q9CAJ0 to train fasta file.
# writing Q9CAK8 to train fasta file.
# writing Q9CB92 to train fasta file.
# writing Q9CBA4 to train fasta file.
# writing Q9CBB2 to train fasta file.
# writing Q9CBD6 to train fasta file.
# writing Q9CBI2 to train fasta file.
# writing Q9CBI6 to train fasta file.
# writing Q9CBM2 to train fasta file.
# writing Q9CBQ2 to train fasta file.
# writing Q9CBQ5 to train fasta file.
# writing Q9CBS0 to train fasta file.
# writing Q9CBU3 to train fasta file.
# writing Q9CBU4 to train fasta file.
# writing Q9CBU5 to train fasta file.
# writing Q9CBW6 to train fasta file.
# writing Q9CBX4 to train fasta file.
# writing Q9CBX6 to train fasta file.
# writing Q9CBY6 to train fasta file.
# writing Q9CBZ4 to train fasta file.
# writing Q9CC16 to train fasta file.
# writing Q9CC23 to train fasta file.
# writing Q9CC57 to train fasta file.
# writing Q9CC91 to train fasta file.
# writing Q9CC97 to train fasta file.
# writing Q9CCE3 to train fasta file.
# writing Q9CCF8 to train fasta file.
# writing Q9CCK2 to train fasta file.
# writing Q9CCL9 to train fasta file.
# writing Q9CCP9 to train fasta file.
# writing Q9CCR2 to train fasta file.
# writing Q9CCR4 to train fasta file.
# writing Q9CCS4 to train fasta file.
# writing Q9CCS5 to train fasta file.
# writing Q9CCT0 to train fasta file.
# writing Q9CCW5 to train fasta file.
# writing Q9CD42 to train fasta file.
# writing Q9CD44 to train fasta file.
# writing Q9CD45 to train fasta file.
# writing Q9CD58 to train fasta file.
# writing Q9CDD2 to train fasta file.
# writing Q9CDG3 to train fasta file.
# writing Q9CDH8 to train fasta file.
# writing Q9CDL9 to train fasta file.
# writing Q9CDT1 to train fasta file.
# writing Q9CDT3 to train fasta file.
# writing Q9CE21 to train fasta file.
# writing Q9CE35 to train fasta file.
# writing Q9CE36 to train fasta file.
# writing Q9CE93 to train fasta file.
# writing Q9CEB5 to train fasta file.
# writing Q9CEB7 to train fasta file.
# writing Q9CED2 to train fasta file.
# writing Q9CEF8 to train fasta file.
# writing Q9CEI4 to train fasta file.
# writing Q9CEI6 to train fasta file.
# writing Q9CEJ0 to train fasta file.
# writing Q9CEM7 to train fasta file.
# writing Q9CEN7 to train fasta file.
# writing Q9CEU1 to train fasta file.
# writing Q9CEV7 to train fasta file.
# writing Q9CEW0 to train fasta file.
# writing Q9CF42 to train fasta file.
# writing Q9CF94 to train fasta file.
# writing Q9CFC2 to train fasta file.
# writing Q9CFU9 to train fasta file.
# writing Q9CFV2 to train fasta file.
# writing Q9CFW7 to train fasta file.
# writing Q9CFZ5 to train fasta file.
# writing Q9CG17 to train fasta file.
# writing Q9CG48 to train fasta file.
# writing Q9CG80 to train fasta file.
# writing Q9CGE1 to train fasta file.
# writing Q9CGE6 to train fasta file.
# writing Q9CGF7 to train fasta file.
# writing Q9CGJ4 to train fasta file.
# writing Q9CGM7 to train fasta file.
# writing Q9CGT5 to train fasta file.
# writing Q9CH12 to train fasta file.
# writing Q9CH95 to train fasta file.
# writing Q9CHB8 to train fasta file.
# writing Q9CHD0 to train fasta file.
# writing Q9CHF2 to train fasta file.
# writing Q9CHN9 to train fasta file.
# writing Q9CHS7 to train fasta file.
# writing Q9CHT8 to train fasta file.
# writing Q9CHW3 to train fasta file.
# writing Q9CHX5 to train fasta file.
# writing Q9CI22 to train fasta file.
# writing Q9CI75 to train fasta file.
# writing Q9CID9 to train fasta file.
# writing Q9CIE4 to train fasta file.
# writing Q9CII7 to train fasta file.
# writing Q9CIL5 to train fasta file.
# writing Q9CIQ1 to train fasta file.
# writing Q9CIR1 to train fasta file.
# writing Q9CIR9 to train fasta file.
# writing Q9CIT0 to train fasta file.
# writing Q9CIU0 to train fasta file.
# writing Q9CIV7 to train fasta file.
# writing Q9CJ54 to train fasta file.
# writing Q9CJ82 to train fasta file.
# writing Q9CJJ0 to train fasta file.
# writing Q9CJL2 to train fasta file.
# writing Q9CJL4 to train fasta file.
# writing Q9CJN6 to train fasta file.
# writing Q9CJT7 to train fasta file.
# writing Q9CJW9 to train fasta file.
# writing Q9CK29 to train fasta file.
# writing Q9CK92 to train fasta file.
# writing Q9CK98 to train fasta file.
# writing Q9CKA9 to train fasta file.
# writing Q9CKB3 to train fasta file.
# writing Q9CKG8 to train fasta file.
# writing Q9CKJ5 to train fasta file.
# writing Q9CKL8 to train fasta file.
# writing Q9CKN9 to train fasta file.
# writing Q9CKP9 to train fasta file.
# writing Q9CKR4 to train fasta file.
# writing Q9CKV0 to train fasta file.
# writing Q9CL73 to train fasta file.
# writing Q9CLA6 to train fasta file.
# writing Q9CLI9 to train fasta file.
# writing Q9CLM4 to train fasta file.
# writing Q9CLP2 to train fasta file.
# writing Q9CLQ1 to train fasta file.
# writing Q9CLT2 to train fasta file.
# writing Q9CLT9 to train fasta file.
# writing Q9CLU1 to train fasta file.
# writing Q9CLV7 to train fasta file.
# writing Q9CLW4 to train fasta file.
# writing Q9CLZ5 to train fasta file.
# writing Q9CM00 to train fasta file.
# writing Q9CM16 to train fasta file.
# writing Q9CM18 to train fasta file.
# writing Q9CM22 to train fasta file.
# writing Q9CM50 to train fasta file.
# writing Q9CM94 to train fasta file.
# writing Q9CMA4 to train fasta file.
# writing Q9CMB1 to train fasta file.
# writing Q9CMD1 to train fasta file.
# writing Q9CMJ8 to train fasta file.
# writing Q9CMN5 to train fasta file.
# writing Q9CMR5 to train fasta file.
# writing Q9CMS2 to train fasta file.
# writing Q9CMW1 to train fasta file.
# writing Q9CMW8 to train fasta file.
# writing Q9CN08 to train fasta file.
# writing Q9CN12 to train fasta file.
# writing Q9CN21 to train fasta file.
# writing Q9CN30 to train fasta file.
# writing Q9CNG4 to train fasta file.
# writing Q9CNH3 to train fasta file.
# writing Q9CNJ0 to train fasta file.
# writing Q9CNP1 to train fasta file.
# writing Q9CNP2 to train fasta file.
# writing Q9CNP8 to train fasta file.
# writing Q9CNS4 to train fasta file.
# writing Q9CNV8 to train fasta file.
# writing Q9CNZ0 to train fasta file.
# writing Q9CP05 to train fasta file.
# writing Q9CP11 to train fasta file.
# writing Q9CP21 to train fasta file.
# writing Q9CP22 to train fasta file.
# writing Q9CP53 to train fasta file.
# writing Q9CP69 to train fasta file.
# writing Q9CP90 to train fasta file.
# writing Q9CPA5 to train fasta file.
# writing Q9CPE3 to train fasta file.
# writing Q9CPH1 to train fasta file.
# writing Q9CPH2 to train fasta file.
# writing Q9CPI5 to train fasta file.
# writing Q9CPL4 to train fasta file.
# writing Q9CPN6 to train fasta file.
# writing Q9CPU0 to train fasta file.
# writing Q9CPW2 to train fasta file.
# writing Q9CPW9 to train fasta file.
# writing Q9CPX9 to train fasta file.
# writing Q9CPY7 to train fasta file.
# writing Q9CQ04 to train fasta file.
# writing Q9CQ19 to train fasta file.
# writing Q9CQ26 to train fasta file.
# writing Q9CQA3 to train fasta file.
# writing Q9CQB5 to train fasta file.
# writing Q9CQC9 to train fasta file.
# writing Q9CQE0 to train fasta file.
# writing Q9CQF6 to train fasta file.
# writing Q9CQG3 to train fasta file.
# writing Q9CQK1 to train fasta file.
# writing Q9CQM9 to train fasta file.
# writing Q9CQZ7 to train fasta file.
# writing Q9CR24 to train fasta file.
# writing Q9CR25 to train fasta file.
# writing Q9CR68 to train fasta file.
# writing Q9CRA7 to train fasta file.
# writing Q9CRY7 to train fasta file.
# writing Q9CS42 to train fasta file.
# writing Q9CS84 to train fasta file.
# writing Q9CTG6 to train fasta file.
# writing Q9CTY5 to train fasta file.
# writing Q9CW73 to train fasta file.
# writing Q9CWD0 to train fasta file.
# writing Q9CWD3 to train fasta file.
# writing Q9CWR2 to train fasta file.
# writing Q9CWS0 to train fasta file.
# writing Q9CWW7 to train fasta file.
# writing Q9CWY8 to train fasta file.
# writing Q9CXI3 to train fasta file.
# writing Q9CXP9 to train fasta file.
# writing Q9CXS4 to train fasta file.
# writing Q9CXT8 to train fasta file.
# writing Q9CY28 to train fasta file.
# writing Q9CY64 to train fasta file.
# writing Q9CYB0 to train fasta file.
# writing Q9CYK2 to train fasta file.
# writing Q9CYR6 to train fasta file.
# writing Q9CZ52 to train fasta file.
# writing Q9CZJ0 to train fasta file.
# writing Q9CZJ6 to train fasta file.
# writing Q9CZR2 to train fasta file.
# writing Q9CZX0 to train fasta file.
# writing Q9D020 to train fasta file.
# writing Q9D099 to train fasta file.
# writing Q9D0D3 to train fasta file.
# writing Q9D0E5 to train fasta file.
# writing Q9D0F3 to train fasta file.
# writing Q9D0F9 to train fasta file.
# writing Q9D110 to train fasta file.
# writing Q9D113 to train fasta file.
# writing Q9D114 to train fasta file.
# writing Q9D136 to train fasta file.
# writing Q9D1A2 to train fasta file.
# writing Q9D1I5 to train fasta file.
# writing Q9D1P4 to train fasta file.
# writing Q9D2H5 to train fasta file.
# writing Q9D2L1 to train fasta file.
# writing Q9D2N4 to train fasta file.
# writing Q9D2N8 to train fasta file.
# writing Q9D361 to train fasta file.
# writing Q9D3N2 to train fasta file.
# writing Q9D3U0 to train fasta file.
# writing Q9D4D4 to train fasta file.
# writing Q9D4J1 to train fasta file.
# writing Q9D5H4 to train fasta file.
# writing Q9D5U0 to train fasta file.
# writing Q9D5U5 to train fasta file.
# writing Q9D5Z5 to train fasta file.
# writing Q9D6H2 to train fasta file.
# writing Q9D6J3 to train fasta file.
# writing Q9D6J6 to train fasta file.
# writing Q9D6N1 to train fasta file.
# writing Q9D708 to train fasta file.
# writing Q9D711 to train fasta file.
# writing Q9D7C9 to train fasta file.
# writing Q9D7G0 to train fasta file.
# writing Q9D7I5 to train fasta file.
# writing Q9D7I9 to train fasta file.
# writing Q9D7J7 to train fasta file.
# writing Q9D7Z6 to train fasta file.
# writing Q9D805 to train fasta file.
# writing Q9D819 to train fasta file.
# writing Q9D823 to train fasta file.
# writing Q9D8F1 to train fasta file.
# writing Q9D8S4 to train fasta file.
# writing Q9D8T3 to train fasta file.
# writing Q9D8X5 to train fasta file.
# writing Q9D8Y0 to train fasta file.
# writing Q9D8Y8 to train fasta file.
# writing Q9D924 to train fasta file.
# writing Q9D9M2 to train fasta file.
# writing Q9D9M5 to train fasta file.
# writing Q9D9N5 to train fasta file.
# writing Q9D9R0 to train fasta file.
# writing Q9D9X6 to train fasta file.
# writing Q9DAM2 to train fasta file.
# writing Q9DAN6 to train fasta file.
# writing Q9DAZ9 to train fasta file.
# writing Q9DB26 to train fasta file.
# writing Q9DB32 to train fasta file.
# writing Q9DB75 to train fasta file.
# writing Q9DBA8 to train fasta file.
# writing Q9DBD2 to train fasta file.
# writing Q9DBH5 to train fasta file.
# writing Q9DBY1 to train fasta file.
# writing Q9DC51 to train fasta file.
# writing Q9DC53 to train fasta file.
# writing Q9DC70 to train fasta file.
# writing Q9DCB8 to train fasta file.
# writing Q9DCH6 to train fasta file.
# writing Q9DCL2 to train fasta file.
# writing Q9DCM0 to train fasta file.
# writing Q9DCZ1 to train fasta file.
# writing Q9DDD0 to train fasta file.
# writing Q9DE46 to train fasta file.
# writing Q9DED5 to train fasta file.
# writing Q9DER7 to train fasta file.
# writing Q9DEV3 to train fasta file.
# writing Q9DEY9 to train fasta file.
# writing Q9DF33 to train fasta file.
# writing Q9DF52 to train fasta file.
# writing Q9DF56 to train fasta file.
# writing Q9DFZ3 to train fasta file.
# writing Q9DFZ4 to train fasta file.
# writing Q9DG31 to train fasta file.
# writing Q9DG42 to train fasta file.
# writing Q9DGG5 to train fasta file.
# writing Q9DGG6 to train fasta file.
# writing Q9DHD6 to train fasta file.
# writing Q9DHV7 to train fasta file.
# writing Q9DK04 to train fasta file.
# writing Q9DUE1 to train fasta file.
# writing Q9DXE5 to train fasta file.
# writing Q9E6N7 to train fasta file.
# writing Q9E779 to train fasta file.
# writing Q9E8F2 to train fasta file.
# writing Q9EA42 to train fasta file.
# writing Q9EMA9 to train fasta file.
# writing Q9EP80 to train fasta file.
# writing Q9EPA0 to train fasta file.
# writing Q9EPF3 to train fasta file.
# writing Q9EPK8 to train fasta file.
# writing Q9EPL5 to train fasta file.
# writing Q9EPL6 to train fasta file.
# writing Q9EPR2 to train fasta file.
# writing Q9EPS3 to train fasta file.
# writing Q9EPU0 to train fasta file.
# writing Q9EPY0 to train fasta file.
# writing Q9EQ60 to train fasta file.
# writing Q9EQC9 to train fasta file.
# writing Q9EQF2 to train fasta file.
# writing Q9EQF5 to train fasta file.
# writing Q9EQG7 to train fasta file.
# writing Q9EQH2 to train fasta file.
# writing Q9EQP0 to train fasta file.
# writing Q9EQP2 to train fasta file.
# writing Q9EQQ0 to train fasta file.
# writing Q9EQV6 to train fasta file.
# writing Q9EQV8 to train fasta file.
# writing Q9EQV9 to train fasta file.
# writing Q9EQX4 to train fasta file.
# writing Q9ER34 to train fasta file.
# writing Q9ER56 to train fasta file.
# writing Q9ER72 to train fasta file.
# writing Q9ERC5 to train fasta file.
# writing Q9ERI5 to train fasta file.
# writing Q9ERP3 to train fasta file.
# writing Q9ERQ8 to train fasta file.
# writing Q9ERZ8 to train fasta file.
# writing Q9ES45 to train fasta file.
# writing Q9ESC7 to train fasta file.
# writing Q9ESD7 to train fasta file.
# writing Q9ESF1 to train fasta file.
# writing Q9ESG9 to train fasta file.
# writing Q9ESK4 to train fasta file.
# writing Q9ESM6 to train fasta file.
# writing Q9ESN1 to train fasta file.
# writing Q9ESN6 to train fasta file.
# writing Q9ESP7 to train fasta file.
# writing Q9ESQ5 to train fasta file.
# writing Q9ET26 to train fasta file.
# writing Q9ET32 to train fasta file.
# writing Q9ET64 to train fasta file.
# writing Q9EUQ2 to train fasta file.
# writing Q9EUS8 to train fasta file.
# writing Q9EV05 to train fasta file.
# writing Q9EV47 to train fasta file.
# writing Q9EVE1 to train fasta file.
# writing Q9EVG3 to train fasta file.
# writing Q9EVG6 to train fasta file.
# writing Q9EVG9 to train fasta file.
# writing Q9EVH5 to train fasta file.
# writing Q9EVH8 to train fasta file.
# writing Q9EVI1 to train fasta file.
# writing Q9EVI4 to train fasta file.
# writing Q9EVI7 to train fasta file.
# writing Q9EXU8 to train fasta file.
# writing Q9EXV4 to train fasta file.
# writing Q9EYG9 to train fasta file.
# writing Q9EYH3 to train fasta file.
# writing Q9EYN8 to train fasta file.
# writing Q9EYP3 to train fasta file.
# writing Q9EYU0 to train fasta file.
# writing Q9EYX5 to train fasta file.
# writing Q9EYY5 to train fasta file.
# writing Q9EZ02 to train fasta file.
# writing Q9F0D4 to train fasta file.
# writing Q9F0I7 to train fasta file.
# writing Q9F0V0 to train fasta file.
# writing Q9F0W4 to train fasta file.
# writing Q9F1S9 to train fasta file.
# writing Q9F1V2 to train fasta file.
# writing Q9F1V8 to train fasta file.
# writing Q9F1X7 to train fasta file.
# writing Q9F1Y6 to train fasta file.
# writing Q9F2I9 to train fasta file.
# writing Q9F2Q3 to train fasta file.
# writing Q9F2V2 to train fasta file.
# writing Q9F2V8 to train fasta file.
# writing Q9F2W1 to train fasta file.
# writing Q9F316 to train fasta file.
# writing Q9F326 to train fasta file.
# writing Q9F344 to train fasta file.
# writing Q9F364 to train fasta file.
# writing Q9F3C7 to train fasta file.
# writing Q9F3P9 to train fasta file.
# writing Q9F437 to train fasta file.
# writing Q9F4F7 to train fasta file.
# writing Q9F6X3 to train fasta file.
# writing Q9F6X5 to train fasta file.
# writing Q9F6X6 to train fasta file.
# writing Q9F714 to train fasta file.
# writing Q9F715 to train fasta file.
# writing Q9F716 to train fasta file.
# writing Q9F722 to train fasta file.
# writing Q9F7A2 to train fasta file.
# writing Q9F7L6 to train fasta file.
# writing Q9F7R5 to train fasta file.
# writing Q9F7Y9 to train fasta file.
# writing Q9F854 to train fasta file.
# writing Q9F8X1 to train fasta file.
# writing Q9F930 to train fasta file.
# writing Q9FAD7 to train fasta file.
# writing Q9FAF8 to train fasta file.
# writing Q9FAX1 to train fasta file.
# writing Q9FAX2 to train fasta file.
# writing Q9FB57 to train fasta file.
# writing Q9FBG4 to train fasta file.
# writing Q9FBM1 to train fasta file.
# writing Q9FBT8 to train fasta file.
# writing Q9FC99 to train fasta file.
# writing Q9FCA2 to train fasta file.
# writing Q9FCD3 to train fasta file.
# writing Q9FCG5 to train fasta file.
# writing Q9FCV3 to train fasta file.
# writing Q9FDL5 to train fasta file.
# writing Q9FDN6 to train fasta file.
# writing Q9FDN7 to train fasta file.
# writing Q9FDX6 to train fasta file.
# writing Q9FDX8 to train fasta file.
# writing Q9FE01 to train fasta file.
# writing Q9FE17 to train fasta file.
# writing Q9FEE2 to train fasta file.
# writing Q9FFA1 to train fasta file.
# writing Q9FFC7 to train fasta file.
# writing Q9FFE0 to train fasta file.
# writing Q9FFF6 to train fasta file.
# writing Q9FFH3 to train fasta file.
# writing Q9FFN9 to train fasta file.
# writing Q9FFP1 to train fasta file.
# writing Q9FFQ4 to train fasta file.
# writing Q9FFQ5 to train fasta file.
# writing Q9FG34 to train fasta file.
# writing Q9FG61 to train fasta file.
# writing Q9FG77 to train fasta file.
# writing Q9FG93 to train fasta file.
# writing Q9FGD6 to train fasta file.
# writing Q9FGI6 to train fasta file.
# writing Q9FGM0 to train fasta file.
# writing Q9FGS4 to train fasta file.
# writing Q9FGY9 to train fasta file.
# writing Q9FH02 to train fasta file.
# writing Q9FH04 to train fasta file.
# writing Q9FH09 to train fasta file.
# writing Q9FH13 to train fasta file.
# writing Q9FHA3 to train fasta file.
# writing Q9FHH8 to train fasta file.
# writing Q9FHN6 to train fasta file.
# writing Q9FHW2 to train fasta file.
# writing Q9FI27 to train fasta file.
# writing Q9FI43 to train fasta file.
# writing Q9FIC6 to train fasta file.
# writing Q9FIC8 to train fasta file.
# writing Q9FIC9 to train fasta file.
# writing Q9FID0 to train fasta file.
# writing Q9FIH8 to train fasta file.
# writing Q9FIJ0 to train fasta file.
# writing Q9FIK0 to train fasta file.
# writing Q9FIK7 to train fasta file.
# writing Q9FIM2 to train fasta file.
# writing Q9FIM9 to train fasta file.
# writing Q9FJD5 to train fasta file.
# writing Q9FJD6 to train fasta file.
# writing Q9FJH5 to train fasta file.
# writing Q9FJP9 to train fasta file.
# writing Q9FJR0 to train fasta file.
# writing Q9FJU4 to train fasta file.
# writing Q9FJZ9 to train fasta file.
# writing Q9FK51 to train fasta file.
# writing Q9FK60 to train fasta file.
# writing Q9FK81 to train fasta file.
# writing Q9FKA4 to train fasta file.
# writing Q9FKD5 to train fasta file.
# writing Q9FKD6 to train fasta file.
# writing Q9FKD7 to train fasta file.
# writing Q9FKD9 to train fasta file.
# writing Q9FKP5 to train fasta file.
# writing Q9FKW4 to train fasta file.
# writing Q9FKW9 to train fasta file.
# writing Q9FKX4 to train fasta file.
# writing Q9FL25 to train fasta file.
# writing Q9FL89 to train fasta file.
# writing Q9FLB5 to train fasta file.
# writing Q9FLC0 to train fasta file.
# writing Q9FLI3 to train fasta file.
# writing Q9FLL1 to train fasta file.
# writing Q9FLN8 to train fasta file.
# writing Q9FLN9 to train fasta file.
# writing Q9FLR0 to train fasta file.
# writing Q9FLS8 to train fasta file.
# writing Q9FLT3 to train fasta file.
# writing Q9FLU5 to train fasta file.
# writing Q9FLV0 to train fasta file.
# writing Q9FM03 to train fasta file.
# writing Q9FM14 to train fasta file.
# writing Q9FM66 to train fasta file.
# writing Q9FMA6 to train fasta file.
# writing Q9FMA8 to train fasta file.
# writing Q9FMA9 to train fasta file.
# writing Q9FMB0 to train fasta file.
# writing Q9FMK9 to train fasta file.
# writing Q9FML2 to train fasta file.
# writing Q9FMP3 to train fasta file.
# writing Q9FMP5 to train fasta file.
# writing Q9FMS6 to train fasta file.
# writing Q9FMT1 to train fasta file.
# writing Q9FMV1 to train fasta file.
# writing Q9FMX0 to train fasta file.
# writing Q9FN02 to train fasta file.
# writing Q9FN32 to train fasta file.
# writing Q9FN89 to train fasta file.
# writing Q9FNH4 to train fasta file.
# writing Q9FNN5 to train fasta file.
# writing Q9FPS9 to train fasta file.
# writing Q9FQ27 to train fasta file.
# writing Q9FRH4 to train fasta file.
# writing Q9FRX6 to train fasta file.
# writing Q9FT37 to train fasta file.
# writing Q9FT88 to train fasta file.
# writing Q9FUM7 to train fasta file.
# writing Q9FUM8 to train fasta file.
# writing Q9FUM9 to train fasta file.
# writing Q9FUN0 to train fasta file.
# writing Q9FUQ7 to train fasta file.
# writing Q9FUZ0 to train fasta file.
# writing Q9FV50 to train fasta file.
# writing Q9FV51 to train fasta file.
# writing Q9FV52 to train fasta file.
# writing Q9FV54 to train fasta file.
# writing Q9FVU9 to train fasta file.
# writing Q9FWQ5 to train fasta file.
# writing Q9FWR2 to train fasta file.
# writing Q9FWR5 to train fasta file.
# writing Q9FX08 to train fasta file.
# writing Q9FX21 to train fasta file.
# writing Q9FX83 to train fasta file.
# writing Q9FX85 to train fasta file.
# writing Q9FX86 to train fasta file.
# writing Q9FXB2 to train fasta file.
# writing Q9FXD8 to train fasta file.
# writing Q9FXH7 to train fasta file.
# writing Q9FXQ3 to train fasta file.
# writing Q9FXY7 to train fasta file.
# writing Q9FY79 to train fasta file.
# writing Q9FYE4 to train fasta file.
# writing Q9FYH1 to train fasta file.
# writing Q9FYN7 to train fasta file.
# writing Q9FYZ9 to train fasta file.
# writing Q9FZ21 to train fasta file.
# writing Q9FZ27 to train fasta file.
# writing Q9FZ37 to train fasta file.
# writing Q9FZ62 to train fasta file.
# writing Q9FZA4 to train fasta file.
# writing Q9FZN8 to train fasta file.
# writing Q9FZP6 to train fasta file.
# writing Q9G0U1 to train fasta file.
# writing Q9G185 to train fasta file.
# writing Q9G1N5 to train fasta file.
# writing Q9G2X2 to train fasta file.
# writing Q9G5S9 to train fasta file.
# writing Q9G6J1 to train fasta file.
# writing Q9GCE7 to train fasta file.
# writing Q9GGX6 to train fasta file.
# writing Q9GHP8 to train fasta file.
# writing Q9GKA1 to train fasta file.
# writing Q9GKE1 to train fasta file.
# writing Q9GKQ9 to train fasta file.
# writing Q9GKR6 to train fasta file.
# writing Q9GKS6 to train fasta file.
# writing Q9GL60 to train fasta file.
# writing Q9GLE4 to train fasta file.
# writing Q9GLE5 to train fasta file.
# writing Q9GLG1 to train fasta file.
# writing Q9GLG2 to train fasta file.
# writing Q9GLG7 to train fasta file.
# writing Q9GLK0 to train fasta file.
# writing Q9GLP0 to train fasta file.
# writing Q9GLP1 to train fasta file.
# writing Q9GLV6 to train fasta file.
# writing Q9GLX9 to train fasta file.
# writing Q9GMB2 to train fasta file.
# writing Q9GMB3 to train fasta file.
# writing Q9GMS6 to train fasta file.
# writing Q9GQV3 to train fasta file.
# writing Q9GR61 to train fasta file.
# writing Q9GRW0 to train fasta file.
# writing Q9GRZ3 to train fasta file.
# writing Q9GSR1 to train fasta file.
# writing Q9GT49 to train fasta file.
# writing Q9GUM2 to train fasta file.
# writing Q9GYD9 to train fasta file.
# writing Q9GYI0 to train fasta file.
# writing Q9GYI4 to train fasta file.
# writing Q9GYQ4 to train fasta file.
# writing Q9GYV5 to train fasta file.
# writing Q9GYZ9 to train fasta file.
# writing Q9GZH3 to train fasta file.
# writing Q9GZT9 to train fasta file.
# writing Q9GZU7 to train fasta file.
# writing Q9GZX7 to train fasta file.
# writing Q9GZZ9 to train fasta file.
# writing Q9H0C1 to train fasta file.
# writing Q9H0C8 to train fasta file.
# writing Q9H0E7 to train fasta file.
# writing Q9H0F7 to train fasta file.
# writing Q9H0I9 to train fasta file.
# writing Q9H0M4 to train fasta file.
# writing Q9H0P0 to train fasta file.
# writing Q9H0R4 to train fasta file.
# writing Q9H0V9 to train fasta file.
# writing Q9H160 to train fasta file.
# writing Q9H1D0 to train fasta file.
# writing Q9H1H1 to train fasta file.
# writing Q9H223 to train fasta file.
# writing Q9H239 to train fasta file.
# writing Q9H257 to train fasta file.
# writing Q9H2B2 to train fasta file.
# writing Q9H2H0 to train fasta file.
# ...
# writing Q9Z585 to train fasta file.
# writing Q9Z5B6 to train fasta file.
# writing Q9Z5D3 to train fasta file.
# writing Q9Z5D9 to train fasta file.
# writing Q9Z5H8 to train fasta file.
# writing Q9Z5X1 to train fasta file.
# writing Q9Z5X5 to train fasta file.
# writing Q9Z6C3 to train fasta file.
# writing Q9Z6J9 to train fasta file.
# writing Q9Z6L5 to train fasta file.
# writing Q9Z6L7 to train fasta file.
# writing Q9Z6M1 to train fasta file.
# writing Q9Z6P2 to train fasta file.
# writing Q9Z6Q0 to train fasta file.
# writing Q9Z6R0 to train fasta file.
# writing Q9Z6T6 to train fasta file.
# writing Q9Z6U1 to train fasta file.
# writing Q9Z6W4 to train fasta file.
# writing Q9Z6X5 to train fasta file.
# writing Q9Z701 to train fasta file.
# writing Q9Z714 to train fasta file.
# writing Q9Z721 to train fasta file.
# writing Q9Z723 to train fasta file.
# writing Q9Z734 to train fasta file.
# writing Q9Z735 to train fasta file.
# writing Q9Z755 to train fasta file.
# writing Q9Z760 to train fasta file.
# writing Q9Z768 to train fasta file.
# writing Q9Z774 to train fasta file.
# writing Q9Z7A6 to train fasta file.
# writing Q9Z7E8 to train fasta file.
# writing Q9Z7G1 to train fasta file.
# writing Q9Z7G7 to train fasta file.
# writing Q9Z7H3 to train fasta file.
# writing Q9Z7Q2 to train fasta file.
# writing Q9Z7V1 to train fasta file.
# writing Q9Z7W0 to train fasta file.
# writing Q9Z7Y7 to train fasta file.
# writing Q9Z805 to train fasta file.
# writing Q9Z808 to train fasta file.
# writing Q9Z843 to train fasta file.
# writing Q9Z874 to train fasta file.
# writing Q9Z8F8 to train fasta file.
# writing Q9Z8H0 to train fasta file.
# writing Q9Z8J8 to train fasta file.
# writing Q9Z8K2 to train fasta file.
# writing Q9Z8R3 to train fasta file.
# writing Q9Z8S6 to train fasta file.
# writing Q9Z8T3 to train fasta file.
# writing Q9Z8U0 to train fasta file.
# writing Q9Z8U8 to train fasta file.
# writing Q9Z8W5 to train fasta file.
# writing Q9Z8Z0 to train fasta file.
# writing Q9Z8Z9 to train fasta file.
# writing Q9Z934 to train fasta file.
# writing Q9Z959 to train fasta file.
# writing Q9Z962 to train fasta file.
# writing Q9Z999 to train fasta file.
# writing Q9Z9C4 to train fasta file.
# writing Q9Z9C7 to train fasta file.
# writing Q9Z9E9 to train fasta file.
# writing Q9Z9F6 to train fasta file.
# writing Q9Z9J4 to train fasta file.
# writing Q9Z9M1 to train fasta file.
# writing Q9Z9S0 to train fasta file.
# writing Q9Z9U1 to train fasta file.
# writing Q9ZAD8 to train fasta file.
# writing Q9ZAE1 to train fasta file.
# writing Q9ZAE7 to train fasta file.
# writing Q9ZAE9 to train fasta file.
# writing Q9ZAH6 to train fasta file.
# writing Q9ZAQ6 to train fasta file.
# writing Q9ZB10 to train fasta file.
# writing Q9ZB35 to train fasta file.
# writing Q9ZB63 to train fasta file.
# writing Q9ZB79 to train fasta file.
# writing Q9ZBL0 to train fasta file.
# writing Q9ZBL5 to train fasta file.
# writing Q9ZBQ7 to train fasta file.
# writing Q9ZBR9 to train fasta file.
# writing Q9ZC70 to train fasta file.
# writing Q9ZC74 to train fasta file.
# writing Q9ZC84 to train fasta file.
# writing Q9ZC86 to train fasta file.
# writing Q9ZC93 to train fasta file.
# writing Q9ZCA4 to train fasta file.
# writing Q9ZCB6 to train fasta file.
# writing Q9ZCC6 to train fasta file.
# writing Q9ZCD3 to train fasta file.
# writing Q9ZCE8 to train fasta file.
# writing Q9ZCF4 to train fasta file.
# writing Q9ZCF6 to train fasta file.
# writing Q9ZCF8 to train fasta file.
# writing Q9ZCI1 to train fasta file.
# writing Q9ZCK3 to train fasta file.
# writing Q9ZCK8 to train fasta file.
# writing Q9ZCK9 to train fasta file.
# writing Q9ZCM9 to train fasta file.
# writing Q9ZCN1 to train fasta file.
# writing Q9ZCV2 to train fasta file.
# writing Q9ZCW5 to train fasta file.
# writing Q9ZCX2 to train fasta file.
# writing Q9ZD43 to train fasta file.
# writing Q9ZD53 to train fasta file.
# writing Q9ZD54 to train fasta file.
# writing Q9ZD55 to train fasta file.
# writing Q9ZD60 to train fasta file.
# writing Q9ZD90 to train fasta file.
# writing Q9ZDA7 to train fasta file.
# writing Q9ZDC6 to train fasta file.
# writing Q9ZDE8 to train fasta file.
# writing Q9ZDF1 to train fasta file.
# writing Q9ZDF6 to train fasta file.
# writing Q9ZDH2 to train fasta file.
# writing Q9ZDH5 to train fasta file.
# writing Q9ZDK2 to train fasta file.
# writing Q9ZDK9 to train fasta file.
# writing Q9ZDQ5 to train fasta file.
# writing Q9ZDR0 to train fasta file.
# writing Q9ZDS1 to train fasta file.
# writing Q9ZDU7 to train fasta file.
# writing Q9ZDV8 to train fasta file.
# writing Q9ZDW3 to train fasta file.
# writing Q9ZDW6 to train fasta file.
# writing Q9ZDY0 to train fasta file.
# writing Q9ZDY5 to train fasta file.
# writing Q9ZE02 to train fasta file.
# writing Q9ZE20 to train fasta file.
# writing Q9ZE29 to train fasta file.
# writing Q9ZE31 to train fasta file.
# writing Q9ZE33 to train fasta file.
# writing Q9ZE38 to train fasta file.
# writing Q9ZE62 to train fasta file.
# writing Q9ZEA1 to train fasta file.
# writing Q9ZEA2 to train fasta file.
# writing Q9ZEA8 to train fasta file.
# writing Q9ZED0 to train fasta file.
# writing Q9ZEJ7 to train fasta file.
# writing Q9ZEL6 to train fasta file.
# writing Q9ZEM7 to train fasta file.
# writing Q9ZEN7 to train fasta file.
# writing Q9ZER9 to train fasta file.
# writing Q9ZES2 to train fasta file.
# writing Q9ZET5 to train fasta file.
# writing Q9ZF44 to train fasta file.
# writing Q9ZFA8 to train fasta file.
# writing Q9ZFB7 to train fasta file.
# writing Q9ZFC5 to train fasta file.
# writing Q9ZFK1 to train fasta file.
# writing Q9ZFR9 to train fasta file.
# writing Q9ZFV8 to train fasta file.
# writing Q9ZFY8 to train fasta file.
# writing Q9ZG11 to train fasta file.
# writing Q9ZG89 to train fasta file.
# writing Q9ZGE8 to train fasta file.
# writing Q9ZGE9 to train fasta file.
# writing Q9ZGF0 to train fasta file.
# writing Q9ZGN0 to train fasta file.
# writing Q9ZH99 to train fasta file.
# writing Q9ZHA4 to train fasta file.
# writing Q9ZHD7 to train fasta file.
# writing Q9ZHE4 to train fasta file.
# writing Q9ZHE6 to train fasta file.
# writing Q9ZHI0 to train fasta file.
# writing Q9ZHI4 to train fasta file.
# writing Q9ZHR1 to train fasta file.
# writing Q9ZHZ1 to train fasta file.
# writing Q9ZHZ4 to train fasta file.
# writing Q9ZI34 to train fasta file.
# writing Q9ZIE4 to train fasta file.
# writing Q9ZIG2 to train fasta file.
# writing Q9ZIM6 to train fasta file.
# writing Q9ZIM7 to train fasta file.
# writing Q9ZJ27 to train fasta file.
# writing Q9ZJ28 to train fasta file.
# writing Q9ZJ42 to train fasta file.
# writing Q9ZJ74 to train fasta file.
# writing Q9ZJ75 to train fasta file.
# writing Q9ZJG6 to train fasta file.
# writing Q9ZJI4 to train fasta file.
# writing Q9ZJI6 to train fasta file.
# writing Q9ZJJ1 to train fasta file.
# writing Q9ZJK8 to train fasta file.
# writing Q9ZJL8 to train fasta file.
# writing Q9ZJM4 to train fasta file.
# writing Q9ZJN1 to train fasta file.
# writing Q9ZJP7 to train fasta file.
# writing Q9ZJQ2 to train fasta file.
# writing Q9ZJT0 to train fasta file.
# writing Q9ZJU5 to train fasta file.
# writing Q9ZJU7 to train fasta file.
# writing Q9ZJV9 to train fasta file.
# writing Q9ZJW6 to train fasta file.
# writing Q9ZJY5 to train fasta file.
# writing Q9ZK05 to train fasta file.
# writing Q9ZK11 to train fasta file.
# writing Q9ZK23 to train fasta file.
# writing Q9ZK37 to train fasta file.
# writing Q9ZK54 to train fasta file.
# writing Q9ZKB3 to train fasta file.
# writing Q9ZKD4 to train fasta file.
# writing Q9ZKE6 to train fasta file.
# writing Q9ZKF8 to train fasta file.
# writing Q9ZKG9 to train fasta file.
# writing Q9ZKM7 to train fasta file.
# writing Q9ZKR8 to train fasta file.
# writing Q9ZKS0 to train fasta file.
# writing Q9ZKS2 to train fasta file.
# writing Q9ZKS4 to train fasta file.
# writing Q9ZKT2 to train fasta file.
# writing Q9ZKU5 to train fasta file.
# writing Q9ZKU8 to train fasta file.
# writing Q9ZKW6 to train fasta file.
# writing Q9ZKY6 to train fasta file.
# writing Q9ZKY8 to train fasta file.
# writing Q9ZKZ1 to train fasta file.
# writing Q9ZL14 to train fasta file.
# writing Q9ZL36 to train fasta file.
# writing Q9ZL40 to train fasta file.
# writing Q9ZL42 to train fasta file.
# writing Q9ZL51 to train fasta file.
# writing Q9ZL53 to train fasta file.
# writing Q9ZL64 to train fasta file.
# writing Q9ZL74 to train fasta file.
# writing Q9ZL75 to train fasta file.
# writing Q9ZLA1 to train fasta file.
# writing Q9ZLA5 to train fasta file.
# writing Q9ZLA9 to train fasta file.
# writing Q9ZLE0 to train fasta file.
# writing Q9ZLF6 to train fasta file.
# writing Q9ZLH0 to train fasta file.
# writing Q9ZLH2 to train fasta file.
# writing Q9ZLH3 to train fasta file.
# writing Q9ZLI1 to train fasta file.
# writing Q9ZLJ7 to train fasta file.
# writing Q9ZLL0 to train fasta file.
# writing Q9ZLL5 to train fasta file.
# writing Q9ZLM1 to train fasta file.
# writing Q9ZLQ0 to train fasta file.
# writing Q9ZLR1 to train fasta file.
# writing Q9ZLW2 to train fasta file.
# writing Q9ZLW5 to train fasta file.
# writing Q9ZLX3 to train fasta file.
# writing Q9ZM10 to train fasta file.
# writing Q9ZM19 to train fasta file.
# writing Q9ZM26 to train fasta file.
# writing Q9ZM50 to train fasta file.
# writing Q9ZM64 to train fasta file.
# writing Q9ZM66 to train fasta file.
# writing Q9ZM69 to train fasta file.
# writing Q9ZM70 to train fasta file.
# writing Q9ZM94 to train fasta file.
# writing Q9ZM99 to train fasta file.
# writing Q9ZMA9 to train fasta file.
# writing Q9ZMB0 to train fasta file.
# writing Q9ZMD3 to train fasta file.
# writing Q9ZMF0 to train fasta file.
# writing Q9ZMF4 to train fasta file.
# writing Q9ZMH8 to train fasta file.
# writing Q9ZMI1 to train fasta file.
# writing Q9ZMJ1 to train fasta file.
# writing Q9ZML2 to train fasta file.
# writing Q9ZMM0 to train fasta file.
# writing Q9ZMP8 to train fasta file.
# writing Q9ZMR8 to train fasta file.
# writing Q9ZMS6 to train fasta file.
# writing Q9ZMV4 to train fasta file.
# writing Q9ZMV6 to train fasta file.
# writing Q9ZMV7 to train fasta file.
# writing Q9ZMZ2 to train fasta file.
# writing Q9ZN34 to train fasta file.
# writing Q9ZN36 to train fasta file.
# writing Q9ZN49 to train fasta file.
# writing Q9ZN54 to train fasta file.
# writing Q9ZNH4 to train fasta file.
# writing Q9ZNU9 to train fasta file.
# writing Q9ZNW0 to train fasta file.
# writing Q9ZNZ7 to train fasta file.
# writing Q9ZP19 to train fasta file.
# writing Q9ZPF5 to train fasta file.
# writing Q9ZPH2 to train fasta file.
# writing Q9ZPI1 to train fasta file.
# writing Q9ZPX9 to train fasta file.
# writing Q9ZPY0 to train fasta file.
# writing Q9ZPY2 to train fasta file.
# writing Q9ZQ81 to train fasta file.
# writing Q9ZQH1 to train fasta file.
# writing Q9ZR03 to train fasta file.
# writing Q9ZRA2 to train fasta file.
# writing Q9ZRA4 to train fasta file.
# writing Q9ZRF1 to train fasta file.
# writing Q9ZS21 to train fasta file.
# writing Q9ZS91 to train fasta file.
# writing Q9ZSA2 to train fasta file.
# writing Q9ZSA3 to train fasta file.
# writing Q9ZSA4 to train fasta file.
# writing Q9ZSA7 to train fasta file.
# writing Q9ZSA8 to train fasta file.
# writing Q9ZSQ4 to train fasta file.
# writing Q9ZT46 to train fasta file.
# writing Q9ZT47 to train fasta file.
# writing Q9ZT92 to train fasta file.
# writing Q9ZT94 to train fasta file.
# writing Q9ZTA1 to train fasta file.
# writing Q9ZTA2 to train fasta file.
# writing Q9ZTA3 to train fasta file.
# writing Q9ZTP5 to train fasta file.
# writing Q9ZTT5 to train fasta file.
# writing Q9ZU77 to train fasta file.
# writing Q9ZU95 to train fasta file.
# writing Q9ZUA5 to train fasta file.
# writing Q9ZUH4 to train fasta file.
# writing Q9ZUL3 to train fasta file.
# writing Q9ZUU0 to train fasta file.
# writing Q9ZUV1 to train fasta file.
# writing Q9ZUZ2 to train fasta file.
# writing Q9ZV04 to train fasta file.
# writing Q9ZV15 to train fasta file.
# writing Q9ZV25 to train fasta file.
# writing Q9ZV33 to train fasta file.
# writing Q9ZVF6 to train fasta file.
# writing Q9ZVH8 to train fasta file.
# writing Q9ZVJ5 to train fasta file.
# writing Q9ZVJ6 to train fasta file.
# writing Q9ZVT9 to train fasta file.
# writing Q9ZW34 to train fasta file.
# writing Q9ZW86 to train fasta file.
# writing Q9ZWA6 to train fasta file.
# writing Q9ZWL6 to train fasta file.
# writing Q9ZWM5 to train fasta file.
# writing Q9ZWQ9 to train fasta file.
# writing Q9ZWT1 to train fasta file.
# writing Q9ZXY2 to train fasta file.
# writing Q9ZZ08 to train fasta file.
# writing Q9ZZ51 to train fasta file.
# writing Q9ZZ52 to train fasta file.
# writing Q9ZZ64 to train fasta file.
# writing Q9ZZM6 to train fasta file.
# writing Q9ZZY8 to train fasta file.
# writing Q9ZZY9 to train fasta file.
# writing R4JGL8 to train fasta file.
# writing R4JJJ1 to train fasta file.
# writing R4JND9 to train fasta file.
# writing R4JQS2 to train fasta file.
# writing R4JQT5 to train fasta file.
# writing R4YVJ8 to train fasta file.
# writing R4YXW8 to train fasta file.
# writing R4YZC3 to train fasta file.
# writing R4ZGN4 to train fasta file.
# writing R9QMQ9 to train fasta file.
# writing R9QMR0 to train fasta file.
# writing R9QMR1 to train fasta file.
# writing R9QMR2 to train fasta file.
# writing R9QMR3 to train fasta file.
# writing R9QMR4 to train fasta file.
# writing R9QMR5 to train fasta file.
# writing R9QMR6 to train fasta file.
# writing R9QMW1 to train fasta file.
# writing R9QMW2 to train fasta file.
# writing R9QMW3 to train fasta file.
# writing R9QMW4 to train fasta file.
# writing R9QMW5 to train fasta file.
# writing R9QMW6 to train fasta file.
# writing R9QMW7 to train fasta file.
# writing R9QMW8 to train fasta file.
# writing R9QMY7 to train fasta file.
# writing R9QMY8 to train fasta file.
# writing R9QMY9 to train fasta file.
# writing R9QMZ0 to train fasta file.
# writing R9UTQ8 to train fasta file.
# writing S0DX56 to train fasta file.
# writing S0ECT9 to train fasta file.
# writing S0EGZ9 to train fasta file.
# writing S0EHD6 to train fasta file.
# writing S0ENM8 to train fasta file.
# writing S0HPF7 to train fasta file.
# writing S3DB74 to train fasta file.
# writing S3E7P8 to train fasta file.
# writing S3E7Q2 to train fasta file.
# writing S4R2K0 to train fasta file.
# writing S4R2P9 to train fasta file.
# writing S5FT07 to train fasta file.
# writing S5FU55 to train fasta file.
# writing S5N020 to train fasta file.
# writing S7VVK4 to train fasta file.
# writing S8FGV1 to train fasta file.
# writing S8FIE4 to train fasta file.
# writing T1RR71 to train fasta file.
# writing T1RR72 to train fasta file.
# writing T1RRI5 to train fasta file.
# writing T1RRI8 to train fasta file.
# writing T1RRJ4 to train fasta file.
# writing T1RRJ6 to train fasta file.
# writing T1RRL8 to train fasta file.
# writing T1RRR9 to train fasta file.
# writing T1RRS0 to train fasta file.
# writing T2G899 to train fasta file.
# writing T2KM04 to train fasta file.
# writing T2KM26 to train fasta file.
# writing T2KMG7 to train fasta file.
# writing T2KN71 to train fasta file.
# writing T2KN75 to train fasta file.
# writing T2KN90 to train fasta file.
# writing T2KN98 to train fasta file.
# writing T2KNC2 to train fasta file.
# writing T2KPJ9 to train fasta file.
# writing T2KPK5 to train fasta file.
# writing U3EPL2 to train fasta file.
# writing U3FAE1 to train fasta file.
# writing U3KPV4 to train fasta file.
# writing U3KYL2 to train fasta file.
# writing U3LVL5 to train fasta file.
# writing U3LVZ7 to train fasta file.
# writing U3N9N6 to train fasta file.
# writing U5PZT6 to train fasta file.
# writing U6BLN5 to train fasta file.
# writing V5TD18 to train fasta file.
# writing V6F235 to train fasta file.
# writing V9VGU0 to train fasta file.
# writing V9Z548 to train fasta file.
# writing V9Z7R6 to train fasta file.
# writing V9Z9A3 to train fasta file.
# writing V9ZAX6 to train fasta file.
# writing V9ZAY0 to train fasta file.
# writing W0FFD7 to train fasta file.
# writing W3X732 to train fasta file.
# writing W4JX79 to train fasta file.
# writing W5QJZ5 to train fasta file.
# writing W6HUT3 to train fasta file.
# writing W6KHH6 to train fasta file.
# writing W6Q4Q9 to train fasta file.
# writing W6QAE7 to train fasta file.
# writing W6QIT2 to train fasta file.
# writing W6RJ11 to train fasta file.
# writing W7JLR6 to train fasta file.
# writing W7K9M0 to train fasta file.
# writing W7LKX6 to train fasta file.
# writing W7MSJ7 to train fasta file.
# writing W7N6M8 to train fasta file.
# writing W8E7D1 to train fasta file.
# writing W8JCF0 to train fasta file.
# writing W8JDE0 to train fasta file.
# writing W8JWW7 to train fasta file.
# writing X1WER2 to train fasta file.

# %%
# !tar cvf full_data_split *1.fasta
# Out:
# TEST_POS_NEG1.fasta
# TRAIN_POS_NEG1.fasta

# %% [markdown]
# # Filter negative data

# %%
print('number of clusters:', len(list(SeqIO.parse("assembly_clustered_rep_seq.fasta", "fasta"))))
# Out:
# number of clusters: 33071

# %%
acc_train, _ = fasta2acc_seq_ls("POS_TRAIN.fasta")

# %%
neg_filtered = []

# %%
for i in reps:
  for j in clusters[clusters['Rep'] == i]['Accession']:
    neg_filtered.append(j)
for i in non_metal_reps:
  neg_filtered.append(i)

# %%
len(neg_filtered)
# Out:
# 40368

# %%
with open('/content/filtered_seqs.txt', 'w') as f:
  for i in neg_filtered:
    f.write(i + '\n')

# %%
trainval = []
with open('/content/trainval.txt', 'r') as f:
  for i in f.readlines():
    trainval.append(i[:-1])

# %%
trainval_filtered = set(neg_filtered).intersection(trainval)

# %%
len(trainval)
# Out:
# 177794

# %%
len(trainval_filtered)
# Out:
# 36457

# %%
test = []
with open('/content/test.txt', 'r') as f:
  for i in f.readlines():
    test.append(i[:-1])

# %%
test_filtered = set(neg_filtered).intersection(test)

# %%
len(test)
# Out:
# 17656

# %%
len(test_filtered)
# Out:
# 3911

# %%
with open('/content/trainval_filtered40.txt', 'w') as f:
  for i in trainval_filtered:
    f.write(i + '\n')

# %%
with open('/content/test_filtered40.txt', 'w') as f:
  for i in test_filtered:
    f.write(i + '\n')
