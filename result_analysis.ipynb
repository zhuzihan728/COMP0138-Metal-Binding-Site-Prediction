# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# compare tf and cnn

# %%
'''
tf -ankh
Zn(2+)                   |precision:  0.427|recall:  0.653|specificity:  1.000|MCC:  0.528|AUROC: 0.971|AUPR: 0.529
Mg(2+)                   |precision:  0.330|recall:  0.575|specificity:  1.000|MCC:  0.435|AUROC: 0.945|AUPR: 0.451
[4Fe-4S] cluster         |precision:  0.405|recall:  0.909|specificity:  1.000|MCC:  0.607|AUROC: 1.000|AUPR: 0.652
Ca(2+)                   |precision:  0.320|recall:  0.523|specificity:  1.000|MCC:  0.409|AUROC: 0.969|AUPR: 0.340
Mn(2+)                   |precision:  0.127|recall:  0.394|specificity:  1.000|MCC:  0.224|AUROC: 0.971|AUPR: 0.080
a divalent metal cation  |precision:  0.393|recall:  0.638|specificity:  1.000|MCC:  0.501|AUROC: 0.960|AUPR: 0.506
Fe cation                |precision:  0.355|recall:  0.386|specificity:  1.000|MCC:  0.370|AUROC: 0.956|AUPR: 0.226
[2Fe-2S] cluster         |precision:  0.848|recall:  0.966|specificity:  1.000|MCC:  0.905|AUROC: 1.000|AUPR: 0.966
Cu cation                |precision:  0.723|recall:  0.870|specificity:  1.000|MCC:  0.793|AUROC: 0.959|AUPR: 0.846
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.445|AUPR: 0.000
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.999|AUPR: 0.002
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.831|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.753|AUPR: 0.001
iron-sulfur cluster      |precision:  0.527|recall:  0.925|specificity:  1.000|MCC:  0.698|AUROC: 1.000|AUPR: 0.831
Cu(2+)                   |precision:  0.167|recall:  0.250|specificity:  1.000|MCC:  0.204|AUROC: 1.000|AUPR: 0.235
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.999|AUPR: 0.001
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.886|AUPR: 0.003
a metal cation           |precision:  0.419|recall:  0.647|specificity:  1.000|MCC:  0.520|AUROC: 0.935|AUPR: 0.520
mean                     |pre(0-1):  0.280|rec(0-1):  0.430|spe(0-1):  1.000|MCC(-1-1):  0.344|AUROC(0-1): 0.921|AUPR(0-1): 0.344

CNN 
Zn(2+)                   |precision:  0.339|recall:  0.540|specificity:  1.000|MCC:  0.428|AUROC: 0.985|AUPR: 0.288
Mg(2+)                   |precision:  0.347|recall:  0.412|specificity:  1.000|MCC:  0.378|AUROC: 0.960|AUPR: 0.301
[4Fe-4S] cluster         |precision:  0.223|recall:  0.667|specificity:  1.000|MCC:  0.386|AUROC: 1.000|AUPR: 0.155
Ca(2+)                   |precision:  0.223|recall:  0.394|specificity:  1.000|MCC:  0.296|AUROC: 0.979|AUPR: 0.135
Mn(2+)                   |precision:  0.050|recall:  0.099|specificity:  1.000|MCC:  0.070|AUROC: 0.956|AUPR: 0.022
a divalent metal cation  |precision:  0.376|recall:  0.509|specificity:  1.000|MCC:  0.437|AUROC: 0.977|AUPR: 0.316
Fe cation                |precision:  0.486|recall:  0.316|specificity:  1.000|MCC:  0.392|AUROC: 0.978|AUPR: 0.202
[2Fe-2S] cluster         |precision:  0.750|recall:  0.828|specificity:  1.000|MCC:  0.788|AUROC: 1.000|AUPR: 0.877
Cu cation                |precision:  0.240|recall:  0.759|specificity:  1.000|MCC:  0.427|AUROC: 0.997|AUPR: 0.145
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.958|AUPR: 0.001
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.968|AUPR: 0.000
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.928|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.847|AUPR: 0.000
iron-sulfur cluster      |precision:  0.385|recall:  0.766|specificity:  1.000|MCC:  0.543|AUROC: 1.000|AUPR: 0.402
Cu(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 1.000|AUPR: 0.007
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.866|AUPR: 0.000
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.801|AUPR: 0.000
a metal cation           |precision:  0.378|recall:  0.529|specificity:  1.000|MCC:  0.447|AUROC: 0.975|AUPR: 0.343
mean                     |pre(0-1):  0.211|rec(0-1):  0.323|spe(0-1):  1.000|MCC(-1-1):  0.255|AUROC(0-1): 0.954|AUPR(0-1): 0.178
'''
# Out:
# '\ntf -ankh\nZn(2+)                   |precision:  0.427|recall:  0.653|specificity:  1.000|MCC:  0.528|AUROC: 0.971|AUPR: 0.529\nMg(2+)                   |precision:  0.330|recall:  0.575|specificity:  1.000|MCC:  0.435|AUROC: 0.945|AUPR: 0.451\n[4Fe-4S] cluster         |precision:  0.405|recall:  0.909|specificity:  1.000|MCC:  0.607|AUROC: 1.000|AUPR: 0.652\nCa(2+)                   |precision:  0.320|recall:  0.523|specificity:  1.000|MCC:  0.409|AUROC: 0.969|AUPR: 0.340\nMn(2+)                   |precision:  0.127|recall:  0.394|specificity:  1.000|MCC:  0.224|AUROC: 0.971|AUPR: 0.080\na divalent metal cation  |precision:  0.393|recall:  0.638|specificity:  1.000|MCC:  0.501|AUROC: 0.960|AUPR: 0.506\nFe cation                |precision:  0.355|recall:  0.386|specificity:  1.000|MCC:  0.370|AUROC: 0.956|AUPR: 0.226\n[2Fe-2S] cluster         |precision:  0.848|recall:  0.966|specificity:  1.000|MCC:  0.905|AUROC: 1.000|AUPR: 0.966\nCu cation                |precision:  0.723|recal
# ...

# %%
df_cnn = pd.read_csv(r'lightning_logs\cnn1\metrics.csv')
model = ['CNN' for i in range(len(df_cnn['train_loss']))]
df_cnn['model'] = model

df_cnn
# Out:
#      train_loss  epoch   step  val_loss       MCC      AUPR  test_loss model
# 0      0.285795      0     49       NaN       NaN       NaN        NaN   CNN
# 1      0.089914      0     99       NaN       NaN       NaN        NaN   CNN
# 2      0.068184      0    149       NaN       NaN       NaN        NaN   CNN
# 3      0.075635      0    199       NaN       NaN       NaN        NaN   CNN
# 4      0.183269      0    249       NaN       NaN       NaN        NaN   CNN
# ..          ...    ...    ...       ...       ...       ...        ...   ...
# 684    0.005926    109  33749       NaN       NaN       NaN        NaN   CNN
# 685    0.001477    109  33799       NaN       NaN       NaN        NaN   CNN
# 686    0.000267    109  33849       NaN       NaN       NaN        NaN   CNN
# 687         NaN    109  33883  0.050887  0.400715  0.377861        NaN   CNN
# 688         NaN    110  33884       NaN       NaN       NaN    0.07637   CNN
#
# [689 rows x 8 columns]

# %%
df_tf = pd.read_csv(r'lightning_logs\transformer1\metrics.csv')
model = ['Transformer' for i in range(len(df_tf['train_loss']))]
df_tf['model'] = model

df_tf
# Out:
#      train_loss  epoch   step  val_loss       MCC      AUPR  test_loss  \
# 0      0.281310      0     49       NaN       NaN       NaN        NaN
# 1      0.250046      0     99       NaN       NaN       NaN        NaN
# 2      0.152091      0    149       NaN       NaN       NaN        NaN
# 3      0.197413      0    199       NaN       NaN       NaN        NaN
# 4      0.250717      0    249       NaN       NaN       NaN        NaN
# ..          ...    ...    ...       ...       ...       ...        ...
# 622    0.012464     99  30699       NaN       NaN       NaN        NaN
# 623    0.015318     99  30749       NaN       NaN       NaN        NaN
# 624    0.014747     99  30799       NaN       NaN       NaN        NaN
# 625         NaN     99  30803  0.041829  0.425199  0.420913        NaN
# 626         NaN    100  30804       NaN       NaN       NaN   0.055705
#
#            model
# 0    Transformer
# 1    Transformer
# 2    Transformer
# 3    Transformer
# 4    Transformer
# ...

# %%
plt.figure(figsize=(6,6))

sns.lineplot(data=df_tf, x='epoch', y='train_loss')
sns.lineplot(data=df_tf, x='epoch', y='val_loss', palette="flare")
plt.legend(['training loss', 'aggregated batch loss', 'validation loss'])
plt.ylabel('loss')
# Out:
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\4097437037.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df_tf, x='epoch', y='val_loss', palette="flare")
# Text(0, 0.5, 'loss')

# %%
plt.figure(figsize=(6,6))
sns.lineplot(data=df_cnn, x='epoch', y='train_loss')
sns.lineplot(data=df_cnn, x='epoch', y='val_loss', palette="flare")
plt.legend(['training loss', 'aggregated batch loss', 'validation loss'])
plt.ylabel('loss')
# Out:
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\231441778.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df_cnn, x='epoch', y='val_loss', palette="flare")
# Text(0, 0.5, 'loss')

# %%
sns.lineplot(data=df_cnn, x='epoch', y='AUPR', hue='model')
sns.lineplot(data=df_tf, x='epoch', y='AUPR', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='AUPR'>

# %%
sns.lineplot(data=df_cnn, x='epoch', y='MCC', hue='model')
sns.lineplot(data=df_tf, x='epoch', y='MCC', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='MCC'>

# %% [markdown]
# Longer epoch

# %%
'''tf
也是烂的
Zn(2+)                   |precision:  0.451 (0.19) |recall:  0.588|specificity:  1.000|MCC:  0.515|AUROC: 0.969|AUPR: 0.511
Mg(2+)                   |precision:  0.447|recall:  0.450|specificity:  1.000|MCC:  0.449|AUROC: 0.923|AUPR: 0.399
[4Fe-4S] cluster         |precision:  0.505|recall:  0.818|specificity:  1.000|MCC:  0.643|AUROC: 1.000|AUPR: 0.570
Ca(2+)                   |precision:  0.417|recall:  0.352|specificity:  1.000|MCC:  0.383|AUROC: 0.946|AUPR: 0.272
Mn(2+)                   |precision:  0.063|recall:  0.113|specificity:  1.000|MCC:  0.085|AUROC: 0.959|AUPR: 0.039
a divalent metal cation  |precision:  0.472|recall:  0.531|specificity:  1.000|MCC:  0.501|AUROC: 0.959|AUPR: 0.495
Fe cation                |precision:  0.200|recall:  0.281|specificity:  1.000|MCC:  0.237|AUROC: 0.947|AUPR: 0.124
[2Fe-2S] cluster         |precision:  0.651|recall:  0.966|specificity:  1.000|MCC:  0.793|AUROC: 1.000|AUPR: 0.966
Cu cation                |precision:  0.818|recall:  0.833|specificity:  1.000|MCC:  0.826|AUROC: 0.996|AUPR: 0.843
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.578|AUPR: 0.000
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 1.000|AUPR: 0.003
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.840|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.782|AUPR: 0.000
iron-sulfur cluster      |precision:  0.587|recall:  0.916|specificity:  1.000|MCC:  0.733|AUROC: 1.000|AUPR: 0.695
Cu(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 1.000|AUPR: 0.505
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.999|AUPR: 0.001
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.881|AUPR: 0.001
a metal cation           |precision:  0.493|recall:  0.545|specificity:  1.000|MCC:  0.518|AUROC: 0.938|AUPR: 0.506
mean                     |pre(0-1):  0.284|rec(0-1):  0.355|spe(0-1):  1.000|MCC(-1-1):  0.316|AUROC(0-1): 0.929|AUPR(0-1): 0.329



CNN
烂的




'''
# Out:
# 'tf\n也是烂的\nZn(2+)                   |precision:  0.451 (0.19) |recall:  0.588|specificity:  1.000|MCC:  0.515|AUROC: 0.969|AUPR: 0.511\nMg(2+)                   |precision:  0.447|recall:  0.450|specificity:  1.000|MCC:  0.449|AUROC: 0.923|AUPR: 0.399\n[4Fe-4S] cluster         |precision:  0.505|recall:  0.818|specificity:  1.000|MCC:  0.643|AUROC: 1.000|AUPR: 0.570\nCa(2+)                   |precision:  0.417|recall:  0.352|specificity:  1.000|MCC:  0.383|AUROC: 0.946|AUPR: 0.272\nMn(2+)                   |precision:  0.063|recall:  0.113|specificity:  1.000|MCC:  0.085|AUROC: 0.959|AUPR: 0.039\na divalent metal cation  |precision:  0.472|recall:  0.531|specificity:  1.000|MCC:  0.501|AUROC: 0.959|AUPR: 0.495\nFe cation                |precision:  0.200|recall:  0.281|specificity:  1.000|MCC:  0.237|AUROC: 0.947|AUPR: 0.124\n[2Fe-2S] cluster         |precision:  0.651|recall:  0.966|specificity:  1.000|MCC:  0.793|AUROC: 1.000|AUPR: 0.966\nCu cation                |precision:  0.818
# ...

# %%
df_tf = pd.read_csv(r'lightning_logs\transformer1\metrics.csv')
model = ['Transformer short epoch train loss' for i in range(len(df_tf['train_loss']))]
df_tf['model_tr'] = model
model = ['Transformer short epoch val loss' for i in range(len(df_tf['train_loss']))]
df_tf['model_val'] = model

df_tf
# Out:
#      train_loss  epoch   step  val_loss       MCC      AUPR  test_loss  \
# 0      0.281310      0     49       NaN       NaN       NaN        NaN
# 1      0.250046      0     99       NaN       NaN       NaN        NaN
# 2      0.152091      0    149       NaN       NaN       NaN        NaN
# 3      0.197413      0    199       NaN       NaN       NaN        NaN
# 4      0.250717      0    249       NaN       NaN       NaN        NaN
# ..          ...    ...    ...       ...       ...       ...        ...
# 622    0.012464     99  30699       NaN       NaN       NaN        NaN
# 623    0.015318     99  30749       NaN       NaN       NaN        NaN
# 624    0.014747     99  30799       NaN       NaN       NaN        NaN
# 625         NaN     99  30803  0.041829  0.425199  0.420913        NaN
# 626         NaN    100  30804       NaN       NaN       NaN   0.055705
#
#                                model_tr                         model_val
# ...

# %%
df_tflong = pd.read_csv(r'lightning_logs\tf_long_epoch\metrics.csv')
model = ['Transformer long epoch train loss' for i in range(len(df_tflong['train_loss']))]
df_tflong['model_tr'] = model
model = ['Transformer long epoch val loss' for i in range(len(df_tflong['train_loss']))]
df_tflong['model_val'] = model
df_tflong
# Out:
#        train_loss  epoch   step  val_loss  MCC  AUPR  \
# 0        0.380631      0     49       NaN  NaN   NaN
# 1        0.454569      0     99       NaN  NaN   NaN
# 2        0.219223      0    149       NaN  NaN   NaN
# 3        0.179276      0    199       NaN  NaN   NaN
# 4        0.180519      0    249       NaN  NaN   NaN
# ...           ...    ...    ...       ...  ...   ...
# 31958    0.004112    211  65144       NaN  NaN   NaN
# 31959    0.000788    211  65145       NaN  NaN   NaN
# 31960    0.000679    211  65146       NaN  NaN   NaN
# 31961    0.001416    211  65147       NaN  NaN   NaN
# 31962    0.000324    211  65148       NaN  NaN   NaN
#
#                                 model_tr                        model_val
# 0      Transformer long epoch train loss  Transformer long epoch val loss
# 1      Transformer long epoch train loss  Transformer long epoch val loss
# 2      Transformer long epoch train loss  Transformer long epoch val loss
# ...

# %%
p = sns.lineplot(data=df_tf, x='epoch', y='train_loss', hue='model_tr', palette = sns.color_palette("mako")[4:])
sns.lineplot(data=df_tflong, x='epoch', y='train_loss', hue='model_tr', palette=sns.color_palette("flare")[0:])
sns.lineplot(data=df_tf, x='epoch', y='val_loss', hue='model_val', palette = sns.color_palette("mako")[3:])
sns.lineplot(data=df_tflong, x='epoch', y='val_loss', hue='model_val', palette=sns.color_palette("flare")[4:])
plt.ylabel('loss')
plt.legend(title = None)
# Out:
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\482717064.py:1: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
#   p = sns.lineplot(data=df_tf, x='epoch', y='train_loss', hue='model_tr', palette = sns.color_palette("mako")[4:])
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\482717064.py:2: UserWarning: The palette list has more values (6) than needed (1), which may not be intended.
#   sns.lineplot(data=df_tflong, x='epoch', y='train_loss', hue='model_tr', palette=sns.color_palette("flare")[0:])
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\482717064.py:3: UserWarning: The palette list has more values (3) than needed (1), which may not be intended.
#   sns.lineplot(data=df_tf, x='epoch', y='val_loss', hue='model_val', palette = sns.color_palette("mako")[3:])
# C:\Users\22674\AppData\Local\Temp\ipykernel_4876\482717064.py:4: UserWarning: The palette list has more values (2) than needed (1), which may not be intended.
# ...

# %%
sns.lineplot(data=df_tf, x='epoch', y='AUPR', hue='model')
sns.lineplot(data=df_tflong, x='epoch', y='AUPR', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='AUPR'>

# %%
sns.lineplot(data=df_tf, x='epoch', y='MCC', hue='model')
sns.lineplot(data=df_tflong, x='epoch', y='MCC', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='MCC'>

# %% [markdown]
# it is interesting that a soar in val loss actual corresponds to a soar in val AUPR and MCC.
# this is when the model learns to predict more 1s, which is good for AUPR and MCC, but bad for loss.

# %% [markdown]
# T5 vs Ankh

# %%
''' t5
Zn(2+)                   |precision:  0.356|recall:  0.696|specificity:  1.000|MCC:  0.498|AUROC: 0.978|AUPR: 0.477
Mg(2+)                   |precision:  0.226|recall:  0.512|specificity:  1.000|MCC:  0.340|AUROC: 0.918|AUPR: 0.317
[4Fe-4S] cluster         |precision:  0.251|recall:  0.939|specificity:  1.000|MCC:  0.486|AUROC: 1.000|AUPR: 0.611
Ca(2+)                   |precision:  0.267|recall:  0.508|specificity:  1.000|MCC:  0.368|AUROC: 0.949|AUPR: 0.317
Mn(2+)                   |precision:  0.071|recall:  0.352|specificity:  1.000|MCC:  0.158|AUROC: 0.930|AUPR: 0.032
a divalent metal cation  |precision:  0.314|recall:  0.638|specificity:  0.999|MCC:  0.447|AUROC: 0.949|AUPR: 0.434
Fe cation                |precision:  0.202|recall:  0.368|specificity:  1.000|MCC:  0.273|AUROC: 0.982|AUPR: 0.180
[2Fe-2S] cluster         |precision:  0.628|recall:  0.931|specificity:  1.000|MCC:  0.765|AUROC: 0.993|AUPR: 0.914
Cu cation                |precision:  0.763|recall:  0.833|specificity:  1.000|MCC:  0.797|AUROC: 0.999|AUPR: 0.849
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.760|AUPR: 0.000
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.999|AUPR: 0.001
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.977|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.808|AUPR: 0.012
iron-sulfur cluster      |precision:  0.344|recall:  0.935|specificity:  1.000|MCC:  0.567|AUROC: 0.998|AUPR: 0.869
Cu(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 1.000|AUPR: 0.220
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 1.000|AUPR: 0.002
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.946|AUPR: 0.004
a metal cation           |precision:  0.338|recall:  0.640|specificity:  0.999|MCC:  0.464|AUROC: 0.925|AUPR: 0.454
mean                     |pre(0-1):  0.209|rec(0-1):  0.408|spe(0-1):  1.000|MCC(-1-1):  0.287|AUROC(0-1): 0.951|AUPR(0-1): 0.316



'''
# Out:
# ' t5\nZn(2+)                   |precision:  0.356|recall:  0.696|specificity:  1.000|MCC:  0.498|AUROC: 0.978|AUPR: 0.477\nMg(2+)                   |precision:  0.226|recall:  0.512|specificity:  1.000|MCC:  0.340|AUROC: 0.918|AUPR: 0.317\n[4Fe-4S] cluster         |precision:  0.251|recall:  0.939|specificity:  1.000|MCC:  0.486|AUROC: 1.000|AUPR: 0.611\nCa(2+)                   |precision:  0.267|recall:  0.508|specificity:  1.000|MCC:  0.368|AUROC: 0.949|AUPR: 0.317\nMn(2+)                   |precision:  0.071|recall:  0.352|specificity:  1.000|MCC:  0.158|AUROC: 0.930|AUPR: 0.032\na divalent metal cation  |precision:  0.314|recall:  0.638|specificity:  0.999|MCC:  0.447|AUROC: 0.949|AUPR: 0.434\nFe cation                |precision:  0.202|recall:  0.368|specificity:  1.000|MCC:  0.273|AUROC: 0.982|AUPR: 0.180\n[2Fe-2S] cluster         |precision:  0.628|recall:  0.931|specificity:  1.000|MCC:  0.765|AUROC: 0.993|AUPR: 0.914\nCu cation                |precision:  0.763|recall:  0.8
# ...

# %%
df_tf = pd.read_csv(r'lightning_logs\transformer1\metrics.csv')
model = ['Transformer Ankh' for i in range(len(df_tf['train_loss']))]
df_tf['model'] = model

df_tf
# Out:
#      train_loss  epoch   step  val_loss       MCC      AUPR  test_loss  \
# 0      0.281310      0     49       NaN       NaN       NaN        NaN
# 1      0.250046      0     99       NaN       NaN       NaN        NaN
# 2      0.152091      0    149       NaN       NaN       NaN        NaN
# 3      0.197413      0    199       NaN       NaN       NaN        NaN
# 4      0.250717      0    249       NaN       NaN       NaN        NaN
# ..          ...    ...    ...       ...       ...       ...        ...
# 622    0.012464     99  30699       NaN       NaN       NaN        NaN
# 623    0.015318     99  30749       NaN       NaN       NaN        NaN
# 624    0.014747     99  30799       NaN       NaN       NaN        NaN
# 625         NaN     99  30803  0.041829  0.425199  0.420913        NaN
# 626         NaN    100  30804       NaN       NaN       NaN   0.055705
#
#                 model
# 0    Transformer Ankh
# 1    Transformer Ankh
# 2    Transformer Ankh
# ...

# %%
df_tf_t5 = pd.read_csv(r'lightning_logs\t5\metrics.csv')
model = ['Transformer ProtT5' for i in range(len(df_tf_t5['train_loss']))]
df_tf_t5['model'] = model

df_tf_t5
# Out:
#       train_loss  epoch   step  val_loss       MCC      AUPR  \
# 0       0.242066      0     49       NaN       NaN       NaN
# 1       0.210535      0     99       NaN       NaN       NaN
# 2       0.626845      0    149       NaN       NaN       NaN
# 3       0.121791      0    199       NaN       NaN       NaN
# 4       0.136035      0    249       NaN       NaN       NaN
# ...          ...    ...    ...       ...       ...       ...
# 6666    0.057755     99  30800       NaN       NaN       NaN
# 6667    0.010719     99  30801       NaN       NaN       NaN
# 6668    0.025452     99  30802       NaN       NaN       NaN
# 6669    0.004460     99  30803       NaN       NaN       NaN
# 6670         NaN     99  30803  0.047351  0.414911  0.394635
#
#                    model
# 0     Transformer ProtT5
# 1     Transformer ProtT5
# 2     Transformer ProtT5
# 3     Transformer ProtT5
# 4     Transformer ProtT5
# ...                  ...
# 6666  Transformer ProtT5
# ...

# %%
sns.lineplot(data=df_tf, x='epoch', y='train_loss', hue='model')
sns.lineplot(data=df_tf_t5, x='epoch', y='train_loss', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='train_loss'>

# %%
sns.lineplot(data=df_tf, x='epoch', y='val_loss', hue='model')
sns.lineplot(data=df_tf_t5, x='epoch', y='val_loss', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='val_loss'>

# %%
sns.lineplot(data=df_tf, x='epoch', y='AUPR', hue='model')
sns.lineplot(data=df_tf_t5, x='epoch', y='AUPR', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='AUPR'>

# %%
sns.lineplot(data=df_tf, x='epoch', y='MCC', hue='model')
sns.lineplot(data=df_tf_t5, x='epoch', y='MCC', hue='model', palette="flare")
# Out:
# <Axes: xlabel='epoch', ylabel='MCC'>

# %% [markdown]
# t5 not as good as ankh, but it is highly competitive. note we did not tune the hyperparameters for t5.

# %% [markdown]
# thres finetune

# %%
'''
tf  

Zn(2+)                   |precision:  0.521|recall:  0.571|specificity:  1.000|MCC:  0.545|AUROC: 0.971|AUPR: 0.529
Mg(2+)                   |precision:  0.514|recall:  0.463|specificity:  1.000|MCC:  0.487|AUROC: 0.945|AUPR: 0.451
[4Fe-4S] cluster         |precision:  0.544|recall:  0.742|specificity:  1.000|MCC:  0.636|AUROC: 1.000|AUPR: 0.652
Ca(2+)                   |precision:  0.522|recall:  0.443|specificity:  1.000|MCC:  0.481|AUROC: 0.969|AUPR: 0.340
Mn(2+)                   |precision:  0.152|recall:  0.141|specificity:  1.000|MCC:  0.146|AUROC: 0.971|AUPR: 0.080
a divalent metal cation  |precision:  0.641|recall:  0.473|specificity:  1.000|MCC:  0.550|AUROC: 0.960|AUPR: 0.506
Fe cation                |precision:  0.512|recall:  0.368|specificity:  1.000|MCC:  0.434|AUROC: 0.956|AUPR: 0.226
[2Fe-2S] cluster         |precision:  0.966|recall:  0.966|specificity:  1.000|MCC:  0.966|AUROC: 1.000|AUPR: 0.966
Cu cation                |precision:  0.783|recall:  0.870|specificity:  1.000|MCC:  0.826|AUROC: 0.959|AUPR: 0.846
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.445|AUPR: 0.000
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.999|AUPR: 0.002
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.831|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.753|AUPR: 0.001
iron-sulfur cluster      |precision:  0.605|recall:  0.860|specificity:  1.000|MCC:  0.721|AUROC: 1.000|AUPR: 0.831
Cu(2+)                   |precision:  0.200|recall:  0.500|specificity:  1.000|MCC:  0.316|AUROC: 1.000|AUPR: 0.235
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 0.999|AUPR: 0.001
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.886|AUPR: 0.003
a metal cation           |precision:  0.655|recall:  0.479|specificity:  1.000|MCC:  0.560|AUROC: 0.935|AUPR: 0.520
mean                     |pre(0-1):  0.367|rec(0-1):  0.382|spe(0-1):  1.000|MCC(-1-1):  0.370|AUROC(0-1): 0.921|AUPR(0-1): 0.344




CNN
Zn(2+)                   |precision:  0.424|recall:  0.412|specificity:  1.000|MCC:  0.418|AUROC: 0.985|AUPR: 0.288
Mg(2+)                   |precision:  0.350|recall:  0.400|specificity:  1.000|MCC:  0.374|AUROC: 0.960|AUPR: 0.301
[4Fe-4S] cluster         |precision:  0.223|recall:  0.667|specificity:  1.000|MCC:  0.386|AUROC: 1.000|AUPR: 0.155
Ca(2+)                   |precision:  0.240|recall:  0.352|specificity:  1.000|MCC:  0.290|AUROC: 0.979|AUPR: 0.135
Mn(2+)                   |precision:  0.034|recall:  0.056|specificity:  1.000|MCC:  0.044|AUROC: 0.956|AUPR: 0.022
a divalent metal cation  |precision:  0.463|recall:  0.415|specificity:  1.000|MCC:  0.438|AUROC: 0.977|AUPR: 0.316
Fe cation                |precision:  0.500|recall:  0.351|specificity:  1.000|MCC:  0.419|AUROC: 0.978|AUPR: 0.202
[2Fe-2S] cluster         |precision:  0.786|recall:  0.759|specificity:  1.000|MCC:  0.772|AUROC: 1.000|AUPR: 0.877
Cu cation                |precision:  0.232|recall:  0.778|specificity:  1.000|MCC:  0.425|AUROC: 0.997|AUPR: 0.145
K(+)                     |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.958|AUPR: 0.001
Ni(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.968|AUPR: 0.000
Na(+)                    |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.928|AUPR: 0.000
Fe(3+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.847|AUPR: 0.000
iron-sulfur cluster      |precision:  0.421|recall:  0.673|specificity:  1.000|MCC:  0.532|AUROC: 1.000|AUPR: 0.402
Cu(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 1.000|AUPR: 0.007
Fe(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.866|AUPR: 0.000
Co(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC: -0.000|AUROC: 0.801|AUPR: 0.000
a metal cation           |precision:  0.431|recall:  0.483|specificity:  1.000|MCC:  0.456|AUROC: 0.975|AUPR: 0.343
mean                     |pre(0-1):  0.228|rec(0-1):  0.297|spe(0-1):  1.000|MCC(-1-1):  0.253|AUROC(0-1): 0.954|AUPR(0-1): 0.178


'''
# Out:
# '\ntf  \n\nZn(2+)                   |precision:  0.521|recall:  0.571|specificity:  1.000|MCC:  0.545|AUROC: 0.971|AUPR: 0.529\nMg(2+)                   |precision:  0.514|recall:  0.463|specificity:  1.000|MCC:  0.487|AUROC: 0.945|AUPR: 0.451\n[4Fe-4S] cluster         |precision:  0.544|recall:  0.742|specificity:  1.000|MCC:  0.636|AUROC: 1.000|AUPR: 0.652\nCa(2+)                   |precision:  0.522|recall:  0.443|specificity:  1.000|MCC:  0.481|AUROC: 0.969|AUPR: 0.340\nMn(2+)                   |precision:  0.152|recall:  0.141|specificity:  1.000|MCC:  0.146|AUROC: 0.971|AUPR: 0.080\na divalent metal cation  |precision:  0.641|recall:  0.473|specificity:  1.000|MCC:  0.550|AUROC: 0.960|AUPR: 0.506\nFe cation                |precision:  0.512|recall:  0.368|specificity:  1.000|MCC:  0.434|AUROC: 0.956|AUPR: 0.226\n[2Fe-2S] cluster         |precision:  0.966|recall:  0.966|specificity:  1.000|MCC:  0.966|AUROC: 1.000|AUPR: 0.966\nCu cation                |precision:  0.783|recall:
# ...

# %% [markdown]
# 11 types

# %%
'''  
Zn(2+)                   |precision:  0.384|recall:  0.665|specificity:  1.000|MCC:  0.505|AUROC: 0.970|AUPR: 0.513
Mg(2+)                   |precision:  0.368|recall:  0.537|specificity:  1.000|MCC:  0.444|AUROC: 0.893|AUPR: 0.431
[4Fe-4S] cluster         |precision:  0.383|recall:  0.894|specificity:  1.000|MCC:  0.585|AUROC: 1.000|AUPR: 0.714
Ca(2+)                   |precision:  0.290|recall:  0.587|specificity:  1.000|MCC:  0.413|AUROC: 0.976|AUPR: 0.357
Mn(2+)                   |precision:  0.049|recall:  0.169|specificity:  1.000|MCC:  0.091|AUROC: 0.916|AUPR: 0.035
a divalent metal cation  |precision:  0.374|recall:  0.654|specificity:  0.999|MCC:  0.495|AUROC: 0.935|AUPR: 0.504
Fe cation                |precision:  0.241|recall:  0.368|specificity:  1.000|MCC:  0.298|AUROC: 0.980|AUPR: 0.233
[2Fe-2S] cluster         |precision:  0.718|recall:  0.966|specificity:  1.000|MCC:  0.833|AUROC: 0.999|AUPR: 0.950
Cu cation                |precision:  0.714|recall:  0.833|specificity:  1.000|MCC:  0.772|AUROC: 0.957|AUPR: 0.831
iron-sulfur cluster      |precision:  0.503|recall:  0.907|specificity:  1.000|MCC:  0.675|AUROC: 0.999|AUPR: 0.842
a metal cation           |precision:  0.393|recall:  0.662|specificity:  0.999|MCC:  0.510|AUROC: 0.933|AUPR: 0.521
mean                     |pre(0-1):  0.402|rec(0-1):  0.658|spe(0-1):  1.000|MCC(-1-1):  0.511|AUROC(0-1): 0.960|AUPR(0-1): 0.539


ft thres
Zn(2+)                   |precision:  0.571|recall:  0.494|specificity:  1.000|MCC:  0.531|AUROC: 0.970|AUPR: 0.513
Mg(2+)                   |precision:  0.562|recall:  0.456|specificity:  1.000|MCC:  0.506|AUROC: 0.893|AUPR: 0.431
[4Fe-4S] cluster         |precision:  0.561|recall:  0.833|specificity:  1.000|MCC:  0.684|AUROC: 1.000|AUPR: 0.714
Ca(2+)                   |precision:  0.485|recall:  0.428|specificity:  1.000|MCC:  0.456|AUROC: 0.976|AUPR: 0.357
Mn(2+)                   |precision:  0.044|recall:  0.042|specificity:  1.000|MCC:  0.043|AUROC: 0.916|AUPR: 0.035
a divalent metal cation  |precision:  0.562|recall:  0.485|specificity:  1.000|MCC:  0.522|AUROC: 0.935|AUPR: 0.504
Fe cation                |precision:  0.419|recall:  0.316|specificity:  1.000|MCC:  0.364|AUROC: 0.980|AUPR: 0.233
[2Fe-2S] cluster         |precision:  0.933|recall:  0.966|specificity:  1.000|MCC:  0.949|AUROC: 0.999|AUPR: 0.950
Cu cation                |precision:  0.750|recall:  0.833|specificity:  1.000|MCC:  0.791|AUROC: 0.957|AUPR: 0.831
iron-sulfur cluster      |precision:  0.657|recall:  0.860|specificity:  1.000|MCC:  0.752|AUROC: 0.999|AUPR: 0.842
a metal cation           |precision:  0.595|recall:  0.493|specificity:  1.000|MCC:  0.541|AUROC: 0.933|AUPR: 0.521
mean                     |pre(0-1):  0.558|rec(0-1):  0.564|spe(0-1):  1.000|MCC(-1-1):  0.558|AUROC(0-1): 0.960|AUPR(0-1): 0.539

Zn(2+)                   |max MCC:  0.566|thres:  0.990
Mg(2+)                   |max MCC:  0.453|thres:  0.950
[4Fe-4S] cluster         |max MCC:  0.766|thres:  0.980
Ca(2+)                   |max MCC:  0.596|thres:  0.990
Mn(2+)                   |max MCC:  0.486|thres:  0.980
a divalent metal cation  |max MCC:  0.572|thres:  0.990
Fe cation                |max MCC:  0.734|thres:  0.990
[2Fe-2S] cluster         |max MCC:  0.801|thres:  0.950
Cu cation                |max MCC:  0.670|thres:  0.730
iron-sulfur cluster      |max MCC:  0.793|thres:  0.980
a metal cation           |max MCC:  0.602|thres:  0.990
'''
# Out:
# '  \nZn(2+)                   |precision:  0.384|recall:  0.665|specificity:  1.000|MCC:  0.505|AUROC: 0.970|AUPR: 0.513\nMg(2+)                   |precision:  0.368|recall:  0.537|specificity:  1.000|MCC:  0.444|AUROC: 0.893|AUPR: 0.431\n[4Fe-4S] cluster         |precision:  0.383|recall:  0.894|specificity:  1.000|MCC:  0.585|AUROC: 1.000|AUPR: 0.714\nCa(2+)                   |precision:  0.290|recall:  0.587|specificity:  1.000|MCC:  0.413|AUROC: 0.976|AUPR: 0.357\nMn(2+)                   |precision:  0.049|recall:  0.169|specificity:  1.000|MCC:  0.091|AUROC: 0.916|AUPR: 0.035\na divalent metal cation  |precision:  0.374|recall:  0.654|specificity:  0.999|MCC:  0.495|AUROC: 0.935|AUPR: 0.504\nFe cation                |precision:  0.241|recall:  0.368|specificity:  1.000|MCC:  0.298|AUROC: 0.980|AUPR: 0.233\n[2Fe-2S] cluster         |precision:  0.718|recall:  0.966|specificity:  1.000|MCC:  0.833|AUROC: 0.999|AUPR: 0.950\nCu cation                |precision:  0.714|recall:  0.83
# ...

# %%
df_tf = pd.read_csv(r'lightning_logs\tf-11types\metrics.csv')
# model = ['Transformer Ankh' for i in range(len(df_tf['train_loss']))]
# df_tf['model'] = model

df_tf
# Out:
#       train_loss  epoch   step  val_loss  MCC  AUPR
# 0       0.295740      0     49       NaN  NaN   NaN
# 1       0.140652      0     99       NaN  NaN   NaN
# 2       0.101395      0    149       NaN  NaN   NaN
# 3       0.130350      0    199       NaN  NaN   NaN
# 4       0.235178      0    249       NaN  NaN   NaN
# ...          ...    ...    ...       ...  ...   ...
# 2937    0.007897    117  36133       NaN  NaN   NaN
# 2938    0.020725    117  36134       NaN  NaN   NaN
# 2939    0.007706    117  36135       NaN  NaN   NaN
# 2940    0.005872    117  36136       NaN  NaN   NaN
# 2941    0.049860    117  36137       NaN  NaN   NaN
#
# [2942 rows x 6 columns]

# %% [markdown]
# 12 types obselete

# %%
'''   
Zn(2+)                   |precision:  0.429|recall:  0.639|specificity:  1.000|MCC:  0.524|AUROC: 0.972|AUPR: 0.523
Mg(2+)                   |precision:  0.326|recall:  0.575|specificity:  1.000|MCC:  0.433|AUROC: 0.934|AUPR: 0.437
[4Fe-4S] cluster         |precision:  0.454|recall:  0.894|specificity:  1.000|MCC:  0.637|AUROC: 1.000|AUPR: 0.553
Ca(2+)                   |precision:  0.287|recall:  0.545|specificity:  1.000|MCC:  0.396|AUROC: 0.928|AUPR: 0.321
Mn(2+)                   |precision:  0.075|recall:  0.225|specificity:  1.000|MCC:  0.130|AUROC: 0.945|AUPR: 0.051
a divalent metal cation  |precision:  0.379|recall:  0.634|specificity:  0.999|MCC:  0.489|AUROC: 0.948|AUPR: 0.493
Fe cation                |precision:  0.216|recall:  0.386|specificity:  1.000|MCC:  0.288|AUROC: 0.928|AUPR: 0.209
[2Fe-2S] cluster         |precision:  0.583|recall:  0.966|specificity:  1.000|MCC:  0.750|AUROC: 0.989|AUPR: 0.966
Cu cation                |precision:  0.758|recall:  0.870|specificity:  1.000|MCC:  0.812|AUROC: 0.998|AUPR: 0.859
iron-sulfur cluster      |precision:  0.568|recall:  0.935|specificity:  1.000|MCC:  0.729|AUROC: 0.998|AUPR: 0.757
Cu(2+)                   |precision:  0.000|recall:  0.000|specificity:  1.000|MCC:  0.000|AUROC: 1.000|AUPR: 0.171
a metal cation           |precision:  0.398|recall:  0.643|specificity:  0.999|MCC:  0.506|AUROC: 0.949|AUPR: 0.513
mean                     |pre(0-1):  0.373|rec(0-1):  0.609|spe(0-1):  1.000|MCC(-1-1):  0.475|AUROC(0-1): 0.966|AUPR(0-1): 0.488
'''
# Out:
# '   \nZn(2+)                   |precision:  0.429|recall:  0.639|specificity:  1.000|MCC:  0.524|AUROC: 0.972|AUPR: 0.523\nMg(2+)                   |precision:  0.326|recall:  0.575|specificity:  1.000|MCC:  0.433|AUROC: 0.934|AUPR: 0.437\n[4Fe-4S] cluster         |precision:  0.454|recall:  0.894|specificity:  1.000|MCC:  0.637|AUROC: 1.000|AUPR: 0.553\nCa(2+)                   |precision:  0.287|recall:  0.545|specificity:  1.000|MCC:  0.396|AUROC: 0.928|AUPR: 0.321\nMn(2+)                   |precision:  0.075|recall:  0.225|specificity:  1.000|MCC:  0.130|AUROC: 0.945|AUPR: 0.051\na divalent metal cation  |precision:  0.379|recall:  0.634|specificity:  0.999|MCC:  0.489|AUROC: 0.948|AUPR: 0.493\nFe cation                |precision:  0.216|recall:  0.386|specificity:  1.000|MCC:  0.288|AUROC: 0.928|AUPR: 0.209\n[2Fe-2S] cluster         |precision:  0.583|recall:  0.966|specificity:  1.000|MCC:  0.750|AUROC: 0.989|AUPR: 0.966\nCu cation                |precision:  0.758|recall:  0.8
# ...
